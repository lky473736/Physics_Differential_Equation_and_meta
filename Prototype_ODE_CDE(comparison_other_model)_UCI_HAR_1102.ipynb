# %%
import os
import time
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import autocast, GradScaler
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from IPython.display import display
from ptflops import get_model_complexity_info

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def compute_model_stats(model, input_shape=(1,9,128)):
    macs, params = get_model_complexity_info(model, (input_shape[1], input_shape[2]), as_strings=False, print_per_layer_stat=False, verbose=False)
    return params/1e6, macs/1e6

def measure_inference_time(model, sz=(1,9,128), dev='cuda', runs=100, warm=10):
    model.eval()
    x = torch.randn(sz, device=dev)
    with torch.inference_mode():
        for _ in range(warm): _ = model(x)
    torch.cuda.synchronize() if dev=='cuda' else None
    t0 = time.time()
    with torch.inference_mode():
        for _ in range(runs): _ = model(x)
    torch.cuda.synchronize() if dev=='cuda' else None
    return (time.time()-t0)/runs*1000

def plot_confusion_matrix(cm, labels, path='cm.png'):
    cmn = cm.astype('float')/cm.sum(axis=1)[:,None]
    df = pd.DataFrame(cmn, index=labels, columns=labels)
    plt.figure(figsize=(6,6))
    sns.heatmap(df, annot=True, fmt='.2f', cmap='Blues', cbar=True)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()
    plt.close()

class HARDataset(Dataset):
    def __init__(self, X, y, norm=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if norm:
            self.mean = self.X.mean(axis=(0,2), keepdims=True)
            self.std = self.X.std(axis=(0,2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean)/self.std
        else:
            self.mean, self.std = 0, 1
    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean)/self.std
    def __len__(self): return len(self.y)
    def __getitem__(self, i): return torch.from_numpy(self.X[i]), int(self.y[i])

def read_txt_matrix(p): return np.loadtxt(p, dtype=np.float32)

def load_full_uci_har_data(root):
    pref = ["total_acc_x_","total_acc_y_","total_acc_z_","body_acc_x_","body_acc_y_","body_acc_z_","body_gyro_x_","body_gyro_y_","body_gyro_z_"]
    def load(s):
        ch = [read_txt_matrix(os.path.join(root,f"{p}{s}.txt")) for p in pref]
        X = np.stack(ch, axis=1)
        y = read_txt_matrix(os.path.join(root,f"y_{s}.txt")).astype(int)-1
        sub = read_txt_matrix(os.path.join(root,f"subject_{s}.txt")).astype(int)
        return X,y,sub
    Xtr,ytr,str = load("train")
    Xte,yte,ste = load("test")
    X = np.concatenate((Xtr,Xte))
    y = np.concatenate((ytr,yte))
    sub = np.concatenate((str,ste))
    idx = np.argsort(sub)
    X,y,sub = X[idx],y[idx],sub[idx]
    names = ['Walking','Walking Upstairs','Walking Downstairs','Sitting','Standing','Laying']
    return X,y,sub,names

class ODEF(nn.Module):
    def forward_with_grad(self, z, t, grad_outputs):
        bs = z.shape[0]
        out = self.forward(z, t)
        a = grad_outputs
        adfdz, adfdt, *adfdp = torch.autograd.grad((out,), (z, t)+tuple(self.parameters()), grad_outputs=(a,), allow_unused=True, retain_graph=True)
        if adfdp: adfdp = torch.cat([p.flatten() for p in adfdp]).unsqueeze(0).expand(bs,-1)/bs
        if adfdt is not None: adfdt = adfdt.expand(bs,1)/bs
        return out, adfdz, adfdt, adfdp
    def flatten_parameters(self):
        return torch.cat([p.flatten() for p in self.parameters()])

class ODEAdjoint(torch.autograd.Function):
    @staticmethod
    def forward(ctx, z0, t, flat_params, func):
        bs, *z_shape = z0.size()
        tl = t.size(0)
        with torch.no_grad():
            z = torch.zeros(tl, bs, *z_shape, device=z0.device)
            z[0] = z0
            for i in range(tl-1):
                z0 = ode_solve(z0, t[i], t[i+1], func)
                z[i+1] = z0
        ctx.func = func
        ctx.save_for_backward(t, z.clone(), flat_params)
        return z
    @staticmethod
    def backward(ctx, dLdz):
        func = ctx.func
        t, z, flat_params = ctx.saved_tensors
        tl, bs, *z_shape = z.size()
        nd = np.prod(z_shape)
        nprm = flat_params.size(0)
        def aug_dyn(aug, ti):
            zi = aug[:,:nd].view(bs,*z_shape)
            a = aug[:,nd:2*nd].view(bs,*z_shape)
            ti = ti.float()
            with torch.enable_grad():
                ti = ti.detach().requires_grad_(True)
                zi = zi.detach().requires_grad_(True)
                f, dfdz, dfdt, dfdp = func.forward_with_grad(zi, ti, a)
                dfdz = dfdz.to(zi) if dfdz is not None else torch.zeros_like(zi)
                dfdp = dfdp.to(zi) if dfdp is not None else torch.zeros(bs, nprm, device=zi.device)
                dfdt = dfdt.to(zi) if dfdt is not None else torch.zeros(bs,1, device=zi.device)
            return torch.cat((f.view(bs,nd), -dfdz.view(bs,nd), -dfdp.view(bs,nprm), -dfdt.view(bs,1)), dim=1)
        dLdz = dLdz.view(tl, bs, nd).float()
        with torch.no_grad():
            adj_z = torch.zeros(bs, nd, device=dLdz.device)
            adj_p = torch.zeros(bs, nprm, device=dLdz.device)
            adj_t = torch.zeros(tl, bs, 1, device=dLdz.device)
            for i in range(tl-1,0,-1):
                zi = z[i].float()
                ti = t[i].float()
                fi = func(zi, ti).view(bs,nd).float()
                dLdzi = dLdz[i].float()
                dLdti = torch.bmm(dLdzi.unsqueeze(-1).transpose(1,2), fi.unsqueeze(-1))[:,0]
                adj_z += dLdzi
                adj_t[i] = adj_t[i] - dLdti
                aug0 = torch.cat((zi.view(bs,nd), adj_z, torch.zeros(bs,nprm,device=z.device), adj_t[i]), dim=-1)
                aug1 = ode_solve(aug0, ti, t[i-1], aug_dyn)
                adj_z[:] = aug1[:,nd:2*nd]
                adj_p[:] += aug1[:,2*nd:2*nd+nprm]
                adj_t[i-1] = aug1[:,2*nd+nprm:]
            dLdz0 = dLdz[0].float()
            dLdt0 = torch.bmm(dLdz0.unsqueeze(-1).transpose(1,2), fi.unsqueeze(-1))[:,0]
            adj_z += dLdz0
            adj_t[0] = adj_t[0] - dLdt0
        return adj_z.view(bs,*z_shape), adj_t, adj_p, None

def ode_solve(z0, t0, t1, f):
    hmax = 0.05
    steps = math.ceil((abs(t1-t0)/hmax).max().item())
    h = (t1-t0)/steps
    z = z0
    t = t0
    for _ in range(steps):
        z = z + h*f(z, t)
        t = t + h
    return z

class NeuralODE(nn.Module):
    def __init__(self, func):
        super().__init__()
        assert isinstance(func, ODEF)
        self.func = func
    def forward(self, z0, t=torch.tensor([0.,1.]), whole=False):
        t = t.to(z0)
        z = ODEAdjoint.apply(z0, t, self.func.flatten_parameters(), self.func)
        return z if whole else z[-1]

class NNODEF(ODEF):
    def __init__(self, dim, hid, ti=False):
        super().__init__()
        self.ti = ti
        self.l1 = nn.Linear(dim+1 if not ti else dim, hid)
        self.l2 = nn.Linear(hid, hid)
        self.l3 = nn.Linear(hid, hid)
        self.l4 = nn.Linear(hid, hid)
        self.l5 = nn.Linear(hid, hid)
        self.l6 = nn.Linear(hid, hid)
        self.l7 = nn.Linear(hid, dim)
        self.act = nn.LeakyReLU(inplace=True)
    def forward(self, x, t):
        if not self.ti:
            t = t.expand(x.shape[0],1)
            x = torch.cat((x,t), dim=-1)
        h = self.act(self.l1(x))
        h = self.act(self.l2(h))
        h = self.act(self.l3(h))
        h = self.act(self.l4(h))
        h = self.act(self.l5(h))
        h = self.act(self.l6(h))
        return self.l7(h)

class LogSigCDEFunc(ODEF):
    def __init__(self, in_dim, hid_dim):
        super().__init__()
        self.in_dim = in_dim
        self.hid_dim = hid_dim
        self.theta = nn.Parameter(torch.randn(in_dim, hid_dim))
        self.net = nn.Sequential(
            nn.Linear(hid_dim, hid_dim*2),
            nn.LeakyReLU(inplace=True),
            nn.Linear(hid_dim*2, hid_dim*2),
            nn.LeakyReLU(inplace=True),
            nn.Linear(hid_dim*2, hid_dim*2),
            nn.LeakyReLU(inplace=True),
            nn.Linear(hid_dim*2, hid_dim)
        )
    def forward(self, X, t=None):
        dX = X[:,1:] - X[:,:-1]
        dX = F.normalize(dX, dim=-1)
        h = F.linear(dX, self.theta)
        return self.net(h)

class PrototypeClassifier(nn.Module):
    def __init__(self, in_dim, n_classes):
        super().__init__()
        self.prototypes = nn.Parameter(torch.randn(n_classes, in_dim))

    def forward(self, x):
        x_norm_sq = (x**2).sum(1, keepdim=True)
        p_norm_sq = (self.prototypes**2).sum(1, keepdim=True).t()
        dot_product = torch.mm(x, self.prototypes.t())
        distances = x_norm_sq + p_norm_sq - 2 * dot_product
        return -distances

class NeuralCDE(nn.Module):
    def __init__(self, in_dim, hid_dim, out_dim, seq_len, **kwargs):
        super().__init__()
        self.seq_len = seq_len
        self.init = nn.Linear(in_dim, hid_dim)
        self.cdef = LogSigCDEFunc(in_dim, hid_dim)
        self.odef = NNODEF(hid_dim, hid_dim*2, ti=True)
        self.ode = NeuralODE(self.odef)
        self.norm = nn.LayerNorm(hid_dim)
        self.cls = PrototypeClassifier(hid_dim, out_dim)
    def extract_features(self, x):
        B,C,T = x.shape
        X = torch.cumsum(x, dim=2)
        z0 = self.init(X[:,:,0])
        t = torch.linspace(0,1,T, device=x.device)
        zT = self.ode(z0, t)
        return self.norm(zT)
    def forward(self, x):
        return self.cls(self.extract_features(x))

class CNNModel(nn.Module):
    def __init__(self, n_channels=9, n_classes=6, **kwargs):
        super().__init__()
        self.c1 = nn.Conv1d(n_channels,64,5,padding=2)
        self.c2 = nn.Conv1d(64,128,5,padding=2)
        self.c3 = nn.Conv1d(128,256,5,padding=2)
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.cls = nn.Linear(256, n_classes)
    def extract_features(self, x):
        x = F.relu(self.c1(x))
        x = F.relu(self.c2(x))
        x = F.relu(self.c3(x))
        return self.pool(x).flatten(1)
    def forward(self, x):
        return self.cls(self.extract_features(x))

class TransformerModel(nn.Module):
    def __init__(self, n_channels=9, seq_len=128, d_model=64, n_classes=6, nhead=4, nlayers=2):
        super().__init__()
        self.proj = nn.Linear(n_channels, d_model)
        enc = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward=256, batch_first=True)
        self.trans = nn.TransformerEncoder(enc, nlayers)
        self.norm = nn.LayerNorm(d_model)
        self.cls = nn.Linear(d_model, n_classes)
    def extract_features(self, x):
        B,C,T = x.shape
        x = x.transpose(1,2)
        x = self.proj(x)
        x = self.trans(x)
        return self.norm(x.mean(1))
    def forward(self, x):
        return self.cls(self.extract_features(x))

class UCIHarODEModel(nn.Module):
    def __init__(self, n_channels=9, seq_len=128, d_model=64, n_classes=6):
        super().__init__()
        self.proj = nn.Linear(n_channels, d_model)
        self.f = NNODEF(d_model, d_model*2)
        self.ode = NeuralODE(self.f)
        self.norm = nn.LayerNorm(d_model)
        self.cls = PrototypeClassifier(d_model, n_classes)
    def extract_features(self, x):
        B,C,T = x.shape
        x = x.transpose(1,2)
        z0 = self.proj(x[:,0,:])
        t = torch.linspace(0,1,T, device=x.device)
        zT = self.ode(z0, t)
        return self.norm(zT)
    def forward(self, x):
        return self.cls(self.extract_features(x))

def evaluate(model, loader, dev):
    model.eval()
    preds, labs = [], []
    with torch.inference_mode():
        for x,y in loader:
            x,y = x.to(dev), y.to(dev)
            out = model(x)
            p = out.argmax(-1)
            preds.append(p.cpu().numpy())
            labs.append(y.cpu().numpy())
    preds = np.concatenate(preds)
    labs = np.concatenate(labs)
    return {'acc':accuracy_score(labs,preds),
            'f1':f1_score(labs,preds,average='macro'),
            'prec':precision_score(labs,preds,average='macro',zero_division=0),
            'rec':recall_score(labs,preds,average='macro',zero_division=0),
            'cm':confusion_matrix(labs,preds)}

def print_res(name, met, par, flop, inf, acts):
    print(f"\n{'='*80}\nResults: {name}\n{'='*80}")
    print(f"Acc: {met['acc']:.4f} | F1: {met['f1']:.4f} | Prec: {met['prec']:.4f} | Rec: {met['rec']:.4f}")
    print(f"Params: {par:.4f}M | FLOPs: {flop:.4f}M | Inf: {inf:.4f}ms\n{'='*80}")
    plot_confusion_matrix(met['cm'], acts, f"./cm_{name.replace(' ','_')}.png")

def train(model, trl, val, ep, lr, wd, dev):
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=ep)
    scaler = GradScaler('cuda')
    best, bst = 0.0, None
    for e in range(1,ep+1):
        model.train()

        epoch_loss = 0.0
        num_batches = 0

        for x,y in trl:
            x,y = x.to(dev), y.to(dev)
            opt.zero_grad()

            with autocast('cuda'):
                out = model(x)
                loss = F.cross_entropy(out, y)

            scaler.scale(loss).backward()
            scaler.unscale_(opt)
            torch.nn.utils.clip_grad_norm_(model.parameters(),1.0)
            scaler.step(opt)
            scaler.update()

            epoch_loss += loss.item()
            num_batches += 1

        sched.step()
        vm = evaluate(model, val, dev)

        avg_loss = epoch_loss / num_batches
        val_acc = vm['acc']

        log_msg = f"Epoch {e}/{ep} | Val Acc: {val_acc:.4f} | Total Loss: {avg_loss:.4f}"
        print(log_msg)

        if vm['acc']>best:
            best = vm['acc']
            bst = {k:v.cpu() for k,v in model.state_dict().items()}

    if bst: model.load_state_dict({k:v.to(dev) for k,v in bst.items()})
    return model

def run_exp(name, cls, args, trl, val, tel, ep, dev, acts, resl):
    print(f"\n{'#'*80}\n# {name}\n{'#'*80}")
    margs = {k:v for k,v in args.items() if k in ['n_channels','n_classes','seq_len','d_model','nhead','nlayers','in_dim','hid_dim','out_dim']}
    m = cls(**margs).to(dev)
    m = train(m, trl, val, ep, args['lr'], args['wd'], dev)
    met = evaluate(m, tel, dev)
    par, flop = compute_model_stats(m)
    inf = measure_inference_time(m, dev=dev)
    print_res(name, met, par, flop, inf, acts)
    resl.append({'Exp':name,'Acc':f"{met['acc']:.4f}",'F1':f"{met['f1']:.4f}",
                 'Prec':f"{met['prec']:.4f}",'Rec':f"{met['rec']:.4f}",
                 'Par(M)':f"{par:.4f}",'FLOPs(M)':f"{flop:.4f}",'Inf(ms)':f"{inf:.4f}"})
    return m

def add_noise(X, typ, lvl, seed=None):
    if seed: np.random.seed(seed)
    Xn = X.copy()
    if lvl<=0: return Xn
    B,C,T = X.shape
    if typ=='jitter':
        for b in range(B):
            for c in range(C):
                js = lvl*50
                tn = np.random.normal(0,js,T)
                ti = np.arange(T)+tn
                ti = np.clip(ti,0,T-1)
                Xn[b,c,:] = np.interp(ti, np.arange(T), X[b,c,:]).astype(np.float32)
    elif typ=='dropout':
        mask = np.random.random(X.shape)<lvl
        Xn[mask]=0.0
    elif typ=='window_shifting':
        ws = max(1,int(T*0.3))
        ms = max(1,int(lvl*T*0.8))
        for b in range(B):
            for c in range(C):
                nw = T//ws
                for w in range(nw):
                    s = w*ws
                    e = min((w+1)*ws,T)
                    if np.random.random()<lvl:
                        sh = np.random.randint(-ms,ms+1)
                        if sh>0:
                            Xn[b,c,s:e-sh] = X[b,c,s+sh:e]
                            Xn[b,c,e-sh:e] = X[b,c,e-1]
                        elif sh<0:
                            Xn[b,c,s-sh:e] = X[b,c,s:e+sh]
                            Xn[b,c,s:s-sh] = X[b,c,s]
    return Xn

if __name__=="__main__":
    set_seed(42)
    dev = 'cuda' if torch.cuda.is_available() else 'cpu'
    root = "/content/drive/MyDrive/HAR_Dataset/UCI"
    ep = 50
    bs = 512
    nw = 1
    base = {'n_channels':9,'seq_len':128,'d_model':64,'n_classes':6,
            'lr':1e-3,'wd':1e-2}
    X,y,sub,acts = load_full_uci_har_data(root)
    tst_sub = [3,12,13,15,16,17,21,26,27]
    trm = ~np.isin(sub,tst_sub)
    tem = np.isin(sub,tst_sub)
    Xtr,ytr = X[trm],y[trm]
    Xte,yte = X[tem],y[tem]
    res = []
    cfgs = [
        {'name':'CNN','cls':CNNModel,'args':base},
        {'name':'Transformer','cls':TransformerModel,'args':base},
        {'name':'NeuralCDE','cls':NeuralCDE,'args':{**base,'in_dim':9,'hid_dim':64,'out_dim':6}},
        {'name':'NeuralODE','cls':UCIHarODEModel,'args':base}
    ]
    mods = {}
    nstats = None
    for cfg in cfgs:
        kf = KFold(5,shuffle=True,random_state=42)
        tri,vali = next(kf.split(Xtr,ytr))
        trds = HARDataset(Xtr[tri],ytr[tri],True)
        vads = HARDataset(Xtr[vali],ytr[vali],False)
        teds = HARDataset(Xte,yte,False)
        vads.set_stats(trds.mean,trds.std)
        teds.set_stats(trds.mean,trds.std)
        nstats = (trds.mean,trds.std)
        trl = DataLoader(trds,bs,True,num_workers=nw,pin_memory=True)
        val = DataLoader(vads,bs,False,num_workers=nw,pin_memory=True)
        tel = DataLoader(teds,bs,False,num_workers=nw,pin_memory=True)
        m = run_exp(cfg['name'],cfg['cls'],cfg['args'],trl,val,tel,ep,dev,acts,res)
        mods[cfg['name']] = m
    ntyp = ['jitter','dropout','window_shifting']
    nlev = [0.0,0.05,0.10,0.15,0.20,0.25,0.30]
    nlab = ['0%','5%','10%','15%','20%','25%','30%']
    for nt in ntyp:
        nr = []
        for lv,la in zip(nlev,nlab):
            row = {'Noise':la}
            for mn,m in mods.items():
                Xn = add_noise(Xte,nt,lv,42)
                tdn = HARDataset(Xn,yte,False)
                tdn.set_stats(*nstats)
                tln = DataLoader(tdn,bs,False,num_workers=nw,pin_memory=True)
                met = evaluate(m,tln,dev)
                row[f'{mn}_Acc'] = f"{met['acc']:.4f}"
                row[f'{mn}_F1'] = f"{met['f1']:.4f}"
            nr.append(row)
        ret = {'Noise':'Avg_Ret'}
        for mn in mods:
            acs = [float(r[f'{mn}_Acc']) for r in nr[1:]]
            base = float(nr[0][f'{mn}_Acc'])
            ret[f'{mn}_Acc'] = f"{np.mean([a/base for a in acs]):.4f}" if base>0 else 'ERR'
            ret[f'{mn}_F1'] = '-'
        nr.append(ret)
        dfn = pd.DataFrame(nr)
        display(dfn)
        dfn.to_csv(f'./{nt}_noise.csv',index=False)
    df = pd.DataFrame(res)
    display(df)
    df.to_csv('./summary.csv',index=False)
# Out:
# ################################################################################
# # CNN
# ################################################################################
# Epoch 1/50 | Val Acc: 0.6601 | Total Loss: 1.4010
# Epoch 2/50 | Val Acc: 0.7194 | Total Loss: 0.7646
# Epoch 3/50 | Val Acc: 0.8820 | Total Loss: 0.4625
# Epoch 4/50 | Val Acc: 0.9166 | Total Loss: 0.2885
# Epoch 5/50 | Val Acc: 0.9300 | Total Loss: 0.2006
# Epoch 6/50 | Val Acc: 0.9081 | Total Loss: 0.1593
# Epoch 7/50 | Val Acc: 0.9378 | Total Loss: 0.1444
# Epoch 8/50 | Val Acc: 0.9413 | Total Loss: 0.1253
# Epoch 9/50 | Val Acc: 0.9463 | Total Loss: 0.1267
# Epoch 10/50 | Val Acc: 0.9413 | Total Loss: 0.1169
# Epoch 11/50 | Val Acc: 0.9456 | Total Loss: 0.1227
# Epoch 12/50 | Val Acc: 0.9456 | Total Loss: 0.1188
# Epoch 13/50 | Val Acc: 0.9449 | Total Loss: 0.1118
# Epoch 14/50 | Val Acc: 0.9456 | Total Loss: 0.1144
# Epoch 15/50 | Val Acc: 0.9463 | Total Loss: 0.1048
# Epoch 16/50 | Val Acc: 0.9463 | Total Loss: 0.1032
# Epoch 17/50 | Val Acc: 0.9470 | Total Loss: 0.1005
# Epoch 18/50 | Val Acc: 0.9463 | Total Loss: 0.1031
# Epoch 19/50 | Val Acc: 0.9463 | Total Loss: 0.1009
# Epoch 20/50 | Val Acc: 0.9491 | Total Loss: 0.0939
# Epoch 21/50 | Val Acc: 0.9470 | Total Loss: 0.0926
# Epoch 22/50 | Val Acc: 0.9456 | Total Loss: 0.0942
# Epoch 23/50 | Val Acc: 0.9498 | Total Loss: 0.1024
# Epoch 24/50 | Val Acc: 0.9484 | Total Loss: 0.0869
# Epoch 25/50 | Val Acc: 0.9491 | Total Loss: 0.0909
# Epoch 26/50 | Val Acc: 0.9512 | Total Loss: 0.0844
# Epoch 27/50 | Val Acc: 0.9498 | Total Loss: 0.0943
# Epoch 28/50 | Val Acc: 0.9505 | Total Loss: 0.0870
# Epoch 29/50 | Val Acc: 0.9505 | Total Loss: 0.0931
# Epoch 30/50 | Val Acc: 0.9498 | Total Loss: 0.0839
# Epoch 31/50 | Val Acc: 0.9512 | Total Loss: 0.0867
# Epoch 32/50 | Val Acc: 0.9498 | Total Loss: 0.0824
# Epoch 33/50 | Val Acc: 0.9519 | Total Loss: 0.0937
# Epoch 34/50 | Val Acc: 0.9505 | Total Loss: 0.0796
# Epoch 35/50 | Val Acc: 0.9519 | Total Loss: 0.0861
# Epoch 36/50 | Val Acc: 0.9519 | Total Loss: 0.0792
# Epoch 37/50 | Val Acc: 0.9512 | Total Loss: 0.0857
# Epoch 38/50 | Val Acc: 0.9512 | Total Loss: 0.0860
# Epoch 39/50 | Val Acc: 0.9541 | Total Loss: 0.0763
# Epoch 40/50 | Val Acc: 0.9519 | Total Loss: 0.0752
# Epoch 41/50 | Val Acc: 0.9527 | Total Loss: 0.0766
# Epoch 42/50 | Val Acc: 0.9534 | Total Loss: 0.0781
# Epoch 43/50 | Val Acc: 0.9541 | Total Loss: 0.0797
# Epoch 44/50 | Val Acc: 0.9541 | Total Loss: 0.0816
# Epoch 45/50 | Val Acc: 0.9534 | Total Loss: 0.0771
# Epoch 46/50 | Val Acc: 0.9527 | Total Loss: 0.0931
# Epoch 47/50 | Val Acc: 0.9527 | Total Loss: 0.0775
# Epoch 48/50 | Val Acc: 0.9541 | Total Loss: 0.0773
# Epoch 49/50 | Val Acc: 0.9541 | Total Loss: 0.0735
# Epoch 50/50 | Val Acc: 0.9541 | Total Loss: 0.0766
#
# ================================================================================
# Results: CNN
# ================================================================================
# Acc: 0.9436 | F1: 0.9484 | Prec: 0.9492 | Rec: 0.9482
# Params: 0.2097M | FLOPs: 26.7648M | Inf: 0.2428ms
# ================================================================================
# ################################################################################
# # Transformer
# ################################################################################
# Epoch 1/50 | Val Acc: 0.8424 | Total Loss: 1.0451
# Epoch 2/50 | Val Acc: 0.9060 | Total Loss: 0.4820
# Epoch 3/50 | Val Acc: 0.9145 | Total Loss: 0.3091
# Epoch 4/50 | Val Acc: 0.9371 | Total Loss: 0.2243
# Epoch 5/50 | Val Acc: 0.9307 | Total Loss: 0.1829
# Epoch 6/50 | Val Acc: 0.9449 | Total Loss: 0.1481
# Epoch 7/50 | Val Acc: 0.9463 | Total Loss: 0.1377
# Epoch 8/50 | Val Acc: 0.9484 | Total Loss: 0.1280
# Epoch 9/50 | Val Acc: 0.9491 | Total Loss: 0.1227
# Epoch 10/50 | Val Acc: 0.9463 | Total Loss: 0.1249
# Epoch 11/50 | Val Acc: 0.9456 | Total Loss: 0.1141
# Epoch 12/50 | Val Acc: 0.9512 | Total Loss: 0.1392
# Epoch 13/50 | Val Acc: 0.9527 | Total Loss: 0.1126
# Epoch 14/50 | Val Acc: 0.9555 | Total Loss: 0.1030
# Epoch 15/50 | Val Acc: 0.9555 | Total Loss: 0.1024
# Epoch 16/50 | Val Acc: 0.9548 | Total Loss: 0.0948
# Epoch 17/50 | Val Acc: 0.9512 | Total Loss: 0.0974
# Epoch 18/50 | Val Acc: 0.9590 | Total Loss: 0.0839
# Epoch 19/50 | Val Acc: 0.9548 | Total Loss: 0.0782
# Epoch 20/50 | Val Acc: 0.9541 | Total Loss: 0.0832
# Epoch 21/50 | Val Acc: 0.9583 | Total Loss: 0.0825
# Epoch 22/50 | Val Acc: 0.9661 | Total Loss: 0.0709
# Epoch 23/50 | Val Acc: 0.9633 | Total Loss: 0.0898
# Epoch 24/50 | Val Acc: 0.9640 | Total Loss: 0.0722
# Epoch 25/50 | Val Acc: 0.9661 | Total Loss: 0.0660
# Epoch 26/50 | Val Acc: 0.9668 | Total Loss: 0.0716
# Epoch 27/50 | Val Acc: 0.9689 | Total Loss: 0.0611
# Epoch 28/50 | Val Acc: 0.9703 | Total Loss: 0.0749
# Epoch 29/50 | Val Acc: 0.9647 | Total Loss: 0.0619
# Epoch 30/50 | Val Acc: 0.9647 | Total Loss: 0.0686
# Epoch 31/50 | Val Acc: 0.9696 | Total Loss: 0.0566
# Epoch 32/50 | Val Acc: 0.9717 | Total Loss: 0.0541
# Epoch 33/50 | Val Acc: 0.9724 | Total Loss: 0.0549
# Epoch 34/50 | Val Acc: 0.9717 | Total Loss: 0.0503
# Epoch 35/50 | Val Acc: 0.9724 | Total Loss: 0.0530
# Epoch 36/50 | Val Acc: 0.9696 | Total Loss: 0.0466
# Epoch 37/50 | Val Acc: 0.9661 | Total Loss: 0.0493
# Epoch 38/50 | Val Acc: 0.9731 | Total Loss: 0.0629
# Epoch 39/50 | Val Acc: 0.9746 | Total Loss: 0.0468
# Epoch 40/50 | Val Acc: 0.9746 | Total Loss: 0.0469
# Epoch 41/50 | Val Acc: 0.9739 | Total Loss: 0.0447
# Epoch 42/50 | Val Acc: 0.9731 | Total Loss: 0.0446
# Epoch 43/50 | Val Acc: 0.9746 | Total Loss: 0.0423
# Epoch 44/50 | Val Acc: 0.9731 | Total Loss: 0.0405
# Epoch 45/50 | Val Acc: 0.9746 | Total Loss: 0.0439
# Epoch 46/50 | Val Acc: 0.9724 | Total Loss: 0.0447
# Epoch 47/50 | Val Acc: 0.9753 | Total Loss: 0.0398
# Epoch 48/50 | Val Acc: 0.9746 | Total Loss: 0.0422
# Epoch 49/50 | Val Acc: 0.9746 | Total Loss: 0.0405
# Epoch 50/50 | Val Acc: 0.9746 | Total Loss: 0.0411
#
# ================================================================================
# Results: Transformer
# ================================================================================
# Acc: 0.9414 | F1: 0.9403 | Prec: 0.9417 | Rec: 0.9412
# Params: 0.1011M | FLOPs: 17.1873M | Inf: 0.7267ms
# ================================================================================
# ################################################################################
# # NeuralCDE
# ################################################################################
# Epoch 1/50 | Val Acc: 0.0876 | Total Loss: 21.6482
# Epoch 2/50 | Val Acc: 0.3781 | Total Loss: 11.3413
# Epoch 3/50 | Val Acc: 0.5703 | Total Loss: 4.3786
# Epoch 4/50 | Val Acc: 0.5979 | Total Loss: 1.6245
# Epoch 5/50 | Val Acc: 0.6106 | Total Loss: 0.9134
# Epoch 6/50 | Val Acc: 0.6438 | Total Loss: 0.9820
# Epoch 7/50 | Val Acc: 0.6968 | Total Loss: 0.7376
# Epoch 8/50 | Val Acc: 0.7074 | Total Loss: 0.7082
# Epoch 9/50 | Val Acc: 0.7025 | Total Loss: 0.6180
# Epoch 10/50 | Val Acc: 0.6686 | Total Loss: 0.6202
# Epoch 11/50 | Val Acc: 0.7216 | Total Loss: 0.6593
# Epoch 12/50 | Val Acc: 0.7286 | Total Loss: 0.5975
# Epoch 13/50 | Val Acc: 0.7420 | Total Loss: 0.5728
# Epoch 14/50 | Val Acc: 0.7364 | Total Loss: 0.5677
# Epoch 15/50 | Val Acc: 0.7336 | Total Loss: 0.5535
# Epoch 16/50 | Val Acc: 0.7569 | Total Loss: 0.6011
# Epoch 17/50 | Val Acc: 0.7053 | Total Loss: 0.5393
# Epoch 18/50 | Val Acc: 0.7307 | Total Loss: 0.5775
# Epoch 19/50 | Val Acc: 0.7710 | Total Loss: 0.5842
# Epoch 20/50 | Val Acc: 0.7576 | Total Loss: 0.5272
# Epoch 21/50 | Val Acc: 0.7583 | Total Loss: 0.5284
# Epoch 22/50 | Val Acc: 0.7498 | Total Loss: 0.5208
# Epoch 23/50 | Val Acc: 0.7541 | Total Loss: 0.5216
# Epoch 24/50 | Val Acc: 0.7922 | Total Loss: 0.5263
# Epoch 25/50 | Val Acc: 0.7640 | Total Loss: 0.5160
# Epoch 26/50 | Val Acc: 0.7647 | Total Loss: 0.4922
# Epoch 27/50 | Val Acc: 0.7887 | Total Loss: 0.4728
# Epoch 28/50 | Val Acc: 0.7604 | Total Loss: 0.4782
# Epoch 29/50 | Val Acc: 0.7498 | Total Loss: 0.4851
# Epoch 30/50 | Val Acc: 0.7654 | Total Loss: 0.4845
# Epoch 31/50 | Val Acc: 0.7823 | Total Loss: 0.4898
# Epoch 32/50 | Val Acc: 0.7484 | Total Loss: 0.4388
# Epoch 33/50 | Val Acc: 0.7795 | Total Loss: 0.4767
# Epoch 34/50 | Val Acc: 0.7802 | Total Loss: 0.4359
# Epoch 35/50 | Val Acc: 0.7809 | Total Loss: 0.4273
# Epoch 36/50 | Val Acc: 0.8021 | Total Loss: 0.4420
# Epoch 37/50 | Val Acc: 0.7859 | Total Loss: 0.4240
# Epoch 38/50 | Val Acc: 0.8000 | Total Loss: 0.4115
# Epoch 39/50 | Val Acc: 0.7943 | Total Loss: 0.4112
# Epoch 40/50 | Val Acc: 0.7936 | Total Loss: 0.4198
# Epoch 41/50 | Val Acc: 0.7951 | Total Loss: 0.4205
# Epoch 42/50 | Val Acc: 0.7951 | Total Loss: 0.4224
# Epoch 43/50 | Val Acc: 0.8021 | Total Loss: 0.3939
# Epoch 44/50 | Val Acc: 0.7986 | Total Loss: 0.4108
# Epoch 45/50 | Val Acc: 0.7986 | Total Loss: 0.3818
# Epoch 46/50 | Val Acc: 0.7972 | Total Loss: 0.3940
# Epoch 47/50 | Val Acc: 0.7979 | Total Loss: 0.4100
# Epoch 48/50 | Val Acc: 0.7979 | Total Loss: 0.3842
# Epoch 49/50 | Val Acc: 0.7979 | Total Loss: 0.3988
# Epoch 50/50 | Val Acc: 0.7965 | Total Loss: 0.3954
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLeakyReLU ptflops can affect your code!
#
# ================================================================================
# Results: NeuralCDE
# ================================================================================
# Acc: 0.7759 | F1: 0.7559 | Prec: 0.7612 | Rec: 0.7554
# Params: 0.1505M | FLOPs: 25.3767M | Inf: 52.7435ms
# ================================================================================
# ################################################################################
# # NeuralODE
# ################################################################################
# Epoch 1/50 | Val Acc: 0.3548 | Total Loss: 12.1835
# Epoch 2/50 | Val Acc: 0.5251 | Total Loss: 6.6959
# Epoch 3/50 | Val Acc: 0.6587 | Total Loss: 2.2080
# Epoch 4/50 | Val Acc: 0.6686 | Total Loss: 0.9490
# Epoch 5/50 | Val Acc: 0.6883 | Total Loss: 0.7489
# Epoch 6/50 | Val Acc: 0.7350 | Total Loss: 0.6900
# Epoch 7/50 | Val Acc: 0.7300 | Total Loss: 0.6274
# Epoch 8/50 | Val Acc: 0.7039 | Total Loss: 0.6046
# Epoch 9/50 | Val Acc: 0.7505 | Total Loss: 0.5833
# Epoch 10/50 | Val Acc: 0.7470 | Total Loss: 0.5456
# Epoch 11/50 | Val Acc: 0.7300 | Total Loss: 0.5614
# Epoch 12/50 | Val Acc: 0.7286 | Total Loss: 0.5438
# Epoch 13/50 | Val Acc: 0.7456 | Total Loss: 0.5370
# Epoch 14/50 | Val Acc: 0.7505 | Total Loss: 0.5340
# Epoch 15/50 | Val Acc: 0.7731 | Total Loss: 0.5475
# Epoch 16/50 | Val Acc: 0.7442 | Total Loss: 0.5115
# Epoch 17/50 | Val Acc: 0.7512 | Total Loss: 0.5531
# Epoch 18/50 | Val Acc: 0.7272 | Total Loss: 0.5285
# Epoch 19/50 | Val Acc: 0.7569 | Total Loss: 0.5814
# Epoch 20/50 | Val Acc: 0.7583 | Total Loss: 0.4929
# Epoch 21/50 | Val Acc: 0.7625 | Total Loss: 0.4902
# Epoch 22/50 | Val Acc: 0.7837 | Total Loss: 0.4550
# Epoch 23/50 | Val Acc: 0.7527 | Total Loss: 0.4655
# Epoch 24/50 | Val Acc: 0.7845 | Total Loss: 0.4674
# Epoch 25/50 | Val Acc: 0.7823 | Total Loss: 0.4416
# Epoch 26/50 | Val Acc: 0.7823 | Total Loss: 0.4520
# Epoch 27/50 | Val Acc: 0.7689 | Total Loss: 0.4400
# Epoch 28/50 | Val Acc: 0.7731 | Total Loss: 0.4414
# Epoch 29/50 | Val Acc: 0.7830 | Total Loss: 0.4488
# Epoch 30/50 | Val Acc: 0.7576 | Total Loss: 0.4279
# Epoch 31/50 | Val Acc: 0.7922 | Total Loss: 0.4405
# Epoch 32/50 | Val Acc: 0.7929 | Total Loss: 0.3993
# Epoch 33/50 | Val Acc: 0.7951 | Total Loss: 0.4025
# Epoch 34/50 | Val Acc: 0.7901 | Total Loss: 0.3905
# Epoch 35/50 | Val Acc: 0.7943 | Total Loss: 0.3916
# Epoch 36/50 | Val Acc: 0.7887 | Total Loss: 0.4030
# Epoch 37/50 | Val Acc: 0.7908 | Total Loss: 0.3784
# Epoch 38/50 | Val Acc: 0.8134 | Total Loss: 0.3625
# Epoch 39/50 | Val Acc: 0.7958 | Total Loss: 0.3883
# Epoch 40/50 | Val Acc: 0.7943 | Total Loss: 0.3675
# Epoch 41/50 | Val Acc: 0.7873 | Total Loss: 0.3756
# Epoch 42/50 | Val Acc: 0.7894 | Total Loss: 0.3542
# Epoch 43/50 | Val Acc: 0.7951 | Total Loss: 0.3608
# Epoch 44/50 | Val Acc: 0.7951 | Total Loss: 0.3521
# Epoch 45/50 | Val Acc: 0.7894 | Total Loss: 0.3557
# Epoch 46/50 | Val Acc: 0.7908 | Total Loss: 0.3523
# Epoch 47/50 | Val Acc: 0.7915 | Total Loss: 0.3399
# Epoch 48/50 | Val Acc: 0.7929 | Total Loss: 0.3521
# Epoch 49/50 | Val Acc: 0.7929 | Total Loss: 0.3547
# Epoch 50/50 | Val Acc: 0.7922 | Total Loss: 0.3445
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
# Warning: variables __flops__ or __params__ are already defined for the moduleLeakyReLU ptflops can affect your code!
#
# ================================================================================
# Results: NeuralODE
# ================================================================================
# Acc: 0.7898 | F1: 0.7689 | Prec: 0.7702 | Rec: 0.7683
# Params: 0.1004M | FLOPs: 25.4092M | Inf: 56.5339ms
# ================================================================================
#      Noise CNN_Acc  CNN_F1 Transformer_Acc Transformer_F1 NeuralCDE_Acc  \
# 0       0%  0.9436  0.9484          0.9414         0.9403        0.7759
# 1       5%  0.9365  0.9400          0.9380         0.9363        0.7353
# 2      10%  0.9051  0.9028          0.9089         0.9031        0.7080
# 3      15%  0.7988  0.7596          0.8717         0.8603        0.6984
# 4      20%  0.7502  0.6922          0.8435         0.8279        0.6885
# 5      25%  0.7269  0.6602          0.8410         0.8250        0.6866
# 6      30%  0.7263  0.6614          0.8450         0.8296        0.6875
# 7  Avg_Ret  0.8556       -          0.9291              -        0.9031
#
#   NeuralCDE_F1 NeuralODE_Acc NeuralODE_F1
# 0       0.7559        0.7898       0.7689
# 1       0.7069        0.7545       0.7263
# 2       0.6735        0.7343       0.7018
# 3       0.6605        0.7269       0.6923
# 4       0.6470        0.7170       0.6796
# 5       0.6425        0.7142       0.6752
# 6       0.6429        0.7099       0.6685
# 7            -        0.9194            -
#      Noise CNN_Acc  CNN_F1 Transformer_Acc Transformer_F1 NeuralCDE_Acc  \
# 0       0%  0.9436  0.9484          0.9414         0.9403        0.7759
# 1       5%  0.9473  0.9513          0.8766         0.8813        0.7257
# 2      10%  0.8872  0.8909          0.8841         0.8887        0.6860
# 3      15%  0.7833  0.7629          0.8782         0.8828        0.6407
# 4      20%  0.7061  0.6597          0.8410         0.8442        0.6048
# 5      25%  0.6224  0.5441          0.7647         0.7719        0.5620
# 6      30%  0.5053  0.4186          0.6438         0.6604        0.5254
# 7  Avg_Ret  0.7863       -          0.8654              -        0.8044
#
#   NeuralCDE_F1 NeuralODE_Acc NeuralODE_F1
# 0       0.7559        0.7898       0.7689
# 1       0.7009        0.7412       0.7169
# 2       0.6592        0.7033       0.6785
# 3       0.6124        0.6615       0.6358
# 4       0.5738        0.6252       0.5983
# 5       0.5284        0.5809       0.5516
# 6       0.4900        0.5409       0.5088
# 7            -        0.8131            -
#      Noise CNN_Acc  CNN_F1 Transformer_Acc Transformer_F1 NeuralCDE_Acc  \
# 0       0%  0.9436  0.9484          0.9414         0.9403        0.7759
# 1       5%  0.9430  0.9476          0.9442         0.9437        0.7728
# 2      10%  0.9402  0.9445          0.9417         0.9406        0.7647
# 3      15%  0.9365  0.9397          0.9349         0.9330        0.7588
# 4      20%  0.9321  0.9348          0.9306         0.9278        0.7405
# 5      25%  0.9256  0.9274          0.9219         0.9176        0.7343
# 6      30%  0.9169  0.9178          0.9079         0.9018        0.7337
# 7  Avg_Ret  0.9881       -          0.9881              -        0.9677
#
#   NeuralCDE_F1 NeuralODE_Acc NeuralODE_F1
# 0       0.7559        0.7898       0.7689
# 1       0.7522        0.7908       0.7700
# 2       0.7422        0.7818       0.7588
# 3       0.7356        0.7756       0.7516
# 4       0.7140        0.7607       0.7339
# 5       0.7058        0.7613       0.7348
# 6       0.7051        0.7595       0.7323
# 7            -        0.9770            -
#            Exp     Acc      F1    Prec     Rec  Par(M) FLOPs(M)  Inf(ms)
# 0          CNN  0.9436  0.9484  0.9492  0.9482  0.2097  26.7648   0.2428
# 1  Transformer  0.9414  0.9403  0.9417  0.9412  0.1011  17.1873   0.7267
# 2    NeuralCDE  0.7759  0.7559  0.7612  0.7554  0.1505  25.3767  52.7435
# 3    NeuralODE  0.7898  0.7689  0.7702  0.7683  0.1004  25.4092  56.5339
