# %%
# !pip install thop ptflops
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238

# %%
import os
import random
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from thop import profile
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import re
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from glob import glob
import pickle

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def compute_mean_std(X):
    X = X.astype(np.float32)
    mean = X.mean(axis=(0, 2), keepdims=True)
    std  = X.std(axis=(0, 2), keepdims=True) + 1e-8
    return mean, std

def aug_jitter_scale(x_batch, jitter_sigma=0.03, scale_max=0.1):
    jitter = torch.randn_like(x_batch) * jitter_sigma
    x_batch = x_batch + jitter
    scale = 1.0 + (torch.rand(x_batch.shape[0], 1, 1, device=x_batch.device) - 0.5) * 2 * scale_max
    x_batch = x_batch * scale
    return x_batch

def aug_sensor_failure(x_batch):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    fail_channel = random.randint(0, C - 1)
    x_aug[:, fail_channel, :] = 0.0
    return x_aug

def aug_missing_segment(x_batch, missing_seg_len_range=(0.1, 0.25)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    seg_len_min = int(L * missing_seg_len_range[0])
    seg_len_max = int(L * missing_seg_len_range[1])
    if seg_len_min >= seg_len_max:
         seg_len_max = seg_len_min + 1
    seg_len = random.randint(seg_len_min, seg_len_max)
    start = random.randint(0, L - seg_len)
    x_aug[:, :, start:start+seg_len] = 0.0
    return x_aug

def aug_outlier_spike(x_batch, outlier_magnitude=10, num_outliers_range=(1, 5)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    num_outliers = random.randint(num_outliers_range[0], num_outliers_range[1])
    for _ in range(num_outliers):
        b_idx = random.randint(0, B - 1)
        c_idx = random.randint(0, C - 1)
        l_idx = random.randint(0, L - 1)
        magnitude = (torch.randn(1) * outlier_magnitude).item()
        x_aug[b_idx, c_idx, l_idx] = x_aug[b_idx, c_idx, l_idx] + magnitude
    return x_aug

def apply_test_noise(x_batch, noise_type, noise_level):
    x_noisy = x_batch.clone()
    B, C, L = x_batch.shape

    if noise_type == 'jitter':
        noise = torch.randn_like(x_batch) * noise_level
        x_noisy = x_batch + noise

    elif noise_type == 'time_shift':
        max_shift = int(L * noise_level)
        if max_shift == 0 and noise_level > 0:
             max_shift = 1
        x_shifted = torch.zeros_like(x_batch)
        for i in range(B):
            shift = random.randint(-max_shift, max_shift)
            if shift == 0:
                x_shifted[i] = x_batch[i]
            elif shift > 0:
                x_shifted[i, :, shift:] = x_batch[i, :, :-shift]
            else:
                x_shifted[i, :, :shift] = x_batch[i, :, -shift:]
        x_noisy = x_shifted

    elif noise_type == 'sensor_failure':
        n_channels = int(np.ceil(C * noise_level))
        if n_channels == 0: n_channels = 1
        fail_channels = np.random.choice(C, n_channels, replace=False)
        x_noisy[:, fail_channels, :] = 0.0

    elif noise_type == 'outlier_spike':
        num_spikes = max(1, int(noise_level * 100))
        for i in range(B):
            for _ in range(num_spikes):
                c_idx = random.randint(0, C - 1)
                l_idx = random.randint(0, L - 1)
                magnitude = (torch.randn(1) * 5).item()
                x_noisy[i, c_idx, l_idx] += magnitude

    elif noise_type == 'missing_segment':
        seg_len = max(1, int(L * noise_level))
        start = random.randint(0, L - seg_len)
        x_noisy[:, :, start:start+seg_len] = 0.0

    return x_noisy


def compute_encoder_stats(encoder, input_shape=(1,9,128)):
    device = next(encoder.parameters()).device
    macs, params = profile(encoder, inputs=(torch.randn(*input_shape).to(device),), verbose=False)
    return params/1e6, macs/1e6

def measure_meta_inference_time(model, n_way, sz=(1,9,128), dev='cuda', runs=100, warm=10):
    model.eval()
    x_q = torch.randn(sz, device=dev)
    x_s = torch.randn((n_way*5,) + sz[1:], device=dev)
    y_s = torch.tensor(np.repeat(range(n_way), 5), device=dev)

    with torch.no_grad():
        for _ in range(warm):
            _, _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    t0 = time.time()
    with torch.no_grad():
        for _ in range(runs):
            _, _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    return (time.time()-t0)/runs*1000

def compute_supervised_stats(model: nn.Module, input_shape=(9, 128)):
    device = next(model.parameters()).device
    dummy_input = torch.randn(1, *input_shape).to(device)
    model.eval()

    if not hasattr(model, 'classifier') or not hasattr(model, 'extract_features'):
        raise ValueError("Model must have 'classifier' attribute and 'extract_features' method.")

    classifier_original = model.classifier
    model.classifier = nn.Identity()
    macs_backbone, params_backbone = profile(model, inputs=(dummy_input,), verbose=False)
    model.classifier = classifier_original

    with torch.no_grad():
        features = model.extract_features(dummy_input)
        if isinstance(features, tuple):
            features = features[0]

    macs_cls, params_cls = profile(model.classifier, inputs=(features,), verbose=False)

    total_macs_m = (macs_backbone + macs_cls) / 1e6
    total_params_m = (params_backbone + params_cls) / 1e6
    return total_params_m, total_macs_m

def measure_supervised_inference_time(model: nn.Module, input_size=(1, 9, 128), device='cuda', n_runs=100, warmup=10):
    model.eval()
    inputs = torch.randn(input_size).to(device)

    with torch.inference_mode():
        for _ in range(warmup):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    start = time.time()
    with torch.inference_mode():
        for _ in range(n_runs):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    end = time.time()
    return (end - start) / n_runs * 1000

def plot_confusion_matrix(cm, labels):
    cmn = cm.astype('float')/cm.sum(axis=1)[:,None]
    df = pd.DataFrame(cmn, index=labels, columns=labels)
    plt.figure(figsize=(8,7))
    sns.heatmap(df, annot=True, fmt='.2f', cmap='Blues', cbar=True)
    plt.xlabel('Predicted', fontsize=12)
    plt.ylabel('True', fontsize=12)
    plt.title('Confusion Matrix (Normalized)', fontsize=14)
    plt.tight_layout()
    plt.show()

def plot_learning_curves(train_losses, train_accs, val_accs, title_suffix=""):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    ax1.plot(train_losses, linewidth=2, label='Train Loss')
    ax1.set_xlabel('Episode', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.set_title(f'Training Loss {title_suffix}', fontsize=14)
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(train_accs, linewidth=2, color='orange', label='Train Acc')
    ax2.plot(val_accs, linewidth=2, color='green', label='Val Acc')
    ax2.set_xlabel('Episode', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.set_title(f'Training & Validation Accuracy {title_suffix}', fontsize=14)
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    plt.tight_layout()

def plot_kshot_comparison(shot_results):
    plt.figure(figsize=(10, 6))
    plt.plot([r['K'] for r in shot_results], [r['Accuracy'] for r in shot_results],
             marker='o', linewidth=2, markersize=8, label='Accuracy')
    plt.plot([r['K'] for r in shot_results], [r['F1'] for r in shot_results],
             marker='s', linewidth=2, markersize=8, label='F1-Score')
    plt.xlabel('K-Shot', fontsize=12)
    plt.ylabel('Score', fontsize=12)
    plt.title('Meta-Learning Performance vs K-Shot', fontsize=14)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def plot_user_performance(per_user_df):
    plt.figure(figsize=(12, 6))
    x = range(len(per_user_df))
    plt.bar(x, per_user_df['Accuracy'], alpha=0.7, label='Accuracy')
    plt.axhline(y=per_user_df['Accuracy'].mean(), color='r', linestyle='--',
                label=f'Mean: {per_user_df["Accuracy"].mean():.3f}')
    plt.xlabel('Test User', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Per-User 5-Shot Accuracy', fontsize=14)
    plt.xticks(x, per_user_df['User'])
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    plt.tight_layout()
    plt.show()

class HARDataset(Dataset):
    def __init__(self, X, y, norm=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if norm:
            self.mean = self.X.mean(axis=(0,2), keepdims=True)
            self.std = self.X.std(axis=(0,2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean)/self.std
        else:
            self.mean, self.std = None, None

    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean)/self.std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        return torch.from_numpy(self.X[i]), int(self.y[i])

def load_mhealth_data(dataset_dir="MHEALTH"):
    subject_files = sorted([
        os.path.join(dataset_dir, f)
        for f in os.listdir(dataset_dir)
        if f.startswith("mHealth_subject") and f.endswith(".log")
    ])
    if not subject_files:
        return None, None, None, None

    all_windows = []
    all_labels = []
    all_subjects = []
    window_size = 50
    step = 25

    for file_path in subject_files:
        subject_id_match = re.search(r'subject(\d+)', os.path.basename(file_path))
        if not subject_id_match:
            continue
        subject_id = int(subject_id_match.group(1))

        df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
        df = df.ffill().bfill()
        if df.shape[1] < 24:
            continue

        labels = df.iloc[:, 23].values.astype(int)
        imu_cols = [0,1,2] + list(range(5, 23))
        features = df.iloc[:, imu_cols].values

        valid_indices = np.where(labels != 0)[0]
        if len(valid_indices) == 0:
            continue

        features = features[valid_indices, :]
        labels = labels[valid_indices]

        if len(features) < window_size:
            continue

        start = 0
        while start + window_size <= len(features):
            window_data = features[start : start + window_size, :]
            window_labels_raw = labels[start : start + window_size]
            most_common_label = Counter(window_labels_raw).most_common(1)[0][0]

            all_windows.append(window_data)
            all_labels.append(most_common_label)
            all_subjects.append(subject_id)

            start += step

    if not all_windows:
        return None, None, None, None

    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(all_labels)
    X_windowed = np.array(all_windows, dtype=np.float32)

    X_windowed = np.transpose(X_windowed, (0, 2, 1))

    mhealth_activity_mapping = {
        1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down', 4: 'Walking',
        5: 'Climbing stairs', 6: 'Waist bends forward', 7: 'Frontal elevation of arms',
        8: 'Knees bending', 9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
    }
    activity_labels = []
    class_names = list(label_encoder.classes_)

    for original_label in class_names:
        if original_label in mhealth_activity_mapping:
            activity_labels.append(mhealth_activity_mapping[original_label])
        else:
            activity_labels.append(f"Unknown_Activity_{original_label}")

    return X_windowed, y_encoded, np.array(all_subjects, dtype=int), activity_labels

class CompactEncoder(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128):
        super().__init__()
        self.stage1 = self._make_stage(in_channels, 32, stride=2)
        self.stage2 = self._make_stage(32, 64, stride=2)
        self.stage3 = self._make_stage(64, 128, stride=2)
        self.stage4 = self._make_stage(128, embed_dim, stride=2)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def _make_stage(self, in_ch, out_ch, stride=1):
        return nn.Sequential(
            nn.Conv1d(in_ch, out_ch, kernel_size=5, stride=stride, padding=2),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU()
        )

    def forward(self, x):
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)
        x = self.pool(x).flatten(1)
        return x

class UncertaintyEncoder(nn.Module):
    def __init__(self, base_cnn, feature_dim):
        super().__init__()
        self.base = base_cnn
        self.fc_mu = nn.Linear(feature_dim, feature_dim)
        self.fc_logvar = nn.Linear(feature_dim, feature_dim)

    def forward(self, x):
        feat = self.base(x)
        mu = self.fc_mu(feat)
        logvar = self.fc_logvar(feat)
        return mu, logvar

class PrototypeNetwork(nn.Module):
    def __init__(self, encoder, temperature=1.0):
        super().__init__()
        self.encoder = encoder
        self.temperature = temperature

        feature_dim = encoder.fc_mu.in_features

        self.attention = nn.Sequential(
            nn.Linear(feature_dim, feature_dim // 2),
            nn.ReLU(),
            nn.Linear(feature_dim // 2, 1)
        )
        self.adapter = nn.Sequential(
            nn.Linear(feature_dim * 2, feature_dim),
            nn.ReLU(),
            nn.Linear(feature_dim, feature_dim)
        )

    def compute_prototypes(self, support_mu, support_logvar, support_y, n_way):
        embed_dim = support_mu.size(1)
        prototypes_mu = []
        prototypes_sigma = []

        for c in range(n_way):
            mask = (support_y == c)
            if mask.sum() > 0:
                mu_c = support_mu[mask]
                logvar_c = support_logvar[mask]

                attn_w = F.softmax(self.attention(mu_c), dim=0)

                sigma_c_sq = torch.exp(logvar_c)
                var_w = 1.0 / (sigma_c_sq + 1e-6)

                weight = attn_w * var_w

                weighted_mu = (weight * mu_c).sum(0) / weight.sum(0)

                weighted_sigma_sq = 1.0 / weight.sum(0)
                weighted_sigma = torch.sqrt(weighted_sigma_sq)

                prototypes_mu.append(weighted_mu)
                prototypes_sigma.append(weighted_sigma)
            else:
                prototypes_mu.append(torch.zeros(embed_dim, device=support_mu.device))
                prototypes_sigma.append(torch.ones(embed_dim, device=support_mu.device))

        return torch.stack(prototypes_mu), torch.stack(prototypes_sigma)

    def forward(self, query_x, support_x, support_y, n_way):
        support_mu, support_logvar = self.encoder(support_x)
        query_mu, query_logvar = self.encoder(query_x)

        prototypes_mu, prototypes_sigma = self.compute_prototypes(support_mu, support_logvar, support_y, n_way)

        query_sigma = torch.exp(0.5 * query_logvar)

        n_query = query_mu.size(0)

        query_mu_expanded = query_mu.unsqueeze(1).expand(-1, n_way, -1)
        query_sigma_expanded = query_sigma.unsqueeze(1).expand(-1, n_way, -1)

        proto_mu_expanded = prototypes_mu.unsqueeze(0).expand(n_query, -1, -1)
        proto_sigma_expanded = prototypes_sigma.unsqueeze(0).expand(n_query, -1, -1)

        cat_input = torch.cat([query_mu_expanded, proto_mu_expanded], dim=-1)
        delta = self.adapter(cat_input)
        adapted_mu = proto_mu_expanded + delta

        mu_diff_sq = (query_mu_expanded - adapted_mu)**2
        sigma_sum_sq = query_sigma_expanded**2 + proto_sigma_expanded**2 + 1e-6
        dist = (mu_diff_sq / sigma_sum_sq).sum(dim=-1)

        logits = -dist / self.temperature

        all_mu = torch.cat([support_mu, query_mu], dim=0)
        all_logvar = torch.cat([support_logvar, query_logvar], dim=0)
        kl_div = -0.5 * torch.sum(1 + all_logvar - all_mu.pow(2) - all_logvar.exp(), dim=1).mean()

        return logits, kl_div

class SupervisedBaseline(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128, num_classes=6):
        super().__init__()
        self.encoder = CompactEncoder(in_channels=in_channels, embed_dim=embed_dim)
        self.classifier = nn.Linear(embed_dim, num_classes)

    def extract_features(self, x):
        return self.encoder(x)

    def forward(self, x):
        features = self.extract_features(x)
        return self.classifier(features)

def create_episodes(users_data, n_way=6, k_shot=5, q_query=15, total_classes=6):
    if not users_data:
        return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

    for _ in range(50):
        user = random.choice(users_data)
        data = user['data']
        labels = user['labels']
        unique_cls = np.unique(labels)

        if len(unique_cls) < n_way:
            continue

        chosen_classes = np.random.choice(unique_cls, n_way, replace=False)
        support_x, support_y, query_x, query_y = [], [], [], []

        valid_episode = True
        for new_c, original_c in enumerate(chosen_classes):
            idxs = np.where(labels == original_c)[0]
            if len(idxs) < k_shot + q_query:
                valid_episode = False
                break

            np.random.shuffle(idxs)
            s_idx = idxs[:k_shot]
            q_idx = idxs[k_shot:k_shot+q_query]

            support_x.extend([data[i] for i in s_idx])
            support_y.extend([new_c] * k_shot)
            query_x.extend([data[i] for i in q_idx])
            query_y.extend([new_c] * q_query)

        if valid_episode:
            if not support_x or not query_x:
                continue
            return (torch.stack(support_x), torch.tensor(support_y),
                    torch.stack(query_x), torch.tensor(query_y))

    return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

def meta_train(model, optimizer, train_users, val_users, n_way_range, k_shot=5, q_query=15,
               episodes=5000, log_every=100, val_every=200, kl_weight=0.001, total_classes=6):
    model.train()
    train_losses, train_accs, val_accs = [], [], []

    clean_cutoff = int(episodes * 0.30)
    jitter_cutoff = clean_cutoff + int(episodes * 0.175)
    sensor_cutoff = jitter_cutoff + int(episodes * 0.175)
    missing_cutoff = sensor_cutoff + int(episodes * 0.175)

    for ep in range(episodes):
        n_way = random.randint(n_way_range[0], n_way_range[1])

        support_x, support_y, query_x, query_y = create_episodes(train_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue

        if ep < clean_cutoff:
            support_x_aug = support_x
            query_x_aug = query_x
        elif ep < jitter_cutoff:
            support_x_aug = aug_jitter_scale(support_x)
            query_x_aug = aug_jitter_scale(query_x)
        elif ep < sensor_cutoff:
            support_x_aug = aug_sensor_failure(support_x)
            query_x_aug = aug_sensor_failure(query_x)
        elif ep < missing_cutoff:
            support_x_aug = aug_missing_segment(support_x)
            query_x_aug = aug_missing_segment(query_x)
        else:
            support_x_aug = aug_outlier_spike(support_x)
            query_x_aug = aug_outlier_spike(query_x)

        support_x_aug, support_y = support_x_aug.cuda(), support_y.cuda()
        query_x_aug, query_y = query_x_aug.cuda(), query_y.cuda()

        logits, kl_div = model(query_x_aug, support_x_aug, support_y, n_way)
        ce_loss = F.cross_entropy(logits, query_y)
        loss = ce_loss + kl_weight * kl_div

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (logits.argmax(1) == query_y).float().mean().item()
        train_losses.append(loss.item())
        train_accs.append(acc)

        if (ep + 1) % log_every == 0:
            print(f"Episode {ep+1:5d} | Loss: {loss.item():.4f} | Train Acc: {acc:.4f}", end="")
            if (ep + 1) % val_every == 0:
                val_acc = meta_validate(model, val_users, k_shot, n_way_range[1], trials=20, total_classes=total_classes)
                val_accs.append(val_acc)
                print(f" | Val Acc: {val_acc:.4f}")
            else:
                print()

    val_episodes = list(range(val_every - 1, episodes, val_every))
    if len(val_accs) == 0 and episodes > 0:
        val_accs = [0.0]
    val_accs_interpolated = np.interp(range(episodes), val_episodes, val_accs)

    return train_losses, train_accs, val_accs_interpolated

def meta_validate(model, val_users, k_shot=5, n_way=6, trials=20, total_classes=6):
    model.eval()
    correct, total = 0, 0
    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(val_users, n_way, k_shot, 15, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()
        with torch.no_grad():
            logits, _ = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1)
            correct += (preds == query_y).sum().item()
            total += len(query_y)
    model.train()
    return correct / total if total > 0 else 0.0

def meta_test(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        with torch.no_grad():
            logits, _ = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def meta_test_noisy(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, noise_type='jitter', noise_level=0.1, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        query_x_noisy = apply_test_noise(query_x, noise_type, noise_level)

        with torch.no_grad():
            logits, _ = model(query_x_noisy, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def train_supervised(model, train_loader, optimizer, criterion, epochs, device):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_correct = 0
        total_samples = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            logits = model(x_batch)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * x_batch.size(0)
            total_correct += (logits.argmax(1) == y_batch).sum().item()
            total_samples += x_batch.size(0)

        avg_loss = total_loss / total_samples
        avg_acc = total_correct / total_samples
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | Train Loss: {avg_loss:.4f} | Train Acc: {avg_acc:.4f}")

def test_supervised(model, test_loader, device, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            logits = model(x_batch)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm

def test_supervised_noisy(model, test_loader, device, noise_type, noise_level, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            x_batch_noisy = apply_test_noise(x_batch, noise_type, noise_level)
            logits = model(x_batch_noisy)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm

def prepare_users(X, y, sub, subs, mean, std):
    users = []
    for uid in subs:
        mask = (sub == uid)
        user_data = X[mask]
        user_labels = y[mask]
        if len(user_data) == 0:
            continue
        user_dataset = HARDataset(user_data, user_labels, norm=False)
        user_dataset.set_stats(mean, std)

        if len(user_dataset) > 0:
            users.append({
                'data': torch.stack([user_dataset[i][0] for i in range(len(user_dataset))]),
                'labels': user_labels,
                'id': uid
            })
    return users

if __name__ == '__main__':
    set_seed(42)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Device: {device}\n")

    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)

    root = "/content/drive/MyDrive/HAR_Dataset/MHEALTH"
    print("=" * 60)
    print("LOADING MHEALTH DATASET")
    print("=" * 60)
    X_raw, y_raw, sub_raw, labels = load_mhealth_data(root)

    if X_raw is None:
        print("Failed to load MHEALTH data. Check directory path and data.")
        exit()

    print(f"Data shape (N, C, L): {X_raw.shape}")
    print(f"Labels: {labels}")
    print(f"Total subjects: {len(np.unique(sub_raw))}")

    INPUT_CHANNELS = X_raw.shape[1]
    INPUT_LENGTH = X_raw.shape[2]
    TOTAL_CLASSES = len(labels)

    unique_subs = np.unique(sub_raw)
    train_subs = unique_subs[:7]
    val_subs = unique_subs[7:8]
    test_subs = unique_subs[8:]

    print(f"\nTrain subjects: {len(train_subs)} users (IDs: {train_subs})")
    print(f"Val subjects: {len(val_subs)} users (IDs: {val_subs})")
    print(f"Test subjects: {len(test_subs)} users (IDs: {test_subs})")

    train_mask = np.isin(sub_raw, train_subs)
    val_mask = np.isin(sub_raw, val_subs)
    test_mask = np.isin(sub_raw, test_subs)

    X_train, y_train, sub_train = X_raw[train_mask], y_raw[train_mask], sub_raw[train_mask]
    X_val, y_val, sub_val = X_raw[val_mask], y_raw[val_mask], sub_raw[val_mask]
    X_test, y_test, sub_test = X_raw[test_mask], y_raw[test_mask], sub_raw[test_mask]

    print(f"\nTrain samples: {len(X_train)}")
    print(f"Val samples: {len(X_val)}")
    print(f"Test samples: {len(X_test)}")

    mean, std = compute_mean_std(X_train)

    train_users = prepare_users(X_train, y_train, sub_train, train_subs, mean, std)
    val_users = prepare_users(X_val, y_val, sub_val, val_subs, mean, std)
    test_users = prepare_users(X_test, y_test, sub_test, test_subs, mean, std)

    train_dataset_sup = HARDataset(X_train, y_train, norm=False)
    train_dataset_sup.set_stats(mean, std)
    train_loader_sup = DataLoader(train_dataset_sup, batch_size=64, shuffle=True)

    test_dataset_sup = HARDataset(X_test, y_test, norm=False)
    test_dataset_sup.set_stats(mean, std)
    test_loader_sup = DataLoader(test_dataset_sup, batch_size=256, shuffle=False)

    final_results_list = []
    stats_results_list = []

    noise_conditions_to_test = [
        ('jitter', 0.1),
        ('jitter', 0.2),
        ('jitter', 0.3),
        ('time_shift', 0.1),
        ('time_shift', 0.2),
        ('time_shift', 0.3),
        ('sensor_failure', 0.1),
        ('sensor_failure', 0.2),
        ('sensor_failure', 0.3),
        ('outlier_spike', 0.1),
        ('outlier_spike', 0.2),
        ('outlier_spike', 0.3),
        ('missing_segment', 0.1),
        ('missing_segment', 0.2),
        ('missing_segment', 0.3)
    ]
    train_k_shots_list = [1, 3, 5, 10]

    print("\n" + "=" * 80)
    print("PART 1: SUPERVISED BASELINE (CompactEncoder + Classifier)")
    print("=" * 80)

    supervised_model = SupervisedBaseline(
        in_channels=INPUT_CHANNELS,
        embed_dim=128,
        num_classes=TOTAL_CLASSES
    ).to(device)

    optimizer_sup = torch.optim.Adam(supervised_model.parameters(), lr=0.001)
    criterion_sup = nn.CrossEntropyLoss()

    print("--- Training Supervised Baseline ---")
    train_supervised(supervised_model, train_loader_sup, optimizer_sup, criterion_sup, epochs=50, device=device)

    print("\n--- Calculating Supervised Model Stats ---")
    sup_params, sup_flops = compute_supervised_stats(supervised_model, input_shape=(INPUT_CHANNELS, INPUT_LENGTH))
    sup_inf_time = measure_supervised_inference_time(supervised_model, input_size=(1, INPUT_CHANNELS, INPUT_LENGTH), device=device)
    print(f"Supervised Stats | Params(M): {sup_params:.2f}, FLOPs(M): {sup_flops:.2f}, Inf. Time(ms): {sup_inf_time:.2f}")

    stats_results_list.append({
        'Model': 'Supervised',
        'K-Shot': 'N/A (Full)',
        'Param (M)': sup_params,
        'FLOPs (M)': sup_flops,
        'Inf. Time (ms)': sup_inf_time
    })

    print("\n--- Testing Supervised Baseline (Clean) ---")
    acc_s, f1_s, prec_s, rec_s, _ = test_supervised(supervised_model, test_loader_sup, device, num_classes=TOTAL_CLASSES)
    print(f"Supervised Clean | Acc: {acc_s:.4f}, F1: {f1_s:.4f}")
    final_results_list.append({
        'Model': 'Supervised',
        'K-Shot': 'N/A (Full)',
        'Noise': 'Clean',
        'Accuracy': acc_s,
        'F1-Score': f1_s,
        'Precision': prec_s,
        'Recall': rec_s
    })

    print("\n--- Testing Supervised Baseline (Robustness) ---")
    for n_type, n_level in noise_conditions_to_test:
        acc_n, f1_n, prec_n, rec_n, _ = test_supervised_noisy(
            supervised_model, test_loader_sup, device,
            noise_type=n_type, noise_level=n_level, num_classes=TOTAL_CLASSES
        )
        print(f"Supervised Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
        final_results_list.append({
            'Model': 'Supervised',
            'K-Shot': 'N/A (Full)',
            'Noise': f"{n_type}_{n_level}",
            'Accuracy': acc_n,
            'F1-Score': f1_n,
            'Precision': prec_n,
            'Recall': rec_n
        })

    del supervised_model, optimizer_sup, criterion_sup
    torch.cuda.empty_cache()

    print("\n" + "=" * 80)
    print("PART 2: META-LEARNING (Per K-Shot Training)")
    print("=" * 80)

    N_WAY_TRAIN_MIN = max(3, TOTAL_CLASSES - 6)
    N_WAY_TRAIN_MAX = TOTAL_CLASSES
    Q_QUERY_TRAIN = 15
    EPISODES = 10000

    for k_train in train_k_shots_list:
        print("\n" + "=" * 70)
        print(f"STARTING META-TRAINING FOR K-SHOT = {k_train}")
        print("=" * 70)

        K_SHOT_TRAIN = k_train

        base_encoder = CompactEncoder(in_channels=INPUT_CHANNELS, embed_dim=128).to(device)
        encoder = UncertaintyEncoder(base_encoder, feature_dim=128).to(device)
        meta_model = PrototypeNetwork(encoder, temperature=1.0).to(device)
        optimizer_meta = torch.optim.Adam(meta_model.parameters(), lr=0.001)

        print(f"--- Calculating Meta Model Stats (K={k_train}) ---")
        meta_enc_params, meta_enc_flops = compute_encoder_stats(encoder, input_shape=(1, INPUT_CHANNELS, INPUT_LENGTH))
        meta_e2e_inf_time = measure_meta_inference_time(meta_model, n_way=TOTAL_CLASSES, sz=(1, INPUT_CHANNELS, INPUT_LENGTH), dev=device)
        print(f"Meta-{k_train} Stats | Encoder Params(M): {meta_enc_params:.2f}, Encoder FLOPs(M): {meta_enc_flops:.2f}, E2E Inf. Time(ms): {meta_e2e_inf_time:.2f}")

        stats_results_list.append({
            'Model': 'Meta-Learning',
            'K-Shot': k_train,
            'Param (M)': meta_enc_params,
            'FLOPs (M)': meta_enc_flops,
            'Inf. Time (ms)': meta_e2e_inf_time
        })

        print(f"--- Meta-Training (K={K_SHOT_TRAIN}, {EPISODES} Episodes, Robust Augmentation) ---")
        train_losses, train_accs, val_accs = meta_train(
            meta_model, optimizer_meta, train_users, val_users,
            n_way_range=(N_WAY_TRAIN_MIN, N_WAY_TRAIN_MAX),
            k_shot=K_SHOT_TRAIN,
            q_query=Q_QUERY_TRAIN,
            episodes=EPISODES,
            log_every=1000,
            val_every=1000,
            kl_weight=0.0001,
            total_classes=TOTAL_CLASSES
        )

        print(f"\n--- Plotting Meta-Training Learning Curves (K={k_train}) ---")
        plot_learning_curves(train_losses, train_accs, val_accs, title_suffix=f"(K-Train = {k_train})")
        plt.show()

        print(f"\n--- Testing Meta-Learning Model (K={k_train}) ---")

        print(f"Meta-{k_train}-Shot (Clean) | Testing...")
        acc_m, f1_m, prec_m, rec_m, _ = meta_test(
            meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES,
            q_query=15, trials=200, total_classes=TOTAL_CLASSES
        )
        print(f"Meta-{k_train}-Shot (Clean) | Acc: {acc_m:.4f}, F1: {f1_m:.4f}")
        final_results_list.append({
            'Model': 'Meta-Learning',
            'K-Shot': k_train,
            'Noise': 'Clean',
            'Accuracy': acc_m,
            'F1-Score': f1_m,
            'Precision': prec_m,
            'Recall': rec_m
        })

        for n_type, n_level in noise_conditions_to_test:
            acc_n, f1_n, prec_n, rec_n, _ = meta_test_noisy(
                meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES, q_query=15,
                trials=100, noise_type=n_type, noise_level=n_level,
                total_classes=TOTAL_CLASSES
            )
            print(f"Meta-{k_train}-Shot Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
            final_results_list.append({
                'Model': 'Meta-Learning',
                'K-Shot': k_train,
                'Noise': f"{n_type}_{n_level}",
                'Accuracy': acc_n,
                'F1-Score': f1_n,
                'Precision': prec_n,
                'Recall': rec_n
            })

        del base_encoder, encoder, meta_model, optimizer_meta
        torch.cuda.empty_cache()


    print("\n" + "=" * 80)
    print("===== FINAL COMPARISON RESULTS =====")
    print("=" * 80)

    final_df = pd.DataFrame(final_results_list)
    display(final_df)

    print("\n" + "=" * 80)
    print("===== PIVOT TABLE: ACCURACY =====")
    print("=" * 80)
    pivot_acc = final_df.pivot_table(
        index='Noise',
        columns=['Model', 'K-Shot'],
        values='Accuracy'
    )

    cols_order = [
        ('Supervised', 'N/A (Full)'),
        ('Meta-Learning', 1),
        ('Meta-Learning', 3),
        ('Meta-Learning', 5),
        ('Meta-Learning', 10)
    ]

    cols_present = [c for c in cols_order if c in pivot_acc.columns]
    pivot_acc = pivot_acc[cols_present]

    display(pivot_acc.style.format("{:.4f}").highlight_max(axis=1, color='lightgreen'))


    print("\n" + "=" * 80)
    print("===== PIVOT TABLE: F1-SCORE =====")
    print("=" * 80)
    pivot_f1 = final_df.pivot_table(
        index='Noise',
        columns=['Model', 'K-Shot'],
        values='F1-Score'
    )

    cols_present_f1 = [c for c in cols_order if c in pivot_f1.columns]
    pivot_f1 = pivot_f1[cols_present_f1]

    display(pivot_f1.style.format("{:.4f}").highlight_max(axis=1, color='lightgreen'))

    print("\n" + "=" * 80)
    print("===== MODEL STATISTICS (Params, FLOPs, Latency) =====")
    print("=" * 80)
    stats_df = pd.DataFrame(stats_results_list)
    display(stats_df.set_index(['Model', 'K-Shot']).style.format("{:.2f}"))
# Out:
# <>:287: SyntaxWarning: invalid escape sequence '\s'
# <>:287: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1876123450.py:287: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
# Device: cuda
#
# ============================================================
# LOADING MHEALTH DATASET
# ============================================================
# Data shape (N, C, L): (13714, 21, 50)
# Labels: ['Standing still', 'Sitting and relaxing', 'Lying down', 'Walking', 'Climbing stairs', 'Waist bends forward', 'Frontal elevation of arms', 'Knees bending', 'Cycling', 'Jogging', 'Running', 'Jump front & back']
# Total subjects: 10
#
# Train subjects: 7 users (IDs: [1 2 3 4 5 6 7])
# Val subjects: 1 users (IDs: [8])
# Test subjects: 2 users (IDs: [ 9 10])
#
# Train samples: 9663
# Val samples: 1332
# Test samples: 2719
#
# ================================================================================
# PART 1: SUPERVISED BASELINE (CompactEncoder + Classifier)
# ================================================================================
# --- Training Supervised Baseline ---
# Epoch  10/50 | Train Loss: 0.0481 | Train Acc: 0.9869
# Epoch  20/50 | Train Loss: 0.0257 | Train Acc: 0.9925
# Epoch  30/50 | Train Loss: 0.0200 | Train Acc: 0.9946
# Epoch  40/50 | Train Loss: 0.0097 | Train Acc: 0.9970
# Epoch  50/50 | Train Loss: 0.0120 | Train Acc: 0.9963
#
# --- Calculating Supervised Model Stats ---
# Supervised Stats | Params(M): 0.37, FLOPs(M): 2.42, Inf. Time(ms): 1.32
#
# --- Testing Supervised Baseline (Clean) ---
# Supervised Clean | Acc: 0.9790, F1: 0.9786
#
# --- Testing Supervised Baseline (Robustness) ---
# Supervised Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9783, F1: 0.9779
# Supervised Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9706, F1: 0.9709
# Supervised Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9511, F1: 0.9525
# Supervised Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9709, F1: 0.9711
# Supervised Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9312, F1: 0.9331
# Supervised Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9070, F1: 0.9075
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.9706, F1: 0.9712
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7915, F1: 0.7890
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.6352, F1: 0.6366
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9132, F1: 0.9129
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8588, F1: 0.8518
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8102, F1: 0.7921
# Supervised Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9728, F1: 0.9731
# Supervised Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8555, F1: 0.8399
# Supervised Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7370, F1: 0.7195
#
# ================================================================================
# PART 2: META-LEARNING (Per K-Shot Training)
# ================================================================================
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 1
# ======================================================================
# --- Calculating Meta Model Stats (K=1) ---
# Meta-1 Stats | Encoder Params(M): 0.40, Encoder FLOPs(M): 2.46, E2E Inf. Time(ms): 9.79
# --- Meta-Training (K=1, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0318 | Train Acc: 0.9933 | Val Acc: 0.7986
# Episode  2000 | Loss: 0.5687 | Train Acc: 0.8500 | Val Acc: 0.7775
# Episode  3000 | Loss: 0.0551 | Train Acc: 0.9852 | Val Acc: 0.8117
# Episode  4000 | Loss: 0.1295 | Train Acc: 0.9524 | Val Acc: 0.8022
# Episode  5000 | Loss: 0.0575 | Train Acc: 0.9778 | Val Acc: 0.7781
# Episode  6000 | Loss: 0.0582 | Train Acc: 0.9879 | Val Acc: 0.8383
# Episode  7000 | Loss: 0.0197 | Train Acc: 1.0000 | Val Acc: 0.8350
# Episode  8000 | Loss: 0.0071 | Train Acc: 1.0000 | Val Acc: 0.8289
# Episode  9000 | Loss: 0.2346 | Train Acc: 0.9417 | Val Acc: 0.9081
# Episode 10000 | Loss: 0.2372 | Train Acc: 0.9750 | Val Acc: 0.8056
#
# --- Plotting Meta-Training Learning Curves (K=1) ---
# --- Testing Meta-Learning Model (K=1) ---
# Meta-1-Shot (Clean) | Testing...
# Meta-1-Shot (Clean) | Acc: 0.9248, F1: 0.9248
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9334, F1: 0.9335
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9318, F1: 0.9318
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9222, F1: 0.9221
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9269, F1: 0.9269
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9291, F1: 0.9291
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8990, F1: 0.8990
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7742, F1: 0.7742
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6682, F1: 0.6684
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5539, F1: 0.5537
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9123, F1: 0.9123
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8828, F1: 0.8828
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8553, F1: 0.8553
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9009, F1: 0.9009
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8253, F1: 0.8252
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6743, F1: 0.6744
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 3
# ======================================================================
# --- Calculating Meta Model Stats (K=3) ---
# Meta-3 Stats | Encoder Params(M): 0.40, Encoder FLOPs(M): 2.46, E2E Inf. Time(ms): 10.22
# --- Meta-Training (K=3, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0111 | Train Acc: 1.0000 | Val Acc: 0.8864
# Episode  2000 | Loss: 0.0092 | Train Acc: 1.0000 | Val Acc: 0.8425
# Episode  3000 | Loss: 0.1196 | Train Acc: 0.9619 | Val Acc: 0.8844
# Episode  4000 | Loss: 0.0131 | Train Acc: 1.0000 | Val Acc: 0.8633
# Episode  5000 | Loss: 0.2839 | Train Acc: 0.9333 | Val Acc: 0.8064
# Episode  6000 | Loss: 0.0079 | Train Acc: 1.0000 | Val Acc: 0.8608
# Episode  7000 | Loss: 0.0066 | Train Acc: 1.0000 | Val Acc: 0.8889
# Episode  8000 | Loss: 0.0197 | Train Acc: 0.9905 | Val Acc: 0.8342
# Episode  9000 | Loss: 0.0015 | Train Acc: 1.0000 | Val Acc: 0.8783
# Episode 10000 | Loss: 0.0048 | Train Acc: 1.0000 | Val Acc: 0.9183
#
# --- Plotting Meta-Training Learning Curves (K=3) ---
# --- Testing Meta-Learning Model (K=3) ---
# Meta-3-Shot (Clean) | Testing...
# Meta-3-Shot (Clean) | Acc: 0.9283, F1: 0.9282
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9292, F1: 0.9292
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9289, F1: 0.9289
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9286, F1: 0.9286
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9267, F1: 0.9267
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9241, F1: 0.9240
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9159, F1: 0.9159
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8082, F1: 0.8082
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7317, F1: 0.7321
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.6191, F1: 0.6189
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9153, F1: 0.9152
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8963, F1: 0.8963
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8686, F1: 0.8685
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9186, F1: 0.9186
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8982, F1: 0.8982
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.8141, F1: 0.8141
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 5
# ======================================================================
# --- Calculating Meta Model Stats (K=5) ---
# Meta-5 Stats | Encoder Params(M): 0.40, Encoder FLOPs(M): 2.46, E2E Inf. Time(ms): 9.62
# --- Meta-Training (K=5, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0059 | Train Acc: 1.0000 | Val Acc: 0.8711
# Episode  2000 | Loss: 0.0031 | Train Acc: 1.0000 | Val Acc: 0.9269
# Episode  3000 | Loss: 0.0133 | Train Acc: 1.0000 | Val Acc: 0.9150
# Episode  4000 | Loss: 0.0116 | Train Acc: 0.9939 | Val Acc: 0.9017
# Episode  5000 | Loss: 0.0851 | Train Acc: 0.9833 | Val Acc: 0.8675
# Episode  6000 | Loss: 0.0053 | Train Acc: 1.0000 | Val Acc: 0.9314
# Episode  7000 | Loss: 0.0842 | Train Acc: 0.9917 | Val Acc: 0.9286
# Episode  8000 | Loss: 0.0750 | Train Acc: 0.9750 | Val Acc: 0.9261
# Episode  9000 | Loss: 0.0025 | Train Acc: 1.0000 | Val Acc: 0.9075
# Episode 10000 | Loss: 0.0020 | Train Acc: 1.0000 | Val Acc: 0.9606
#
# --- Plotting Meta-Training Learning Curves (K=5) ---
# --- Testing Meta-Learning Model (K=5) ---
# Meta-5-Shot (Clean) | Testing...
# Meta-5-Shot (Clean) | Acc: 0.9615, F1: 0.9615
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9622, F1: 0.9622
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9594, F1: 0.9594
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9592, F1: 0.9592
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9573, F1: 0.9573
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9546, F1: 0.9546
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9456, F1: 0.9456
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7995, F1: 0.7996
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7102, F1: 0.7103
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5909, F1: 0.5908
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9474, F1: 0.9474
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9236, F1: 0.9236
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8944, F1: 0.8944
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9554, F1: 0.9554
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8767, F1: 0.8767
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7903, F1: 0.7903
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 10
# ======================================================================
# --- Calculating Meta Model Stats (K=10) ---
# Meta-10 Stats | Encoder Params(M): 0.40, Encoder FLOPs(M): 2.46, E2E Inf. Time(ms): 9.69
# --- Meta-Training (K=10, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0155 | Train Acc: 0.9917 | Val Acc: 0.9453
# Episode  2000 | Loss: 0.0106 | Train Acc: 1.0000 | Val Acc: 0.9258
# Episode  3000 | Loss: 0.0027 | Train Acc: 1.0000 | Val Acc: 0.9142
# Episode  4000 | Loss: 0.0034 | Train Acc: 1.0000 | Val Acc: 0.9583
# Episode  5000 | Loss: 0.1364 | Train Acc: 0.9667 | Val Acc: 0.9408
# Episode  6000 | Loss: 0.8198 | Train Acc: 0.6889 | Val Acc: 0.8783
# Episode  7000 | Loss: 0.0027 | Train Acc: 1.0000 | Val Acc: 0.9219
# Episode  8000 | Loss: 0.0294 | Train Acc: 0.9917 | Val Acc: 0.9122
# Episode  9000 | Loss: 0.0026 | Train Acc: 1.0000 | Val Acc: 0.9453
# Episode 10000 | Loss: 0.0014 | Train Acc: 1.0000 | Val Acc: 0.9417
#
# --- Plotting Meta-Training Learning Curves (K=10) ---
# --- Testing Meta-Learning Model (K=10) ---
# Meta-10-Shot (Clean) | Testing...
# Meta-10-Shot (Clean) | Acc: 0.9561, F1: 0.9561
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9505, F1: 0.9504
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9492, F1: 0.9492
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9517, F1: 0.9517
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9526, F1: 0.9526
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9444, F1: 0.9444
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9178, F1: 0.9178
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8175, F1: 0.8173
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7168, F1: 0.7168
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5993, F1: 0.5994
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9378, F1: 0.9378
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9134, F1: 0.9134
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8774, F1: 0.8774
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9417, F1: 0.9417
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8318, F1: 0.8319
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6654, F1: 0.6653
#
# ================================================================================
# ===== FINAL COMPARISON RESULTS =====
# ================================================================================
#             Model      K-Shot                Noise  Accuracy  F1-Score  Precision    Recall
# 0      Supervised  N/A (Full)                Clean  0.979036  0.978639   0.980116  0.978887
# 1      Supervised  N/A (Full)           jitter_0.1  0.978301  0.977887   0.979525  0.978175
# 2      Supervised  N/A (Full)           jitter_0.2  0.970577  0.970895   0.971868  0.971010
# 3      Supervised  N/A (Full)           jitter_0.3  0.951085  0.952500   0.957874  0.953564
# 4      Supervised  N/A (Full)       time_shift_0.1  0.970945  0.971085   0.971869  0.971151
# 5      Supervised  N/A (Full)       time_shift_0.2  0.931225  0.933072   0.948235  0.933955
# 6      Supervised  N/A (Full)       time_shift_0.3  0.906951  0.907457   0.938802  0.911891
# 7      Supervised  N/A (Full)   sensor_failure_0.1  0.970577  0.971208   0.971964  0.971733
# 8      Supervised  N/A (Full)   sensor_failure_0.2  0.791467  0.788962   0.815346  0.801821
# 9      Supervised  N/A (Full)   sensor_failure_0.3  0.635160  0.636573   0.698400  0.651751
# 10     Supervised  N/A (Full)    outlier_spike_0.1  0.913203  0.912873   0.924053  0.917834
# 11     Supervised  N/A (Full)    outlier_spike_0.2  0.858772  0.851814   0.888481  0.866687
# 12     Supervised  N/A (Full)    outlier_spike_0.3  0.810224  0.792128   0.859125  0.820596
# 13     Supervised  N/A (Full)  missing_segment_0.1  0.972784  0.973078   0.973677  0.972843
# 14     Supervised  N/A (Full)  missing_segment_0.2  0.855462  0.839917   0.833513  0.862398
# 15     Supervised  N/A (Full)  missing_segment_0.3  0.737036  0.719514   0.788190  0.751452
# 16  Meta-Learning           1                Clean  0.924833  0.924828   0.924961  0.924833
# 17  Meta-Learning           1           jitter_0.1  0.933444  0.933469   0.933725  0.933444
# 18  Meta-Learning           1           jitter_0.2  0.931778  0.931792   0.932135  0.931778
# 19  Meta-Learning           1           jitter_0.3  0.922167  0.922115   0.922195  0.922167
# 20  Meta-Learning           1       time_shift_0.1  0.926889  0.926890   0.927089  0.926889
# 21  Meta-Learning           1       time_shift_0.2  0.929111  0.929125   0.929444  0.929111
# 22  Meta-Learning           1       time_shift_0.3  0.899000  0.899026   0.899257  0.899000
# 23  Meta-Learning           1   sensor_failure_0.1  0.774222  0.774156   0.774560  0.774222
# 24  Meta-Learning           1   sensor_failure_0.2  0.668222  0.668421   0.670087  0.668222
# 25  Meta-Learning           1   sensor_failure_0.3  0.553944  0.553696   0.555231  0.553944
# 26  Meta-Learning           1    outlier_spike_0.1  0.912333  0.912331   0.912377  0.912333
# 27  Meta-Learning           1    outlier_spike_0.2  0.882833  0.882836   0.882951  0.882833
# 28  Meta-Learning           1    outlier_spike_0.3  0.855278  0.855295   0.855529  0.855278
# 29  Meta-Learning           1  missing_segment_0.1  0.900889  0.900897   0.901226  0.900889
# 30  Meta-Learning           1  missing_segment_0.2  0.825333  0.825225   0.825573  0.825333
# 31  Meta-Learning           1  missing_segment_0.3  0.674278  0.674374   0.675487  0.674278
# 32  Meta-Learning           3                Clean  0.928250  0.928236   0.928253  0.928250
# 33  Meta-Learning           3           jitter_0.1  0.929167  0.929169   0.929246  0.929167
# 34  Meta-Learning           3           jitter_0.2  0.928889  0.928871   0.928988  0.928889
# 35  Meta-Learning           3           jitter_0.3  0.928611  0.928612   0.928716  0.928611
# 36  Meta-Learning           3       time_shift_0.1  0.926722  0.926703   0.926729  0.926722
# 37  Meta-Learning           3       time_shift_0.2  0.924056  0.924030   0.924086  0.924056
# 38  Meta-Learning           3       time_shift_0.3  0.915889  0.915878   0.916017  0.915889
# 39  Meta-Learning           3   sensor_failure_0.1  0.808222  0.808163   0.809452  0.808222
# 40  Meta-Learning           3   sensor_failure_0.2  0.731667  0.732115   0.734267  0.731667
# 41  Meta-Learning           3   sensor_failure_0.3  0.619111  0.618906   0.619574  0.619111
# 42  Meta-Learning           3    outlier_spike_0.1  0.915278  0.915242   0.915305  0.915278
# 43  Meta-Learning           3    outlier_spike_0.2  0.896333  0.896295   0.896414  0.896333
# 44  Meta-Learning           3    outlier_spike_0.3  0.868556  0.868520   0.868810  0.868556
# 45  Meta-Learning           3  missing_segment_0.1  0.918611  0.918631   0.918801  0.918611
# 46  Meta-Learning           3  missing_segment_0.2  0.898222  0.898247   0.898558  0.898222
# 47  Meta-Learning           3  missing_segment_0.3  0.814056  0.814064   0.814424  0.814056
# 48  Meta-Learning           5                Clean  0.961528  0.961529   0.961632  0.961528
# 49  Meta-Learning           5           jitter_0.1  0.962222  0.962184   0.962213  0.962222
# 50  Meta-Learning           5           jitter_0.2  0.959444  0.959440   0.959524  0.959444
# 51  Meta-Learning           5           jitter_0.3  0.959222  0.959221   0.959263  0.959222
# 52  Meta-Learning           5       time_shift_0.1  0.957333  0.957292   0.957386  0.957333
# 53  Meta-Learning           5       time_shift_0.2  0.954611  0.954611   0.954665  0.954611
# 54  Meta-Learning           5       time_shift_0.3  0.945556  0.945585   0.945774  0.945556
# 55  Meta-Learning           5   sensor_failure_0.1  0.799500  0.799625   0.800602  0.799500
# 56  Meta-Learning           5   sensor_failure_0.2  0.710167  0.710342   0.711764  0.710167
# 57  Meta-Learning           5   sensor_failure_0.3  0.590889  0.590827   0.591748  0.590889
# 58  Meta-Learning           5    outlier_spike_0.1  0.947444  0.947405   0.947461  0.947444
# 59  Meta-Learning           5    outlier_spike_0.2  0.923611  0.923605   0.923684  0.923611
# 60  Meta-Learning           5    outlier_spike_0.3  0.894389  0.894361   0.894440  0.894389
# 61  Meta-Learning           5  missing_segment_0.1  0.955389  0.955401   0.955506  0.955389
# 62  Meta-Learning           5  missing_segment_0.2  0.876667  0.876690   0.876929  0.876667
# 63  Meta-Learning           5  missing_segment_0.3  0.790333  0.790301   0.790809  0.790333
# 64  Meta-Learning          10                Clean  0.956056  0.956064   0.956121  0.956056
# 65  Meta-Learning          10           jitter_0.1  0.950500  0.950446   0.950588  0.950500
# 66  Meta-Learning          10           jitter_0.2  0.949222  0.949216   0.949281  0.949222
# 67  Meta-Learning          10           jitter_0.3  0.951667  0.951671   0.951770  0.951667
# 68  Meta-Learning          10       time_shift_0.1  0.952611  0.952593   0.952710  0.952611
# 69  Meta-Learning          10       time_shift_0.2  0.944389  0.944402   0.944510  0.944389
# 70  Meta-Learning          10       time_shift_0.3  0.917833  0.917817   0.917828  0.917833
# 71  Meta-Learning          10   sensor_failure_0.1  0.817500  0.817332   0.818348  0.817500
# 72  Meta-Learning          10   sensor_failure_0.2  0.716833  0.716790   0.717868  0.716833
# 73  Meta-Learning          10   sensor_failure_0.3  0.599333  0.599371   0.600364  0.599333
# 74  Meta-Learning          10    outlier_spike_0.1  0.937778  0.937797   0.937890  0.937778
# 75  Meta-Learning          10    outlier_spike_0.2  0.913444  0.913409   0.913664  0.913444
# 76  Meta-Learning          10    outlier_spike_0.3  0.877444  0.877435   0.877697  0.877444
# 77  Meta-Learning          10  missing_segment_0.1  0.941722  0.941705   0.941797  0.941722
# 78  Meta-Learning          10  missing_segment_0.2  0.831778  0.831892   0.832831  0.831778
# 79  Meta-Learning          10  missing_segment_0.3  0.665444  0.665335   0.666265  0.665444
# ================================================================================
# ===== PIVOT TABLE: ACCURACY =====
# ================================================================================
# <style type="text/css">
# #T_da1a9_row0_col0, #T_da1a9_row1_col0, #T_da1a9_row2_col0, #T_da1a9_row3_col3, #T_da1a9_row4_col0, #T_da1a9_row5_col2, #T_da1a9_row6_col2, #T_da1a9_row7_col3, #T_da1a9_row8_col3, #T_da1a9_row9_col3, #T_da1a9_row10_col0, #T_da1a9_row11_col0, #T_da1a9_row12_col0, #T_da1a9_row13_col0, #T_da1a9_row14_col3, #T_da1a9_row15_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_da1a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_da1a9_level0_col0" class="col_heading level0 col0" >Supervised</th>
#       <th id="T_da1a9_level0_col1" class="col_heading level0 col1" colspan="4">Meta-Learning</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >K-Shot</th>
#       <th id="T_da1a9_level1_col0" class="col_heading level1 col0" >N/A (Full)</th>
#       <th id="T_da1a9_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_da1a9_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_da1a9_level1_col3" class="col_heading level1 col3" >5</th>
#       <th id="T_da1a9_level1_col4" class="col_heading level1 col4" >10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Noise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da1a9_level0_row0" class="row_heading level0 row0" >Clean</th>
#       <td id="T_da1a9_row0_col0" class="data row0 col0" >0.9790</td>
#       <td id="T_da1a9_row0_col1" class="data row0 col1" >0.9248</td>
#       <td id="T_da1a9_row0_col2" class="data row0 col2" >0.9283</td>
#       <td id="T_da1a9_row0_col3" class="data row0 col3" >0.9615</td>
#       <td id="T_da1a9_row0_col4" class="data row0 col4" >0.9561</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row1" class="row_heading level0 row1" >jitter_0.1</th>
#       <td id="T_da1a9_row1_col0" class="data row1 col0" >0.9783</td>
#       <td id="T_da1a9_row1_col1" class="data row1 col1" >0.9334</td>
#       <td id="T_da1a9_row1_col2" class="data row1 col2" >0.9292</td>
#       <td id="T_da1a9_row1_col3" class="data row1 col3" >0.9622</td>
#       <td id="T_da1a9_row1_col4" class="data row1 col4" >0.9505</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row2" class="row_heading level0 row2" >jitter_0.2</th>
#       <td id="T_da1a9_row2_col0" class="data row2 col0" >0.9706</td>
#       <td id="T_da1a9_row2_col1" class="data row2 col1" >0.9318</td>
#       <td id="T_da1a9_row2_col2" class="data row2 col2" >0.9289</td>
#       <td id="T_da1a9_row2_col3" class="data row2 col3" >0.9594</td>
#       <td id="T_da1a9_row2_col4" class="data row2 col4" >0.9492</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row3" class="row_heading level0 row3" >jitter_0.3</th>
#       <td id="T_da1a9_row3_col0" class="data row3 col0" >0.9511</td>
#       <td id="T_da1a9_row3_col1" class="data row3 col1" >0.9222</td>
#       <td id="T_da1a9_row3_col2" class="data row3 col2" >0.9286</td>
#       <td id="T_da1a9_row3_col3" class="data row3 col3" >0.9592</td>
#       <td id="T_da1a9_row3_col4" class="data row3 col4" >0.9517</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row4" class="row_heading level0 row4" >missing_segment_0.1</th>
#       <td id="T_da1a9_row4_col0" class="data row4 col0" >0.9728</td>
#       <td id="T_da1a9_row4_col1" class="data row4 col1" >0.9009</td>
#       <td id="T_da1a9_row4_col2" class="data row4 col2" >0.9186</td>
#       <td id="T_da1a9_row4_col3" class="data row4 col3" >0.9554</td>
#       <td id="T_da1a9_row4_col4" class="data row4 col4" >0.9417</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row5" class="row_heading level0 row5" >missing_segment_0.2</th>
#       <td id="T_da1a9_row5_col0" class="data row5 col0" >0.8555</td>
#       <td id="T_da1a9_row5_col1" class="data row5 col1" >0.8253</td>
#       <td id="T_da1a9_row5_col2" class="data row5 col2" >0.8982</td>
#       <td id="T_da1a9_row5_col3" class="data row5 col3" >0.8767</td>
#       <td id="T_da1a9_row5_col4" class="data row5 col4" >0.8318</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row6" class="row_heading level0 row6" >missing_segment_0.3</th>
#       <td id="T_da1a9_row6_col0" class="data row6 col0" >0.7370</td>
#       <td id="T_da1a9_row6_col1" class="data row6 col1" >0.6743</td>
#       <td id="T_da1a9_row6_col2" class="data row6 col2" >0.8141</td>
#       <td id="T_da1a9_row6_col3" class="data row6 col3" >0.7903</td>
#       <td id="T_da1a9_row6_col4" class="data row6 col4" >0.6654</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row7" class="row_heading level0 row7" >outlier_spike_0.1</th>
#       <td id="T_da1a9_row7_col0" class="data row7 col0" >0.9132</td>
#       <td id="T_da1a9_row7_col1" class="data row7 col1" >0.9123</td>
#       <td id="T_da1a9_row7_col2" class="data row7 col2" >0.9153</td>
#       <td id="T_da1a9_row7_col3" class="data row7 col3" >0.9474</td>
#       <td id="T_da1a9_row7_col4" class="data row7 col4" >0.9378</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row8" class="row_heading level0 row8" >outlier_spike_0.2</th>
#       <td id="T_da1a9_row8_col0" class="data row8 col0" >0.8588</td>
#       <td id="T_da1a9_row8_col1" class="data row8 col1" >0.8828</td>
#       <td id="T_da1a9_row8_col2" class="data row8 col2" >0.8963</td>
#       <td id="T_da1a9_row8_col3" class="data row8 col3" >0.9236</td>
#       <td id="T_da1a9_row8_col4" class="data row8 col4" >0.9134</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row9" class="row_heading level0 row9" >outlier_spike_0.3</th>
#       <td id="T_da1a9_row9_col0" class="data row9 col0" >0.8102</td>
#       <td id="T_da1a9_row9_col1" class="data row9 col1" >0.8553</td>
#       <td id="T_da1a9_row9_col2" class="data row9 col2" >0.8686</td>
#       <td id="T_da1a9_row9_col3" class="data row9 col3" >0.8944</td>
#       <td id="T_da1a9_row9_col4" class="data row9 col4" >0.8774</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row10" class="row_heading level0 row10" >sensor_failure_0.1</th>
#       <td id="T_da1a9_row10_col0" class="data row10 col0" >0.9706</td>
#       <td id="T_da1a9_row10_col1" class="data row10 col1" >0.7742</td>
#       <td id="T_da1a9_row10_col2" class="data row10 col2" >0.8082</td>
#       <td id="T_da1a9_row10_col3" class="data row10 col3" >0.7995</td>
#       <td id="T_da1a9_row10_col4" class="data row10 col4" >0.8175</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row11" class="row_heading level0 row11" >sensor_failure_0.2</th>
#       <td id="T_da1a9_row11_col0" class="data row11 col0" >0.7915</td>
#       <td id="T_da1a9_row11_col1" class="data row11 col1" >0.6682</td>
#       <td id="T_da1a9_row11_col2" class="data row11 col2" >0.7317</td>
#       <td id="T_da1a9_row11_col3" class="data row11 col3" >0.7102</td>
#       <td id="T_da1a9_row11_col4" class="data row11 col4" >0.7168</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row12" class="row_heading level0 row12" >sensor_failure_0.3</th>
#       <td id="T_da1a9_row12_col0" class="data row12 col0" >0.6352</td>
#       <td id="T_da1a9_row12_col1" class="data row12 col1" >0.5539</td>
#       <td id="T_da1a9_row12_col2" class="data row12 col2" >0.6191</td>
#       <td id="T_da1a9_row12_col3" class="data row12 col3" >0.5909</td>
#       <td id="T_da1a9_row12_col4" class="data row12 col4" >0.5993</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row13" class="row_heading level0 row13" >time_shift_0.1</th>
#       <td id="T_da1a9_row13_col0" class="data row13 col0" >0.9709</td>
#       <td id="T_da1a9_row13_col1" class="data row13 col1" >0.9269</td>
#       <td id="T_da1a9_row13_col2" class="data row13 col2" >0.9267</td>
#       <td id="T_da1a9_row13_col3" class="data row13 col3" >0.9573</td>
#       <td id="T_da1a9_row13_col4" class="data row13 col4" >0.9526</td>
#     </tr>
#     <tr>
#       <th id="T_da1a9_level0_row14" class="row_heading level0 row14" >time_shift_0.2</th>
#       <td id="T_da1a9_row14_col0" class="data row14 col0" >0.9312</
# ================================================================================
# ===== PIVOT TABLE: F1-SCORE =====
# ================================================================================
# <style type="text/css">
# #T_af17a_row0_col0, #T_af17a_row1_col0, #T_af17a_row2_col0, #T_af17a_row3_col3, #T_af17a_row4_col0, #T_af17a_row5_col2, #T_af17a_row6_col2, #T_af17a_row7_col3, #T_af17a_row8_col3, #T_af17a_row9_col3, #T_af17a_row10_col0, #T_af17a_row11_col0, #T_af17a_row12_col0, #T_af17a_row13_col0, #T_af17a_row14_col3, #T_af17a_row15_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_af17a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_af17a_level0_col0" class="col_heading level0 col0" >Supervised</th>
#       <th id="T_af17a_level0_col1" class="col_heading level0 col1" colspan="4">Meta-Learning</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >K-Shot</th>
#       <th id="T_af17a_level1_col0" class="col_heading level1 col0" >N/A (Full)</th>
#       <th id="T_af17a_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_af17a_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_af17a_level1_col3" class="col_heading level1 col3" >5</th>
#       <th id="T_af17a_level1_col4" class="col_heading level1 col4" >10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Noise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af17a_level0_row0" class="row_heading level0 row0" >Clean</th>
#       <td id="T_af17a_row0_col0" class="data row0 col0" >0.9786</td>
#       <td id="T_af17a_row0_col1" class="data row0 col1" >0.9248</td>
#       <td id="T_af17a_row0_col2" class="data row0 col2" >0.9282</td>
#       <td id="T_af17a_row0_col3" class="data row0 col3" >0.9615</td>
#       <td id="T_af17a_row0_col4" class="data row0 col4" >0.9561</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row1" class="row_heading level0 row1" >jitter_0.1</th>
#       <td id="T_af17a_row1_col0" class="data row1 col0" >0.9779</td>
#       <td id="T_af17a_row1_col1" class="data row1 col1" >0.9335</td>
#       <td id="T_af17a_row1_col2" class="data row1 col2" >0.9292</td>
#       <td id="T_af17a_row1_col3" class="data row1 col3" >0.9622</td>
#       <td id="T_af17a_row1_col4" class="data row1 col4" >0.9504</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row2" class="row_heading level0 row2" >jitter_0.2</th>
#       <td id="T_af17a_row2_col0" class="data row2 col0" >0.9709</td>
#       <td id="T_af17a_row2_col1" class="data row2 col1" >0.9318</td>
#       <td id="T_af17a_row2_col2" class="data row2 col2" >0.9289</td>
#       <td id="T_af17a_row2_col3" class="data row2 col3" >0.9594</td>
#       <td id="T_af17a_row2_col4" class="data row2 col4" >0.9492</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row3" class="row_heading level0 row3" >jitter_0.3</th>
#       <td id="T_af17a_row3_col0" class="data row3 col0" >0.9525</td>
#       <td id="T_af17a_row3_col1" class="data row3 col1" >0.9221</td>
#       <td id="T_af17a_row3_col2" class="data row3 col2" >0.9286</td>
#       <td id="T_af17a_row3_col3" class="data row3 col3" >0.9592</td>
#       <td id="T_af17a_row3_col4" class="data row3 col4" >0.9517</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row4" class="row_heading level0 row4" >missing_segment_0.1</th>
#       <td id="T_af17a_row4_col0" class="data row4 col0" >0.9731</td>
#       <td id="T_af17a_row4_col1" class="data row4 col1" >0.9009</td>
#       <td id="T_af17a_row4_col2" class="data row4 col2" >0.9186</td>
#       <td id="T_af17a_row4_col3" class="data row4 col3" >0.9554</td>
#       <td id="T_af17a_row4_col4" class="data row4 col4" >0.9417</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row5" class="row_heading level0 row5" >missing_segment_0.2</th>
#       <td id="T_af17a_row5_col0" class="data row5 col0" >0.8399</td>
#       <td id="T_af17a_row5_col1" class="data row5 col1" >0.8252</td>
#       <td id="T_af17a_row5_col2" class="data row5 col2" >0.8982</td>
#       <td id="T_af17a_row5_col3" class="data row5 col3" >0.8767</td>
#       <td id="T_af17a_row5_col4" class="data row5 col4" >0.8319</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row6" class="row_heading level0 row6" >missing_segment_0.3</th>
#       <td id="T_af17a_row6_col0" class="data row6 col0" >0.7195</td>
#       <td id="T_af17a_row6_col1" class="data row6 col1" >0.6744</td>
#       <td id="T_af17a_row6_col2" class="data row6 col2" >0.8141</td>
#       <td id="T_af17a_row6_col3" class="data row6 col3" >0.7903</td>
#       <td id="T_af17a_row6_col4" class="data row6 col4" >0.6653</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row7" class="row_heading level0 row7" >outlier_spike_0.1</th>
#       <td id="T_af17a_row7_col0" class="data row7 col0" >0.9129</td>
#       <td id="T_af17a_row7_col1" class="data row7 col1" >0.9123</td>
#       <td id="T_af17a_row7_col2" class="data row7 col2" >0.9152</td>
#       <td id="T_af17a_row7_col3" class="data row7 col3" >0.9474</td>
#       <td id="T_af17a_row7_col4" class="data row7 col4" >0.9378</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row8" class="row_heading level0 row8" >outlier_spike_0.2</th>
#       <td id="T_af17a_row8_col0" class="data row8 col0" >0.8518</td>
#       <td id="T_af17a_row8_col1" class="data row8 col1" >0.8828</td>
#       <td id="T_af17a_row8_col2" class="data row8 col2" >0.8963</td>
#       <td id="T_af17a_row8_col3" class="data row8 col3" >0.9236</td>
#       <td id="T_af17a_row8_col4" class="data row8 col4" >0.9134</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row9" class="row_heading level0 row9" >outlier_spike_0.3</th>
#       <td id="T_af17a_row9_col0" class="data row9 col0" >0.7921</td>
#       <td id="T_af17a_row9_col1" class="data row9 col1" >0.8553</td>
#       <td id="T_af17a_row9_col2" class="data row9 col2" >0.8685</td>
#       <td id="T_af17a_row9_col3" class="data row9 col3" >0.8944</td>
#       <td id="T_af17a_row9_col4" class="data row9 col4" >0.8774</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row10" class="row_heading level0 row10" >sensor_failure_0.1</th>
#       <td id="T_af17a_row10_col0" class="data row10 col0" >0.9712</td>
#       <td id="T_af17a_row10_col1" class="data row10 col1" >0.7742</td>
#       <td id="T_af17a_row10_col2" class="data row10 col2" >0.8082</td>
#       <td id="T_af17a_row10_col3" class="data row10 col3" >0.7996</td>
#       <td id="T_af17a_row10_col4" class="data row10 col4" >0.8173</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row11" class="row_heading level0 row11" >sensor_failure_0.2</th>
#       <td id="T_af17a_row11_col0" class="data row11 col0" >0.7890</td>
#       <td id="T_af17a_row11_col1" class="data row11 col1" >0.6684</td>
#       <td id="T_af17a_row11_col2" class="data row11 col2" >0.7321</td>
#       <td id="T_af17a_row11_col3" class="data row11 col3" >0.7103</td>
#       <td id="T_af17a_row11_col4" class="data row11 col4" >0.7168</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row12" class="row_heading level0 row12" >sensor_failure_0.3</th>
#       <td id="T_af17a_row12_col0" class="data row12 col0" >0.6366</td>
#       <td id="T_af17a_row12_col1" class="data row12 col1" >0.5537</td>
#       <td id="T_af17a_row12_col2" class="data row12 col2" >0.6189</td>
#       <td id="T_af17a_row12_col3" class="data row12 col3" >0.5908</td>
#       <td id="T_af17a_row12_col4" class="data row12 col4" >0.5994</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row13" class="row_heading level0 row13" >time_shift_0.1</th>
#       <td id="T_af17a_row13_col0" class="data row13 col0" >0.9711</td>
#       <td id="T_af17a_row13_col1" class="data row13 col1" >0.9269</td>
#       <td id="T_af17a_row13_col2" class="data row13 col2" >0.9267</td>
#       <td id="T_af17a_row13_col3" class="data row13 col3" >0.9573</td>
#       <td id="T_af17a_row13_col4" class="data row13 col4" >0.9526</td>
#     </tr>
#     <tr>
#       <th id="T_af17a_level0_row14" class="row_heading level0 row14" >time_shift_0.2</th>
#       <td id="T_af17a_row14_col0" class="data row14 col0" >0.9331</
# ================================================================================
# ===== MODEL STATISTICS (Params, FLOPs, Latency) =====
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_77c17" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77c17_level0_col0" class="col_heading level0 col0" >Param (M)</th>
#       <th id="T_77c17_level0_col1" class="col_heading level0 col1" >FLOPs (M)</th>
#       <th id="T_77c17_level0_col2" class="col_heading level0 col2" >Inf. Time (ms)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="index_name level1" >K-Shot</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77c17_level0_row0" class="row_heading level0 row0" >Supervised</th>
#       <th id="T_77c17_level1_row0" class="row_heading level1 row0" >N/A (Full)</th>
#       <td id="T_77c17_row0_col0" class="data row0 col0" >0.37</td>
#       <td id="T_77c17_row0_col1" class="data row0 col1" >2.42</td>
#       <td id="T_77c17_row0_col2" class="data row0 col2" >1.32</td>
#     </tr>
#     <tr>
#       <th id="T_77c17_level0_row1" class="row_heading level0 row1" rowspan="4">Meta-Learning</th>
#       <th id="T_77c17_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_77c17_row1_col0" class="data row1 col0" >0.40</td>
#       <td id="T_77c17_row1_col1" class="data row1 col1" >2.46</td>
#       <td id="T_77c17_row1_col2" class="data row1 col2" >9.79</td>
#     </tr>
#     <tr>
#       <th id="T_77c17_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_77c17_row2_col0" class="data row2 col0" >0.40</td>
#       <td id="T_77c17_row2_col1" class="data row2 col1" >2.46</td>
#       <td id="T_77c17_row2_col2" class="data row2 col2" >10.22</td>
#     </tr>
#     <tr>
#       <th id="T_77c17_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_77c17_row3_col0" class="data row3 col0" >0.40</td>
#       <td id="T_77c17_row3_col1" class="data row3 col1" >2.46</td>
#       <td id="T_77c17_row3_col2" class="data row3 col2" >9.62</td>
#     </tr>
#     <tr>
#       <th id="T_77c17_level1_row4" class="row_heading level1 row4" >10</th>
#       <td id="T_77c17_row4_col0" class="data row4 col0" >0.40</td>
#       <td id="T_77c17_row4_col1" class="data row4 col1" >2.46</td>
#       <td id="T_77c17_row4_col2" class="data row4 col2" >9.69</td>
#     </tr>
#   </tbody>
# </table>
