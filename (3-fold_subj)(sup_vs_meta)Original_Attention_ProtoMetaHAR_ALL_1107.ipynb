# %%
# !pip install thop ptflops
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238

# %%
import os
import random
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from thop import profile
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import re
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from glob import glob
import pickle
import scipy.io as scio
from sklearn.model_selection import KFold

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def compute_mean_std(X):
    X = X.astype(np.float32)
    mean = X.mean(axis=(0, 2), keepdims=True)
    std  = X.std(axis=(0, 2), keepdims=True) + 1e-8
    return mean, std

def aug_jitter_scale(x_batch, jitter_sigma=0.03, scale_max=0.1):
    jitter = torch.randn_like(x_batch) * jitter_sigma
    x_batch = x_batch + jitter
    scale = 1.0 + (torch.rand(x_batch.shape[0], 1, 1, device=x_batch.device) - 0.5) * 2 * scale_max
    x_batch = x_batch * scale
    return x_batch

def aug_sensor_failure(x_batch):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    fail_channel = random.randint(0, C - 1)
    x_aug[:, fail_channel, :] = 0.0
    return x_aug

def aug_missing_segment(x_batch, missing_seg_len_range=(0.1, 0.25)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    seg_len_min = int(L * missing_seg_len_range[0])
    seg_len_max = int(L * missing_seg_len_range[1])
    if seg_len_min >= seg_len_max:
         seg_len_max = seg_len_min + 1
    seg_len = random.randint(seg_len_min, seg_len_max)
    start = random.randint(0, L - seg_len)
    x_aug[:, :, start:start+seg_len] = 0.0
    return x_aug

def aug_outlier_spike(x_batch, outlier_magnitude=10, num_outliers_range=(1, 5)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    device = x_batch.device

    num_outliers = random.randint(num_outliers_range[0], num_outliers_range[1])
    if num_outliers == 0:
        return x_aug

    b_idx = torch.randint(0, B, (num_outliers,), device=device)
    c_idx = torch.randint(0, C, (num_outliers,), device=device)
    l_idx = torch.randint(0, L, (num_outliers,), device=device)

    magnitudes = torch.randn(num_outliers, device=device) * outlier_magnitude

    flat_indices = b_idx * (C * L) + c_idx * L + l_idx
    x_aug.view(-1).index_add_(0, flat_indices, magnitudes)

    return x_aug

def apply_test_noise(x_batch, noise_type, noise_level):
    x_noisy = x_batch.clone()
    B, C, L = x_batch.shape
    device = x_batch.device

    if noise_type == 'jitter':
        noise = torch.randn_like(x_batch) * noise_level
        x_noisy = x_batch + noise

    elif noise_type == 'time_shift':
        max_shift = int(L * noise_level)
        if max_shift == 0 and noise_level > 0:
             max_shift = 1

        shifts = torch.randint(-max_shift, max_shift + 1, (B,), device=device)

        src_indices = torch.arange(L, device=device).unsqueeze(0).expand(B, -1)
        dest_indices = src_indices + shifts.unsqueeze(1)

        valid_mask = (dest_indices >= 0) & (dest_indices < L)

        batch_idx = torch.arange(B, device=device).view(-1, 1, 1).expand(-1, C, L)
        channel_idx = torch.arange(C, device=device).view(1, -1, 1).expand(B, -1, L)

        x_shifted = torch.zeros_like(x_batch)

        dest_time_idx = dest_indices.unsqueeze(1).expand(-1, C, -1)
        valid_mask_expanded = valid_mask.unsqueeze(1).expand(-1, C, -1)

        valid_dest_indices = dest_time_idx[valid_mask_expanded]
        valid_batch_indices = batch_idx[valid_mask_expanded]
        valid_channel_indices = channel_idx[valid_mask_expanded]
        valid_src_values = x_batch[valid_mask_expanded]

        x_shifted[valid_batch_indices, valid_channel_indices, valid_dest_indices] = valid_src_values
        x_noisy = x_shifted

    elif noise_type == 'sensor_failure':
        n_channels = int(np.ceil(C * noise_level))
        if n_channels == 0: n_channels = 1
        fail_channels = np.random.choice(C, n_channels, replace=False)
        x_noisy[:, fail_channels, :] = 0.0

    elif noise_type == 'outlier_spike':
        num_spikes = max(1, int(noise_level * 100))
        total_spikes = B * num_spikes

        b_idx = torch.arange(B, device=device).repeat_interleave(num_spikes)
        c_idx = torch.randint(0, C, (total_spikes,), device=device)
        l_idx = torch.randint(0, L, (total_spikes,), device=device)
        magnitudes = (torch.randn(total_spikes, device=device) * 5)

        flat_indices = b_idx * (C * L) + c_idx * L + l_idx
        x_noisy.view(-1).index_add_(0, flat_indices, magnitudes)

    elif noise_type == 'missing_segment':
        seg_len = max(1, int(L * noise_level))
        start = random.randint(0, L - seg_len)
        x_noisy[:, :, start:start+seg_len] = 0.0

    return x_noisy

def compute_encoder_stats(encoder, input_shape=(1,9,128)):
    device = next(encoder.parameters()).device
    macs, params = profile(encoder, inputs=(torch.randn(*input_shape).to(device),), verbose=False)
    return params/1e6, macs/1e6

def measure_meta_inference_time(model, n_way, sz=(1,9,128), dev='cuda', runs=100, warm=10):
    model.eval()
    x_q = torch.randn(sz, device=dev)
    x_s = torch.randn((n_way*5,) + sz[1:], device=dev)
    y_s = torch.tensor(np.repeat(range(n_way), 5), device=dev)

    with torch.no_grad():
        for _ in range(warm):
            _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    t0 = time.time()
    with torch.no_grad():
        for _ in range(runs):
            _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    return (time.time()-t0)/runs*1000

def compute_supervised_stats(model: nn.Module, input_shape=(9, 128)):
    device = next(model.parameters()).device
    dummy_input = torch.randn(1, *input_shape).to(device)
    model.eval()

    if not hasattr(model, 'classifier') or not hasattr(model, 'extract_features'):
        raise ValueError("Model must have 'classifier' attribute and 'extract_features' method.")

    classifier_original = model.classifier
    model.classifier = nn.Identity()
    macs_backbone, params_backbone = profile(model, inputs=(dummy_input,), verbose=False)
    model.classifier = classifier_original

    with torch.no_grad():
        features = model.extract_features(dummy_input)
        if isinstance(features, tuple):
            features = features[0]

    macs_cls, params_cls = profile(model.classifier, inputs=(features,), verbose=False)

    total_macs_m = (macs_backbone + macs_cls) / 1e6
    total_params_m = (params_backbone + params_cls) / 1e6
    return total_params_m, total_macs_m

def measure_supervised_inference_time(model: nn.Module, input_size=(1, 9, 128), device='cuda', n_runs=100, warmup=10):
    model.eval()
    inputs = torch.randn(input_size).to(device)

    with torch.inference_mode():
        for _ in range(warmup):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    start = time.time()
    with torch.inference_mode():
        for _ in range(n_runs):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    end = time.time()
    return (end - start) / n_runs * 1000

def plot_confusion_matrix(cm, labels):
    cmn = cm.astype('float')/cm.sum(axis=1)[:,None]
    df = pd.DataFrame(cmn, index=labels, columns=labels)
    plt.figure(figsize=(8,7))
    sns.heatmap(df, annot=True, fmt='.2f', cmap='Blues', cbar=True)
    plt.xlabel('Predicted', fontsize=12)
    plt.ylabel('True', fontsize=12)
    plt.title('Confusion Matrix (Normalized)', fontsize=14)
    plt.tight_layout()
    plt.show()

def plot_learning_curves(train_losses, train_accs, val_accs, title_suffix=""):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    ax1.plot(train_losses, linewidth=2, label='Train Loss')
    ax1.set_xlabel('Episode', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.set_title(f'Training Loss {title_suffix}', fontsize=14)
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(train_accs, linewidth=2, color='orange', label='Train Acc')
    ax2.plot(val_accs, linewidth=2, color='green', label='Val Acc')
    ax2.set_xlabel('Episode', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.set_title(f'Training & Validation Accuracy {title_suffix}', fontsize=14)
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    plt.tight_layout()

def plot_kshot_comparison(shot_results):
    plt.figure(figsize=(10, 6))
    plt.plot([r['K'] for r in shot_results], [r['Accuracy'] for r in shot_results],
             marker='o', linewidth=2, markersize=8, label='Accuracy')
    plt.plot([r['K'] for r in shot_results], [r['F1'] for r in shot_results],
             marker='s', linewidth=2, markersize=8, label='F1-Score')
    plt.xlabel('K-Shot', fontsize=12)
    plt.ylabel('Score', fontsize=12)
    plt.title('Meta-Learning Performance vs K-Shot', fontsize=14)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def plot_user_performance(per_user_df):
    plt.figure(figsize=(12, 6))
    x = range(len(per_user_df))
    plt.bar(x, per_user_df['Accuracy'], alpha=0.7, label='Accuracy')
    plt.axhline(y=per_user_df['Accuracy'].mean(), color='r', linestyle='--',
                label=f'Mean: {per_user_df["Accuracy"].mean():.3f}')
    plt.xlabel('Test User', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Per-User 5-Shot Accuracy', fontsize=14)
    plt.xticks(x, per_user_df['User'])
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    plt.tight_layout()
    plt.show()

class HARDataset(Dataset):
    def __init__(self, X, y, norm=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if norm:
            self.mean = self.X.mean(axis=(0,2), keepdims=True)
            self.std = self.X.std(axis=(0,2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean)/self.std
        else:
            self.mean, self.std = None, None

    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean)/self.std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        return torch.from_numpy(self.X[i]), int(self.y[i])

def read_txt_matrix(path):
    with open(path, 'r') as f:
        lines = f.readlines()
    lines = [list(map(float, line.strip().split())) for line in lines]
    return np.array(lines)

def slide_window(a, w, s):
    a = np.asarray(a)
    sh = (a.shape[0] - w + 1, w, a.shape[1])
    st = (a.strides[0], a.strides[0], a.strides[1])
    A = np.lib.stride_tricks.as_strided(a, shape=sh, strides=st)
    return A[::s]

def load_dsads_data(data_path, w_s=25, stride=12):
    print(f"Loading DSADS data with window={w_s}, stride={stride}")
    all_windows = []
    all_labels = []
    all_subjects = []

    activities = {
        'a01': 'sitting', 'a02': 'standing', 'a03': 'lying on back',
        'a04': 'lying on right side', 'a05': 'ascending stairs',
        'a06': 'descending stairs', 'a07': 'standing in an elevator still',
        'a08': 'moving around in an elevator', 'a09': 'walking in a parking lot',
        'a10': 'walking on a treadmill with a speed of 4 kmh',
        'a11': 'walking in flat and 15 deg inclined positions',
        'a12': 'running on a treadmill with a speed of 8 kmh',
        'a13': 'exercising on a stepper', 'a14': 'exercising on a cross trainer',
        'a15': 'cycling on an exercise bike in horizontal positions',
        'a16': 'cycling on an exercise bike in vertical positions',
        'a17': 'rowing', 'a18': 'jumping', 'a19': 'playing basketball'
    }
    activity_codes = sorted(activities.keys())

    label_encoder = LabelEncoder()
    label_encoder.fit(activity_codes)

    persons = ['p' + str(i) for i in range(1, 9)]

    for person_str in persons:
        subject_id = int(person_str[1:])
        # print (f"{subject_id} subject") # Reduced verbosity

        for activity_str in activity_codes:
            activity_label = label_encoder.transform([activity_str])[0]
            pattern = os.path.join(data_path, activity_str, person_str, 's*.txt')
            segment_files = sorted(glob(pattern))

            if not segment_files:
                continue

            for f in segment_files[:11]:
                try:
                    segment_data = np.loadtxt(f, delimiter=',')
                    if segment_data.shape[0] < w_s:
                        continue

                    start = 0
                    while start + w_s <= segment_data.shape[0]:
                        window_data = segment_data[start : start + w_s, :]
                        all_windows.append(window_data)
                        all_labels.append(activity_label)
                        all_subjects.append(subject_id)
                        start += stride

                except Exception as e:
                    print(f"Error loading or windowing {f}: {e}")

    if not all_windows:
        print("No valid windows created from DSADS data.")
        return None, None, None, None

    X_windowed = np.array(all_windows, dtype=np.float32)
    y_encoded = np.array(all_labels, dtype=int)
    subjects = np.array(all_subjects, dtype=int)

    X_windowed = np.transpose(X_windowed, (0, 2, 1))

    activity_names_sorted = [activities[code] for code in label_encoder.classes_]

    print("\n" + "=" * 50)
    print("Per-Subject Class Distribution (Window Count)")
    print("=" * 50)

    all_subjects_u = np.unique(subjects)
    all_labels_idx = sorted(list(np.unique(y_encoded)))

    dist_data = []

    for sub_id in all_subjects_u:
        sub_mask = (subjects == sub_id)
        sub_labels = y_encoded[sub_mask]
        class_counts = Counter(sub_labels)

        row = {'Subject': f"S{sub_id}"}
        total = 0
        for label_idx in all_labels_idx:
            count = class_counts.get(label_idx, 0)
            row[activities[activity_codes[label_idx]]] = count
            total += count
        row['Total'] = total
        dist_data.append(row)

    dist_df = pd.DataFrame(dist_data)
    dist_df = dist_df.set_index('Subject')

    col_order = [activities[activity_codes[i]] for i in all_labels_idx] + ['Total']
    dist_df = dist_df[col_order]

    display(dist_df)
    print("=" * 50 + "\n")

    return X_windowed, y_encoded, subjects, activity_names_sorted

def load_uschad_data(path, w_s=100, stride=50):
    ACTIVITIES = {
        0: 'Walking Forward', 1: 'Walking Left', 2: 'Walking Right', 3: 'Walking Upstairs',
        4: 'Walking Downstairs', 5: 'Running Forward', 6: 'Jumping Up', 7: 'Sitting',
        8: 'Standing', 9: 'Sleeping', 10: 'Elevator Up', 11: 'Elevator Down'
    }

    result = []
    subject_ids = []
    labels = []

    if not os.path.exists(path):
        print(f"Path does not exist: {path}")
        return None, None, None, None

    subject_list = os.listdir(path)
    subject_list = [subject for subject in subject_list if subject.find('Subject') != -1]
    subject_list = sorted(subject_list)

    if not subject_list:
        print(f"No 'Subject' directories found in: {path}")
        return None, None, None, None

    print(f"Loading USC-HAD: Found {len(subject_list)} subjects. (w_s={w_s}, stride={stride})")

    original_cwd = os.getcwd()
    try:
        os.chdir(path)

        for i, subject in enumerate(subject_list):
            if not os.path.isdir(subject):
                continue

            subject_num_match = re.findall(r'(\d+)', subject)
            if not subject_num_match:
                continue
            subject_num = int(subject_num_match[0])

            mat_list = os.listdir(subject)
            os.chdir(subject)

            for mat in mat_list:
                if not mat.endswith('.mat'):
                    continue

                activity_num_match = re.findall(r'a(\d+)', mat)
                if not activity_num_match:
                    continue

                category = int(activity_num_match[0]) - 1
                if category not in ACTIVITIES:
                    continue

                content = scio.loadmat(mat)['sensor_readings']

                x = slide_window(content, w_s, stride)

                result.extend(x)
                subject_ids.extend([subject_num] * len(x))
                labels.extend([category] * len(x))

            os.chdir('../')

    except Exception as e:
        print(f"Error loading data: {e}")
        os.chdir(original_cwd)
        return None, None, None, None

    os.chdir(original_cwd)

    if not result:
        print("No data loaded from .mat files.")
        return None, None, None, None

    data = np.array(result, dtype=np.float32)
    data = np.transpose(data, (0, 2, 1))

    activity_labels = [ACTIVITIES[i] for i in range(len(ACTIVITIES))]

    y_full = np.array(labels, dtype=int)
    sub_full = np.array(subject_ids, dtype=int)

    print("\n" + "=" * 50)
    print("Per-Subject Class Distribution (Window Count)")
    print("=" * 50)

    all_subjects = np.unique(sub_full)
    all_labels_idx = sorted(list(ACTIVITIES.keys()))

    dist_data = []

    for sub_id in all_subjects:
        sub_mask = (sub_full == sub_id)
        sub_labels = y_full[sub_mask]
        class_counts = Counter(sub_labels)

        row = {'Subject': f"S{sub_id}"}
        total = 0
        for label_idx in all_labels_idx:
            count = class_counts.get(label_idx, 0)
            row[ACTIVITIES[label_idx]] = count
            total += count
        row['Total'] = total
        dist_data.append(row)

    dist_df = pd.DataFrame(dist_data)
    dist_df = dist_df.set_index('Subject')

    col_order = [ACTIVITIES[i] for i in all_labels_idx] + ['Total']
    dist_df = dist_df[col_order]

    display(dist_df)
    print("=" * 50 + "\n")

    return data, y_full, sub_full, activity_labels

def load_mhealth_data(dataset_dir="MHEALTH", **kwargs):
    subject_files = sorted([
        os.path.join(dataset_dir, f)
        for f in os.listdir(dataset_dir)
        if f.startswith("mHealth_subject") and f.endswith(".log")
    ])
    if not subject_files:
        print(f"No mHealth log files found in directory: {dataset_dir}")
        return None, None, None, None

    all_windows = []
    all_labels = []
    all_subjects = []
    window_size = 50
    step = 25

    print(f"Loading MHEALTH data with window={window_size}, stride={step}")

    for file_path in subject_files:
        subject_id_match = re.search(r'subject(\d+)', os.path.basename(file_path))
        if not subject_id_match:
            continue
        subject_id = int(subject_id_match.group(1))

        df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
        df = df.ffill().bfill()
        if df.shape[1] < 24:
            continue

        labels = df.iloc[:, 23].values.astype(int)
        imu_cols = [0,1,2] + list(range(5, 23))
        features = df.iloc[:, imu_cols].values

        valid_indices = np.where(labels != 0)[0]
        if len(valid_indices) == 0:
            continue

        features = features[valid_indices, :]
        labels = labels[valid_indices]

        if len(features) < window_size:
            continue

        start = 0
        while start + window_size <= len(features):
            window_data = features[start : start + window_size, :]
            window_labels_raw = labels[start : start + window_size]
            most_common_label = Counter(window_labels_raw).most_common(1)[0][0]

            all_windows.append(window_data)
            all_labels.append(most_common_label)
            all_subjects.append(subject_id)

            start += step

    if not all_windows:
        print("No valid windows created from mHealth data.")
        return None, None, None, None

    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(all_labels)
    X_windowed = np.array(all_windows, dtype=np.float32)

    X_windowed = np.transpose(X_windowed, (0, 2, 1))

    mhealth_activity_mapping = {
        1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down', 4: 'Walking',
        5: 'Climbing stairs', 6: 'Waist bends forward', 7: 'Frontal elevation of arms',
        8: 'Knees bending', 9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
    }
    activity_labels = []
    class_names = list(label_encoder.classes_)

    for original_label in class_names:
        if original_label in mhealth_activity_mapping:
            activity_labels.append(mhealth_activity_mapping[original_label])
        else:
            activity_labels.append(f"Unknown_Activity_{original_label}")

    return X_windowed, y_encoded, np.array(all_subjects, dtype=int), activity_labels

def load_full_uci_har_data(root, **kwargs):
    print(f"Loading UCI-HAR data from: {root}")
    pref = ["total_acc_x_","total_acc_y_","total_acc_z_",
            "body_acc_x_","body_acc_y_","body_acc_z_",
            "body_gyro_x_","body_gyro_y_","body_gyro_z_"]

    def load(s):
        folder = "./"
        base_path = os.path.join(root)

        ch = [read_txt_matrix(os.path.join(base_path, f"{p}{s}.txt")) for p in pref]
        X = np.stack(ch, axis=1)

        y_path = os.path.join(root,f"y_{s}.txt")
        y = read_txt_matrix(y_path).astype(int).reshape(-1) - 1

        sub_path = os.path.join(root, f"subject_{s}.txt")
        sub = read_txt_matrix(sub_path).astype(int).reshape(-1)

        return X,y,sub

    Xtr,ytr,str = load("train")
    Xte,yte,ste = load("test")
    X = np.concatenate((Xtr,Xte))
    y = np.concatenate((ytr,yte))
    sub = np.concatenate((str,ste))

    names = ['Walking','Walking Upstairs','Walking Downstairs','Sitting','Standing','Laying']

    print("\n" + "=" * 50)
    print("Per-Subject Class Distribution (Window Count)")
    print("=" * 50)

    all_subjects_u = np.unique(sub)
    all_labels_idx = sorted(list(np.unique(y)))

    dist_data = []

    for sub_id in all_subjects_u:
        sub_mask = (sub == sub_id)
        sub_labels = y[sub_mask]
        class_counts = Counter(sub_labels)

        row = {'Subject': f"S{sub_id}"}
        total = 0
        for label_idx in all_labels_idx:
            count = class_counts.get(label_idx, 0)
            row[names[label_idx]] = count
            total += count
        row['Total'] = total
        dist_data.append(row)

    dist_df = pd.DataFrame(dist_data)
    dist_df = dist_df.set_index('Subject')

    col_order = [names[i] for i in all_labels_idx] + ['Total']
    dist_df = dist_df[col_order]

    display(dist_df)
    print("=" * 50 + "\n")

    return X,y,sub,names

class CompactEncoder(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128):
        super().__init__()
        self.stage1 = self._make_stage(in_channels, 32, stride=2)
        self.stage2 = self._make_stage(32, 64, stride=2)
        self.stage3 = self._make_stage(64, 128, stride=2)
        self.stage4 = self._make_stage(128, embed_dim, stride=2)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def _make_stage(self, in_ch, out_ch, stride=1):
        return nn.Sequential(
            nn.Conv1d(in_ch, out_ch, kernel_size=5, stride=stride, padding=2),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU()
        )

    def forward(self, x):
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)
        x = self.pool(x).flatten(1)
        return x

class AttentionWeightedProtoNet(nn.Module):
    def __init__(self, encoder, feature_dim, temperature=1.0):
        super().__init__()
        self.encoder = encoder
        self.temperature = temperature

        self.attention = nn.Sequential(
            nn.Linear(feature_dim, feature_dim // 2),
            nn.ReLU(),
            nn.Linear(feature_dim // 2, 1)
        )
        self.adapter = nn.Sequential(
            nn.Linear(feature_dim * 2, feature_dim),
            nn.ReLU(),
            nn.Linear(feature_dim, feature_dim)
        )

    def compute_prototypes(self, support_features, support_y, n_way):
        embed_dim = support_features.size(1)
        prototypes = []

        for c in range(n_way):
            mask = (support_y == c)
            if mask.sum() > 0:
                features_c = support_features[mask]

                attn_w = F.softmax(self.attention(features_c), dim=0)

                prototype_c = (attn_w * features_c).sum(0)

                prototypes.append(prototype_c)
            else:
                prototypes.append(torch.zeros(embed_dim, device=support_features.device))

        return torch.stack(prototypes)

    def forward(self, query_x, support_x, support_y, n_way):
        support_features = self.encoder(support_x)
        query_features = self.encoder(query_x)

        prototypes = self.compute_prototypes(support_features, support_y, n_way)

        n_query = query_features.size(0)

        query_features_expanded = query_features.unsqueeze(1).expand(-1, n_way, -1)
        proto_features_expanded = prototypes.unsqueeze(0).expand(n_query, -1, -1)

        cat_input = torch.cat([query_features_expanded, proto_features_expanded], dim=-1)
        delta = self.adapter(cat_input)
        adapted_prototypes = proto_features_expanded + delta

        dist = ((query_features_expanded - adapted_prototypes)**2).sum(dim=-1)

        logits = -dist / self.temperature

        return logits

class OriginalProtoNet(nn.Module):
    def __init__(self, encoder, feature_dim, temperature=1.0):
        super().__init__()
        self.encoder = encoder
        self.temperature = temperature

    def compute_prototypes(self, support_features, support_y, n_way):
        embed_dim = support_features.size(1)
        prototypes = []

        for c in range(n_way):
            mask = (support_y == c)
            if mask.sum() > 0:
                features_c = support_features[mask]
                prototype_c = features_c.mean(dim=0)
                prototypes.append(prototype_c)
            else:
                prototypes.append(torch.zeros(embed_dim, device=support_features.device))

        return torch.stack(prototypes)

    def forward(self, query_x, support_x, support_y, n_way):
        support_features = self.encoder(support_x)
        query_features = self.encoder(query_x)

        prototypes = self.compute_prototypes(support_features, support_y, n_way)

        n_query = query_features.size(0)

        query_features_expanded = query_features.unsqueeze(1).expand(-1, n_way, -1)
        proto_features_expanded = prototypes.unsqueeze(0).expand(n_query, -1, -1)

        dist = ((query_features_expanded - proto_features_expanded)**2).sum(dim=-1)

        logits = -dist / self.temperature

        return logits

class SupervisedBaseline(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128, num_classes=6):
        super().__init__()
        self.encoder = CompactEncoder(in_channels=in_channels, embed_dim=embed_dim)
        self.classifier = nn.Linear(embed_dim, num_classes)

    def extract_features(self, x):
        return self.encoder(x)

    def forward(self, x):
        features = self.extract_features(x)
        return self.classifier(features)

def create_episodes(users_data, n_way=6, k_shot=5, q_query=15, total_classes=6):
    if not users_data:
        return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

    for _ in range(50):
        user = random.choice(users_data)
        data = user['data']
        labels = user['labels']
        unique_cls = np.unique(labels)

        if len(unique_cls) < n_way:
            continue

        chosen_classes = np.random.choice(unique_cls, n_way, replace=False)
        support_x, support_y, query_x, query_y = [], [], [], []

        valid_episode = True
        for new_c, original_c in enumerate(chosen_classes):
            idxs = np.where(labels == original_c)[0]
            if len(idxs) < k_shot + q_query:
                valid_episode = False
                break

            np.random.shuffle(idxs)
            s_idx = idxs[:k_shot]
            q_idx = idxs[k_shot:k_shot+q_query]

            support_x.extend([data[i] for i in s_idx])
            support_y.extend([new_c] * k_shot)
            query_x.extend([data[i] for i in q_idx])
            query_y.extend([new_c] * q_query)

        if valid_episode:
            if not support_x or not query_x:
                continue
            return (torch.stack(support_x), torch.tensor(support_y),
                    torch.stack(query_x), torch.tensor(query_y))

    return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

def meta_train(model, optimizer, train_users, val_users, n_way_range, k_shot=5, q_query=15,
               episodes=5000, log_every=100, val_every=200, total_classes=6):
    model.train()
    train_losses, train_accs, val_accs = [], [], []

    augmentation_funcs = [
        aug_jitter_scale,
        aug_sensor_failure,
        aug_missing_segment,
        aug_outlier_spike
    ]

    aug_plan = []

    n_clean = int(episodes * 0.4)
    n_aug_per_type = int(episodes * 0.6) // len(augmentation_funcs)

    aug_plan.extend([None] * n_clean)
    for func in augmentation_funcs:
        aug_plan.extend([func] * n_aug_per_type)

    remainder = episodes - len(aug_plan)
    aug_plan.extend([None] * remainder)

    random.shuffle(aug_plan)

    print(f"Training Strategy: Fully shuffled list of {len(aug_plan)} episodes.")
    print(f"(Composition: {n_clean + remainder} Clean, 4x{n_aug_per_type} Augmentations)")

    for ep in range(episodes):
        n_way = random.randint(n_way_range[0], n_way_range[1])

        support_x, support_y, query_x, query_y = create_episodes(train_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue

        if ep < len(aug_plan):
            aug_func = aug_plan[ep]
        else:
            aug_func = None

        if aug_func is None:
            support_x_aug = support_x
            query_x_aug = query_x
        else:
            support_x_aug = aug_func(support_x)
            query_x_aug = aug_func(query_x)

        support_x_aug, support_y = support_x_aug.cuda(), support_y.cuda()
        query_x_aug, query_y = query_x_aug.cuda(), query_y.cuda()

        logits = model(query_x_aug, support_x_aug, support_y, n_way)
        loss = F.cross_entropy(logits, query_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (logits.argmax(1) == query_y).float().mean().item()
        train_losses.append(loss.item())
        train_accs.append(acc)

        if (ep + 1) % log_every == 0:
            print(f"Episode {ep+1:5d} | Loss: {loss.item():.4f} | Train Acc: {acc:.4f}", end="")
            if (ep + 1) % val_every == 0:
                val_acc = meta_validate(model, val_users, k_shot, n_way_range[1], trials=20, total_classes=total_classes)
                val_accs.append(val_acc)
                print(f" | Val Acc: {val_acc:.4f}")
            else:
                print()

    val_episodes = list(range(val_every - 1, episodes, val_every))
    if not val_episodes:
        val_episodes = [episodes - 1] if episodes > 0 else [0]
    if not val_accs:
        val_accs = [0.0]

    val_accs_interpolated = np.interp(range(episodes), val_episodes, val_accs)

    return train_losses, train_accs, val_accs_interpolated

def meta_validate(model, val_users, k_shot=5, n_way=6, trials=20, total_classes=6):
    model.eval()
    correct, total = 0, 0
    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(val_users, n_way, k_shot, 15, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()
        with torch.no_grad():
            logits = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1)
            correct += (preds == query_y).sum().item()
            total += len(query_y)
    model.train()
    return correct / total if total > 0 else 0.0

def meta_test(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        with torch.no_grad():
            logits = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def meta_test_noisy(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, noise_type='jitter', noise_level=0.1, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        query_x_noisy = apply_test_noise(query_x, noise_type, noise_level)

        with torch.no_grad():
            logits = model(query_x_noisy, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def train_supervised(model, train_loader, optimizer, criterion, epochs, device):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_correct = 0
        total_samples = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            logits = model(x_batch)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * x_batch.size(0)
            total_correct += (logits.argmax(1) == y_batch).sum().item()
            total_samples += x_batch.size(0)

        if total_samples == 0:
            avg_loss, avg_acc = 0, 0
        else:
            avg_loss = total_loss / total_samples
            avg_acc = total_correct / total_samples

        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | Train Loss: {avg_loss:.4f} | Train Acc: {avg_acc:.4f}")

def test_supervised(model, test_loader, device, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            logits = model(x_batch)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm

def test_supervised_noisy(model, test_loader, device, noise_type, noise_level, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            x_batch_noisy = apply_test_noise(x_batch, noise_type, noise_level)
            logits = model(x_batch_noisy)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm

def prepare_users(X, y, sub, subs, mean, std):
    users = []
    for uid in subs:
        mask = (sub == uid)
        user_data = X[mask]
        user_labels = y[mask]
        if len(user_data) == 0:
            continue
        user_dataset = HARDataset(user_data, user_labels, norm=False)
        user_dataset.set_stats(mean, std)

        if len(user_dataset) > 0:
            users.append({
                'data': torch.stack([user_dataset[i][0] for i in range(len(user_dataset))]),
                'labels': user_labels,
                'id': uid
            })
    return users

if __name__ == '__main__':
    set_seed(42)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Device: {device}\n")

    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)

    UCI_ROOT = "/content/drive/MyDrive/HAR_Dataset/UCI"
    USC_ROOT = "/content/drive/MyDrive/HAR_Dataset/USC"
    DSADS_ROOT = "/content/drive/MyDrive/HAR_Dataset/DSADS"
    MHEALTH_ROOT = "/content/drive/MyDrive/HAR_Dataset/MHEALTH"

    datasets_to_run = [
        {
            'name': 'DSADS',
            'loader': load_dsads_data,
            'path': DSADS_ROOT,
            'params': {'w_s': 50, 'stride': 25}
        },
        {
            'name': 'UCI-HAR',
            'loader': load_full_uci_har_data,
            'path': UCI_ROOT,
            'params': {}
        },
        {
            'name': 'USC-HAD',
            'loader': load_uschad_data,
            'path': USC_ROOT,
            'params': {'w_s': 100, 'stride': 50}
        },
        {
            'name': 'MHEALTH',
            'loader': load_mhealth_data,
            'path': MHEALTH_ROOT,
            'params': {}
        },
    ]

    noise_conditions_to_test = [
        ('jitter', 0.1), ('jitter', 0.2), ('jitter', 0.3),
        ('time_shift', 0.1), ('time_shift', 0.2), ('time_shift', 0.3),
        ('sensor_failure', 0.1), ('sensor_failure', 0.2), ('sensor_failure', 0.3),
        ('outlier_spike', 0.1), ('outlier_spike', 0.2), ('outlier_spike', 0.3),
        ('missing_segment', 0.1), ('missing_segment', 0.2), ('missing_segment', 0.3)
    ]
    train_k_shots_list = [1, 3, 5]
    meta_models_to_test = [
        ('OriginalProtoNet', OriginalProtoNet),
        ('AttentionWeightedProtoNet', AttentionWeightedProtoNet)
    ]

    N_SPLITS = 3
    EPISODES = 5000
    N_WAY_TRAIN_MIN = 3
    Q_QUERY_TRAIN = 15

    for dataset_info in datasets_to_run:
        dataset_name = dataset_info['name']
        loader_func = dataset_info['loader']
        dataset_path = dataset_info['path']
        loader_params = dataset_info['params']

        print("\n" + "#" * 90)
        print(f"##### STARTING EXPERIMENT FOR DATASET: {dataset_name} #####")
        print("#" * 90 + "\n")

        print("=" * 60)
        print(f"LOADING {dataset_name} DATASET")
        print("=" * 60)
        X_raw, y_raw, sub_raw, labels = loader_func(dataset_path, **loader_params)

        if X_raw is None:
            print(f"Failed to load {dataset_name} data. Check the path: {dataset_path}. Skipping...")
            continue

        print(f"Data shape (N, C, L): {X_raw.shape}")
        print(f"Labels: {labels}")
        unique_subs = np.unique(sub_raw)
        np.random.shuffle(unique_subs)

        print(f"Total subjects: {len(unique_subs)} (IDs: {unique_subs})")
        print(f"Using Subject-wise {N_SPLITS}-Fold Cross-Validation")

        INPUT_CHANNELS = X_raw.shape[1]
        INPUT_LENGTH = X_raw.shape[2]
        TOTAL_CLASSES = len(labels)
        N_WAY_TRAIN_MAX = TOTAL_CLASSES

        print(f"Input Channels: {INPUT_CHANNELS}, Input Length: {INPUT_LENGTH}, Total Classes: {TOTAL_CLASSES}")

        all_folds_final_results = []
        all_folds_stats_results = []

        kf = KFold(n_splits=N_SPLITS)

        for fold_idx, (train_val_idx, test_idx) in enumerate(kf.split(unique_subs)):

            test_subs = unique_subs[test_idx]
            train_val_subs = unique_subs[train_val_idx]

            if len(train_val_subs) < 2:
                print(f"Not enough subjects for train/val split in fold {fold_idx+1}. Skipping.")
                continue

            val_subs = [train_val_subs[0]]
            train_subs = train_val_subs[1:]

            if len(train_subs) == 0 or len(val_subs) == 0 or len(test_subs) == 0:
                print(f"Fold {fold_idx+1} has empty subject splits. Skipping.")
                continue

            print("\n" + "*" * 80)
            print(f"STARTING FOLD {fold_idx+1}/{N_SPLITS} (Dataset: {dataset_name})")
            print(f"Test subjects: {test_subs}")
            print(f"Val subjects:  {val_subs}")
            print(f"Train subjects: {train_subs}")
            print("*" * 80)

            train_mask = np.isin(sub_raw, train_subs)
            val_mask = np.isin(sub_raw, val_subs)
            test_mask = np.isin(sub_raw, test_subs)

            X_train, y_train, sub_train = X_raw[train_mask], y_raw[train_mask], sub_raw[train_mask]
            X_val, y_val, sub_val = X_raw[val_mask], y_raw[val_mask], sub_raw[val_mask]
            X_test, y_test, sub_test = X_raw[test_mask], y_raw[test_mask], sub_raw[test_mask]

            if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
                print(f"Fold {fold_idx+1} has empty data splits (Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}). Skipping.")
                continue

            print(f"Train samples: {len(X_train)}")
            print(f"Val samples: {len(X_val)}")
            print(f"Test samples: {len(X_test)}")

            mean, std = compute_mean_std(X_train)

            train_users = prepare_users(X_train, y_train, sub_train, train_subs, mean, std)
            val_users = prepare_users(X_val, y_val, sub_val, val_subs, mean, std)
            test_users = prepare_users(X_test, y_test, sub_test, test_subs, mean, std)

            if not train_users or not val_users or not test_users:
                print(f"Fold {fold_idx+1} resulted in empty user lists after processing. Skipping.")
                continue

            train_dataset_sup = HARDataset(X_train, y_train, norm=False)
            train_dataset_sup.set_stats(mean, std)
            train_loader_sup = DataLoader(train_dataset_sup, batch_size=512, shuffle=True)

            test_dataset_sup = HARDataset(X_test, y_test, norm=False)
            test_dataset_sup.set_stats(mean, std)
            test_loader_sup = DataLoader(test_dataset_sup, batch_size=512, shuffle=False)

            print("\n" + "=" * 80)
            print(f"PART 1: SUPERVISED BASELINE (Fold {fold_idx+1})")
            print("=" * 80)

            supervised_model = SupervisedBaseline(
                in_channels=INPUT_CHANNELS,
                embed_dim=128,
                num_classes=TOTAL_CLASSES
            ).to(device)

            optimizer_sup = torch.optim.Adam(supervised_model.parameters(), lr=0.001)
            criterion_sup = nn.CrossEntropyLoss()

            print("--- Training Supervised Baseline ---")
            train_supervised(supervised_model, train_loader_sup, optimizer_sup, criterion_sup, epochs=50, device=device)

            print("\n--- Calculating Supervised Model Stats ---")
            sup_params, sup_flops = compute_supervised_stats(supervised_model, input_shape=(INPUT_CHANNELS, INPUT_LENGTH))
            sup_inf_time = measure_supervised_inference_time(supervised_model, input_size=(1, INPUT_CHANNELS, INPUT_LENGTH), device=device)
            print(f"Supervised Stats | Params(M): {sup_params:.2f}, FLOPs(M): {sup_flops:.2f}, Inf. Time(ms): {sup_inf_time:.2f}")

            all_folds_stats_results.append({
                'Model': 'Supervised',
                'K-Shot': 'N/A (Full)',
                'Param (M)': sup_params,
                'FLOPs (M)': sup_flops,
                'Inf. Time (ms)': sup_inf_time
            })

            print("\n--- Testing Supervised Baseline (Clean) ---")
            acc_s, f1_s, prec_s, rec_s, _ = test_supervised(supervised_model, test_loader_sup, device, num_classes=TOTAL_CLASSES)
            print(f"Supervised Clean | Acc: {acc_s:.4f}, F1: {f1_s:.4f}")
            all_folds_final_results.append({
                'Model': 'Supervised',
                'K-Shot': 'N/A (Full)',
                'Noise': 'Clean',
                'Accuracy': acc_s,
                'F1-Score': f1_s,
                'Precision': prec_s,
                'Recall': rec_s
            })

            print("\n--- Testing Supervised Baseline (Robustness) ---")
            for n_type, n_level in noise_conditions_to_test:
                acc_n, f1_n, prec_n, rec_n, _ = test_supervised_noisy(
                    supervised_model, test_loader_sup, device,
                    noise_type=n_type, noise_level=n_level, num_classes=TOTAL_CLASSES
                )
                print(f"Supervised Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
                all_folds_final_results.append({
                    'Model': 'Supervised',
                    'K-Shot': 'N/A (Full)',
                    'Noise': f"{n_type}_{n_level}",
                    'Accuracy': acc_n,
                    'F1-Score': f1_n,
                    'Precision': prec_n,
                    'Recall': rec_n
                })

            del supervised_model, optimizer_sup, criterion_sup
            torch.cuda.empty_cache()

            print("\n" + "=" * 80)
            print(f"PART 2: META-LEARNING (Per K-Shot Training) (Fold {fold_idx+1})")
            print("=" * 80)

            for model_name, model_class in meta_models_to_test:

                print("\n" + "=" * 80)
                print(f"===== STARTING META-TRAINING FOR: {model_name} (Fold {fold_idx+1}) =====")
                print("=" * 80)

                for k_train in train_k_shots_list:
                    print("\n" + "=" * 70)
                    print(f"STARTING {model_name} FOR K-SHOT = {k_train} (Fold {fold_idx+1})")
                    print("=" * 70)

                    K_SHOT_TRAIN = k_train

                    encoder = CompactEncoder(in_channels=INPUT_CHANNELS, embed_dim=128).to(device)
                    meta_model = model_class(encoder, feature_dim=128, temperature=1.0).to(device)
                    optimizer_meta = torch.optim.Adam(meta_model.parameters(), lr=0.001)

                    print(f"--- Calculating Meta Model Stats (Model={model_name}, K={k_train}) ---")
                    meta_enc_params, meta_enc_flops = compute_encoder_stats(encoder, input_shape=(1, INPUT_CHANNELS, INPUT_LENGTH))
                    meta_e2e_inf_time = measure_meta_inference_time(meta_model, n_way=TOTAL_CLASSES, sz=(1, INPUT_CHANNELS, INPUT_LENGTH), dev=device)
                    print(f"Stats-{model_name}-{k_train} | Encoder Params(M): {meta_enc_params:.2f}, Encoder FLOPs(M): {meta_enc_flops:.2f}, E2E Inf. Time(ms): {meta_e2e_inf_time:.2f}")

                    all_folds_stats_results.append({
                        'Model': model_name,
                        'K-Shot': k_train,
                        'Param (M)': meta_enc_params,
                        'FLOPs (M)': meta_enc_flops,
                        'Inf. Time (ms)': meta_e2e_inf_time
                    })

                    print(f"--- Meta-Training (Model={model_name}, K={K_SHOT_TRAIN}, {EPISODES} Episodes) ---")
                    train_losses, train_accs, val_accs = meta_train(
                        meta_model, optimizer_meta, train_users, val_users,
                        n_way_range=(N_WAY_TRAIN_MIN, N_WAY_TRAIN_MAX),
                        k_shot=K_SHOT_TRAIN,
                        q_query=Q_QUERY_TRAIN,
                        episodes=EPISODES,
                        log_every=1000,
                        val_every=1000,
                        total_classes=TOTAL_CLASSES
                    )

                    print(f"\n--- Testing Meta-Learning Model (Model={model_name}, K={k_train}) ---")

                    print(f"Test-{model_name}-{k_train}-Shot (Clean) | Testing...")
                    acc_m, f1_m, prec_m, rec_m, _ = meta_test(
                        meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES,
                        q_query=15, trials=250, total_classes=TOTAL_CLASSES
                    )
                    print(f"Test-{model_name}-{k_train}-Shot (Clean) | Acc: {acc_m:.4f}, F1: {f1_m:.4f}")
                    all_folds_final_results.append({
                        'Model': model_name,
                        'K-Shot': k_train,
                        'Noise': 'Clean',
                        'Accuracy': acc_m,
                        'F1-Score': f1_m,
                        'Precision': prec_m,
                        'Recall': rec_m
                    })

                    for n_type, n_level in noise_conditions_to_test:
                        acc_n, f1_n, prec_n, rec_n, _ = meta_test_noisy(
                            meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES, q_query=15,
                            trials=400, noise_type=n_type, noise_level=n_level,
                            total_classes=TOTAL_CLASSES
                        )
                        print(f"Test-{model_name}-{k_train}-Shot Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
                        all_folds_final_results.append({
                            'Model': model_name,
                            'K-Shot': k_train,
                            'Noise': f"{n_type}_{n_level}",
                            'Accuracy': acc_n,
                            'F1-Score': f1_n,
                            'Precision': prec_n,
                            'Recall': rec_n
                        })

                    del encoder, meta_model, optimizer_meta
                    torch.cuda.empty_cache()

        if not all_folds_final_results:
            print(f"No results generated for dataset {dataset_name}. Skipping aggregation.")
            continue

        print("\n" + "=" * 80)
        print(f"===== FINAL AGGREGATED RESULTS FOR: {dataset_name} =====")
        print(f"(Averaged over {N_SPLITS} Subject-wise folds)")
        print("=" * 80)

        final_df = pd.DataFrame(all_folds_final_results)
        grouped = final_df.groupby(['Model', 'K-Shot', 'Noise'])

        avg_final_df = grouped.mean().reset_index()
        std_final_df = grouped.std().reset_index()

        merged_df = pd.merge(
            avg_final_df,
            std_final_df,
            on=['Model', 'K-Shot', 'Noise'],
            suffixes=('_mean', '_std'),
            how='left'
        )

        metric_cols = ['Accuracy', 'F1-Score', 'Precision', 'Recall']
        display_df = merged_df[['Model', 'K-Shot', 'Noise']].copy()

        for col in metric_cols:
            display_df[col] = merged_df.apply(
                lambda row: f"{row[col + '_mean']:.4f} ± {row[col + '_std']:.4f}",
                axis=1
            )

        display(display_df)

        print("\n" + "=" * 80)
        print(f"===== PIVOT TABLE: ACCURACY ({dataset_name}) =====")
        print("=" * 80)

        pivot_acc_str = display_df.pivot_table(
            index='Noise',
            columns=['Model', 'K-Shot'],
            values='Accuracy',
            aggfunc='first'
        )

        cols_order = [
            ('Supervised', 'N/A (Full)'),
            ('OriginalProtoNet', 1),
            ('OriginalProtoNet', 3),
            ('OriginalProtoNet', 5),
            ('AttentionWeightedProtoNet', 1),
            ('AttentionWeightedProtoNet', 3),
            ('AttentionWeightedProtoNet', 5)
        ]

        cols_present = [c for c in cols_order if c in pivot_acc_str.columns]
        pivot_acc_str = pivot_acc_str[cols_present]
        display(pivot_acc_str)


        print("\n" + "=" * 80)
        print(f"===== PIVOT TABLE: F1-SCORE ({dataset_name}) =====")
        print("=" * 80)

        pivot_f1_str = display_df.pivot_table(
            index='Noise',
            columns=['Model', 'K-Shot'],
            values='F1-Score',
            aggfunc='first'
        )

        cols_present_f1 = [c for c in cols_order if c in pivot_f1_str.columns]
        pivot_f1_str = pivot_f1_str[cols_present_f1]
        display(pivot_f1_str)

        print("\n" + "=" * 80)
        print(f"===== MODEL STATISTICS ({dataset_name}) =====")
        print("=" * 80)

        stats_df = pd.DataFrame(all_folds_stats_results)
        stats_grouped = stats_df.groupby(['Model', 'K-Shot'])

        avg_stats_df = stats_grouped.mean()
        std_stats_df = stats_grouped.std().fillna(0)

        display_stats_df = pd.DataFrame(index=avg_stats_df.index)
        stats_cols = ['Param (M)', 'FLOPs (M)', 'Inf. Time (ms)']

        for col in stats_cols:
            mean = avg_stats_df[col]
            std = std_stats_df[col]
            display_stats_df[col] = mean.combine(std, lambda m, s: f"{m:.2f} ± {s:.2f}")

        display(display_stats_df)


        print("\n" + "=" * 80)
        print(f"===== K-SHOT PERFORMANCE COMPARISON (F1-SCORE) ({dataset_name}) =====")
        print("=" * 80)

        df_clean_mean = avg_final_df[avg_final_df['Noise'] == 'Clean'].copy()
        df_clean_std = std_final_df[std_final_df['Noise'] == 'Clean'].copy()

        df_clean = pd.merge(
            df_clean_mean,
            df_clean_std,
            on=['Model', 'K-Shot', 'Noise'],
            suffixes=('_mean', '_std'),
            how='left'
        )

        f1_supervised_mean = 0.0
        f1_supervised_std = 0.0

        sup_data = df_clean[df_clean['Model'] == 'Supervised']
        if not sup_data.empty:
            f1_supervised_mean = sup_data['F1-Score_mean'].values[0]
            f1_supervised_std = sup_data['F1-Score_std'].values[0]

        k_shots_numeric = sorted(df_clean[df_clean['Model'] != 'Supervised']['K-Shot'].unique())
        if not k_shots_numeric:
            k_shots_numeric = [1, 3, 5]

        k_shots_present = [k for k in train_k_shots_list if k in k_shots_numeric]

        df_sup_line = pd.DataFrame({
            'Model': 'Supervised',
            'K-Shot': k_shots_present,
            'F1-Score_mean': f1_supervised_mean,
            'F1-Score_std': f1_supervised_std
        })

        df_meta = df_clean[df_clean['Model'] != 'Supervised']
        plot_df = pd.concat([df_meta, df_sup_line])

        plt.figure(figsize=(7, 4.5))

        models_to_plot = plot_df['Model'].unique()

        for model in models_to_plot:
            model_df = plot_df[plot_df['Model'] == model]
            plt.errorbar(
                model_df['K-Shot'],
                model_df['F1-Score_mean'],
                yerr=model_df['F1-Score_std'],
                label=model,
                marker='o',
                capsize=5,
                markersize=8,
                linewidth=2
            )

        plt.title(f'{dataset_name}: Model F1-Score vs. K-Shot (Clean Data)', fontsize=14)
        plt.xlabel('K-Shot', fontsize=12)
        plt.ylabel('F1-Score (Mean ± Std)', fontsize=12)
        plt.xticks(k_shots_present)
        plt.grid(True, linestyle='--', alpha=0.4)
        plt.legend(title='Model')
        plt.tight_layout()
        plt.show()

    print("\n" + "#" * 90)
    print("##### ALL DATASET EXPERIMENTS COMPLETE #####")
    print("#" * 90)
# Out:
# <>:546: SyntaxWarning: invalid escape sequence '\s'
# <>:546: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2230125046.py:546: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
# Device: cuda
#
#
# ##########################################################################################
# ##### STARTING EXPERIMENT FOR DATASET: DSADS #####
# ##########################################################################################
#
# ============================================================
# LOADING DSADS DATASET
# ============================================================
# Loading DSADS data with window=50, stride=25
#
# ==================================================
# Per-Subject Class Distribution (Window Count)
# ==================================================
#          sitting  standing  lying on back  lying on right side  ascending stairs  descending stairs  standing in an elevator still  moving around in an elevator  walking in a parking lot  walking on a treadmill with a speed of 4 kmh  walking in flat and 15 deg inclined positions  running on a treadmill with a speed of 8 kmh  exercising on a stepper  exercising on a cross trainer  cycling on an exercise bike in horizontal positions  cycling on an exercise bike in vertical positions  rowing  jumping  playing basketball  Total
# Subject
# S1            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S2            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S3            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S4            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S5            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S6            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S7            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# S8            44        44             44                   44                44                 44                             44                            44                        44                                            44                                             44                                            44                       44                             44                                                 44                                                   44      44       44                  44    836
# ==================================================
#
# Data shape (N, C, L): (6688, 45, 50)
# Labels: ['sitting', 'standing', 'lying on back', 'lying on right side', 'ascending stairs', 'descending stairs', 'standing in an elevator still', 'moving around in an elevator', 'walking in a parking lot', 'walking on a treadmill with a speed of 4 kmh', 'walking in flat and 15 deg inclined positions', 'running on a treadmill with a speed of 8 kmh', 'exercising on a stepper', 'exercising on a cross trainer', 'cycling on an exercise bike in horizontal positions', 'cycling on an exercise bike in vertical positions', 'rowing', 'jumping', 'playing basketball']
# Total subjects: 8 (IDs: [2 6 1 8 3 5 4 7])
# Using Subject-wise 3-Fold Cross-Validation
# Input Channels: 45, Input Length: 50, Total Classes: 19
#
# ********************************************************************************
# STARTING FOLD 1/3 (Dataset: DSADS)
# Test subjects: [2 6 1]
# Val subjects:  [np.int64(8)]
# Train subjects: [3 5 4 7]
# ********************************************************************************
# Train samples: 3344
# Val samples: 836
# Test samples: 2508
#
# ================================================================================
# PART 1: SUPERVISED BASELINE (Fold 1)
# ================================================================================
# --- Training Supervised Baseline ---
# Epoch  10/50 | Train Loss: 0.0518 | Train Acc: 0.9943
# Epoch  20/50 | Train Loss: 0.0262 | Train Acc: 0.9952
# Epoch  30/50 | Train Loss: 0.0279 | Train Acc: 0.9937
# Epoch  40/50 | Train Loss: 0.0058 | Train Acc: 0.9994
# Epoch  50/50 | Train Loss: 0.0021 | Train Acc: 1.0000
#
# --- Calculating Supervised Model Stats ---
# Supervised Stats | Params(M): 0.37, FLOPs(M): 2.52, Inf. Time(ms): 1.17
#
# --- Testing Supervised Baseline (Clean) ---
# Supervised Clean | Acc: 0.7209, F1: 0.7030
#
# --- Testing Supervised Baseline (Robustness) ---
# Supervised Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.7213, F1: 0.7044
# Supervised Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.7233, F1: 0.7061
# Supervised Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.7153, F1: 0.6948
# Supervised Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.7213, F1: 0.7040
# Supervised Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.7173, F1: 0.6990
# Supervised Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.6998, F1: 0.6783
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.6647, F1: 0.6316
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.5283, F1: 0.4903
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4442, F1: 0.4037
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.7141, F1: 0.6925
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.7137, F1: 0.6903
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.7117, F1: 0.6857
# Supervised Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.7010, F1: 0.6794
# Supervised Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.6611, F1: 0.6299
# Supervised Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6180, F1: 0.5942
#
# ================================================================================
# PART 2: META-LEARNING (Per K-Shot Training) (Fold 1)
# ================================================================================
#
# ================================================================================
# ===== STARTING META-TRAINING FOR: OriginalProtoNet (Fold 1) =====
# ================================================================================
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 1 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=1) ---
# Stats-OriginalProtoNet-1 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 5.52
# --- Meta-Training (Model=OriginalProtoNet, K=1, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.1093 | Train Acc: 0.9500 | Val Acc: 0.8440
# Episode  2000 | Loss: 0.1118 | Train Acc: 0.9556 | Val Acc: 0.8063
# Episode  3000 | Loss: 0.1106 | Train Acc: 0.9422 | Val Acc: 0.8225
# Episode  4000 | Loss: 0.4620 | Train Acc: 0.9556 | Val Acc: 0.8349
# Episode  5000 | Loss: 0.0268 | Train Acc: 1.0000 | Val Acc: 0.8286
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=1) ---
# Test-OriginalProtoNet-1-Shot (Clean) | Testing...
# Test-OriginalProtoNet-1-Shot (Clean) | Acc: 0.8801, F1: 0.8801
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8828, F1: 0.8828
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8829, F1: 0.8829
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8783, F1: 0.8783
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8822, F1: 0.8822
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8602, F1: 0.8602
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8050, F1: 0.8050
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7243, F1: 0.7243
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6046, F1: 0.6047
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4741, F1: 0.4741
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8790, F1: 0.8790
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8665, F1: 0.8665
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8504, F1: 0.8504
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8533, F1: 0.8533
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.6654, F1: 0.6653
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.4899, F1: 0.4900
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 3 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=3) ---
# Stats-OriginalProtoNet-3 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 5.56
# --- Meta-Training (Model=OriginalProtoNet, K=3, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0761 | Train Acc: 0.9778 | Val Acc: 0.8751
# Episode  2000 | Loss: 0.1051 | Train Acc: 0.9905 | Val Acc: 0.8574
# Episode  3000 | Loss: 0.0424 | Train Acc: 0.9846 | Val Acc: 0.8814
# Episode  4000 | Loss: 0.0277 | Train Acc: 0.9961 | Val Acc: 0.8954
# Episode  5000 | Loss: 0.0300 | Train Acc: 0.9939 | Val Acc: 0.9128
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=3) ---
# Test-OriginalProtoNet-3-Shot (Clean) | Testing...
# Test-OriginalProtoNet-3-Shot (Clean) | Acc: 0.9338, F1: 0.9338
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9308, F1: 0.9308
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9330, F1: 0.9330
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9231, F1: 0.9231
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9292, F1: 0.9292
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9153, F1: 0.9153
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8834, F1: 0.8834
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7581, F1: 0.7581
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6254, F1: 0.6254
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5029, F1: 0.5029
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9249, F1: 0.9249
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9121, F1: 0.9121
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.9001, F1: 0.9001
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8906, F1: 0.8907
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7929, F1: 0.7929
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6230, F1: 0.6230
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 5 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=5) ---
# Stats-OriginalProtoNet-5 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 5.61
# --- Meta-Training (Model=OriginalProtoNet, K=5, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0562 | Train Acc: 0.9758 | Val Acc: 0.8784
# Episode  2000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.8774
# Episode  3000 | Loss: 0.0001 | Train Acc: 1.0000 | Val Acc: 0.9172
# Episode  4000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.8807
# Episode  5000 | Loss: 0.1754 | Train Acc: 0.9704 | Val Acc: 0.9084
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=5) ---
# Test-OriginalProtoNet-5-Shot (Clean) | Testing...
# Test-OriginalProtoNet-5-Shot (Clean) | Acc: 0.8499, F1: 0.8498
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8508, F1: 0.8508
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8495, F1: 0.8495
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8442, F1: 0.8441
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8516, F1: 0.8516
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8341, F1: 0.8340
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8006, F1: 0.8006
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7244, F1: 0.7245
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6119, F1: 0.6118
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4694, F1: 0.4693
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8478, F1: 0.8477
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8387, F1: 0.8387
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8300, F1: 0.8300
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8129, F1: 0.8129
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.6898, F1: 0.6897
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5161, F1: 0.5160
#
# ================================================================================
# ===== STARTING META-TRAINING FOR: AttentionWeightedProtoNet (Fold 1) =====
# ================================================================================
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 1 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=1) ---
# Stats-AttentionWeightedProtoNet-1 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 8.68
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=1, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.3421 | Train Acc: 0.8588 | Val Acc: 0.8268
# Episode  2000 | Loss: 0.6171 | Train Acc: 0.8485 | Val Acc: 0.8339
# Episode  3000 | Loss: 0.0406 | Train Acc: 1.0000 | Val Acc: 0.8249
# Episode  4000 | Loss: 0.1960 | Train Acc: 0.9833 | Val Acc: 0.8684
# Episode  5000 | Loss: 0.0480 | Train Acc: 0.9926 | Val Acc: 0.8984
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=1) ---
# Test-AttentionWeightedProtoNet-1-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-1-Shot (Clean) | Acc: 0.9185, F1: 0.9185
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9167, F1: 0.9167
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9161, F1: 0.9161
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9103, F1: 0.9103
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9125, F1: 0.9125
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9077, F1: 0.9077
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8709, F1: 0.8709
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7903, F1: 0.7904
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6573, F1: 0.6572
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5096, F1: 0.5095
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9084, F1: 0.9084
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8999, F1: 0.8999
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8904, F1: 0.8904
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8996, F1: 0.8996
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7654, F1: 0.7654
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5583, F1: 0.5581
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 3 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=3) ---
# Stats-AttentionWeightedProtoNet-3 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 8.72
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=3, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.1607 | Train Acc: 0.9255 | Val Acc: 0.8718
# Episode  2000 | Loss: 0.0985 | Train Acc: 0.9429 | Val Acc: 0.8598
# Episode  3000 | Loss: 0.1281 | Train Acc: 0.9644 | Val Acc: 0.8761
# Episode  4000 | Loss: 0.0004 | Train Acc: 1.0000 | Val Acc: 0.8442
# Episode  5000 | Loss: 0.1917 | Train Acc: 0.9579 | Val Acc: 0.8632
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=3) ---
# Test-AttentionWeightedProtoNet-3-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-3-Shot (Clean) | Acc: 0.8855, F1: 0.8855
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8848, F1: 0.8847
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8845, F1: 0.8844
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8782, F1: 0.8782
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8856, F1: 0.8856
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8706, F1: 0.8706
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8405, F1: 0.8405
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7132, F1: 0.7132
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.5763, F1: 0.5761
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4474, F1: 0.4473
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8778, F1: 0.8778
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8669, F1: 0.8669
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8571, F1: 0.8571
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8501, F1: 0.8501
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7162, F1: 0.7161
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5165, F1: 0.5165
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 5 (Fold 1)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=5) ---
# Stats-AttentionWeightedProtoNet-5 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 9.28
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=5, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.1940 | Train Acc: 0.9556 | Val Acc: 0.8311
# Episode  2000 | Loss: 0.0157 | Train Acc: 1.0000 | Val Acc: 0.9104
# Episode  3000 | Loss: 0.1095 | Train Acc: 0.9792 | Val Acc: 0.9053
# Episode  4000 | Loss: 0.0003 | Train Acc: 1.0000 | Val Acc: 0.9184
# Episode  5000 | Loss: 0.0127 | Train Acc: 0.9933 | Val Acc: 0.9235
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=5) ---
# Test-AttentionWeightedProtoNet-5-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-5-Shot (Clean) | Acc: 0.9040, F1: 0.9040
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9037, F1: 0.9037
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9015, F1: 0.9015
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8967, F1: 0.8967
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8990, F1: 0.8990
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8874, F1: 0.8875
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8517, F1: 0.8517
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7521, F1: 0.7521
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6193, F1: 0.6192
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4638, F1: 0.4638
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8954, F1: 0.8954
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8824, F1: 0.8824
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8723, F1: 0.8723
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8607, F1: 0.8607
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7111, F1: 0.7111
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5098, F1: 0.5098
#
# ********************************************************************************
# STARTING FOLD 2/3 (Dataset: DSADS)
# Test subjects: [8 3 5]
# Val subjects:  [np.int64(2)]
# Train subjects: [6 1 4 7]
# ********************************************************************************
# Train samples: 3344
# Val samples: 836
# Test samples: 2508
#
# ================================================================================
# PART 1: SUPERVISED BASELINE (Fold 2)
# ================================================================================
# --- Training Supervised Baseline ---
# Epoch  10/50 | Train Loss: 0.0443 | Train Acc: 0.9982
# Epoch  20/50 | Train Loss: 0.0253 | Train Acc: 0.9979
# Epoch  30/50 | Train Loss: 0.0374 | Train Acc: 0.9913
# Epoch  40/50 | Train Loss: 0.0044 | Train Acc: 1.0000
# Epoch  50/50 | Train Loss: 0.0026 | Train Acc: 0.9997
#
# --- Calculating Supervised Model Stats ---
# Supervised Stats | Params(M): 0.37, FLOPs(M): 2.52, Inf. Time(ms): 1.24
#
# --- Testing Supervised Baseline (Clean) ---
# Supervised Clean | Acc: 0.7217, F1: 0.6978
#
# --- Testing Supervised Baseline (Robustness) ---
# Supervised Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.7185, F1: 0.6942
# Supervised Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.7133, F1: 0.6884
# Supervised Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.7081, F1: 0.6813
# Supervised Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.7185, F1: 0.6943
# Supervised Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.7089, F1: 0.6854
# Supervised Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.6978, F1: 0.6746
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.6906, F1: 0.6726
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.5279, F1: 0.5142
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4270, F1: 0.4231
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.7189, F1: 0.6900
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.6994, F1: 0.6707
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.6719, F1: 0.6431
# Supervised Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.6962, F1: 0.6733
# Supervised Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.6611, F1: 0.6370
# Supervised Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5550, F1: 0.5415
#
# ================================================================================
# PART 2: META-LEARNING (Per K-Shot Training) (Fold 2)
# ================================================================================
#
# ================================================================================
# ===== STARTING META-TRAINING FOR: OriginalProtoNet (Fold 2) =====
# ================================================================================
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 1 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=1) ---
# Stats-OriginalProtoNet-1 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 5.85
# --- Meta-Training (Model=OriginalProtoNet, K=1, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.1066 | Train Acc: 0.9750 | Val Acc: 0.8953
# Episode  2000 | Loss: 0.0647 | Train Acc: 0.9905 | Val Acc: 0.8575
# Episode  3000 | Loss: 0.0399 | Train Acc: 0.9926 | Val Acc: 0.8984
# Episode  4000 | Loss: 0.0570 | Train Acc: 0.9882 | Val Acc: 0.9316
# Episode  5000 | Loss: 0.0503 | Train Acc: 0.9795 | Val Acc: 0.9440
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=1) ---
# Test-OriginalProtoNet-1-Shot (Clean) | Testing...
# Test-OriginalProtoNet-1-Shot (Clean) | Acc: 0.9084, F1: 0.9084
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9074, F1: 0.9074
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9065, F1: 0.9065
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9057, F1: 0.9057
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9087, F1: 0.9086
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9057, F1: 0.9057
# Test-OriginalProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8854, F1: 0.8854
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7917, F1: 0.7917
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6820, F1: 0.6819
# Test-OriginalProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5495, F1: 0.5496
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9035, F1: 0.9035
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8965, F1: 0.8965
# Test-OriginalProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8854, F1: 0.8854
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8928, F1: 0.8928
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8275, F1: 0.8275
# Test-OriginalProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6702, F1: 0.6702
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 3 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=3) ---
# Stats-OriginalProtoNet-3 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 6.19
# --- Meta-Training (Model=OriginalProtoNet, K=3, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0853 | Train Acc: 0.9667 | Val Acc: 0.9282
# Episode  2000 | Loss: 0.0418 | Train Acc: 1.0000 | Val Acc: 0.9135
# Episode  3000 | Loss: 0.0104 | Train Acc: 1.0000 | Val Acc: 0.9460
# Episode  4000 | Loss: 0.0424 | Train Acc: 0.9810 | Val Acc: 0.9567
# Episode  5000 | Loss: 0.0397 | Train Acc: 0.9917 | Val Acc: 0.9635
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=3) ---
# Test-OriginalProtoNet-3-Shot (Clean) | Testing...
# Test-OriginalProtoNet-3-Shot (Clean) | Acc: 0.9115, F1: 0.9115
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9150, F1: 0.9150
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9133, F1: 0.9133
# Test-OriginalProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9098, F1: 0.9098
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9094, F1: 0.9094
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9084, F1: 0.9084
# Test-OriginalProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8910, F1: 0.8910
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7658, F1: 0.7659
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6638, F1: 0.6639
# Test-OriginalProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5468, F1: 0.5467
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9044, F1: 0.9044
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8984, F1: 0.8984
# Test-OriginalProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8877, F1: 0.8877
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8990, F1: 0.8990
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8497, F1: 0.8496
# Test-OriginalProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7060, F1: 0.7060
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 5 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=5) ---
# Stats-OriginalProtoNet-5 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 6.65
# --- Meta-Training (Model=OriginalProtoNet, K=5, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0476 | Train Acc: 0.9833 | Val Acc: 0.8875
# Episode  2000 | Loss: 0.0008 | Train Acc: 1.0000 | Val Acc: 0.9604
# Episode  3000 | Loss: 0.1035 | Train Acc: 0.9576 | Val Acc: 0.9391
# Episode  4000 | Loss: 0.0007 | Train Acc: 1.0000 | Val Acc: 0.9589
# Episode  5000 | Loss: 0.1729 | Train Acc: 0.9429 | Val Acc: 0.9682
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=5) ---
# Test-OriginalProtoNet-5-Shot (Clean) | Testing...
# Test-OriginalProtoNet-5-Shot (Clean) | Acc: 0.9262, F1: 0.9262
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9260, F1: 0.9260
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9237, F1: 0.9237
# Test-OriginalProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9229, F1: 0.9229
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9226, F1: 0.9226
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9136, F1: 0.9136
# Test-OriginalProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8957, F1: 0.8957
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8015, F1: 0.8015
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6955, F1: 0.6955
# Test-OriginalProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5572, F1: 0.5571
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9203, F1: 0.9203
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9113, F1: 0.9113
# Test-OriginalProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.9058, F1: 0.9058
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8970, F1: 0.8970
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8234, F1: 0.8233
# Test-OriginalProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6580, F1: 0.6580
#
# ================================================================================
# ===== STARTING META-TRAINING FOR: AttentionWeightedProtoNet (Fold 2) =====
# ================================================================================
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 1 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=1) ---
# Stats-AttentionWeightedProtoNet-1 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 9.05
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=1, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.3926 | Train Acc: 0.9133 | Val Acc: 0.8982
# Episode  2000 | Loss: 0.0454 | Train Acc: 0.9810 | Val Acc: 0.9326
# Episode  3000 | Loss: 0.0853 | Train Acc: 0.9944 | Val Acc: 0.9388
# Episode  4000 | Loss: 0.0820 | Train Acc: 0.9733 | Val Acc: 0.8995
# Episode  5000 | Loss: 0.0022 | Train Acc: 1.0000 | Val Acc: 0.9098
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=1) ---
# Test-AttentionWeightedProtoNet-1-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-1-Shot (Clean) | Acc: 0.8789, F1: 0.8788
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8798, F1: 0.8798
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8707, F1: 0.8707
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8772, F1: 0.8772
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8776, F1: 0.8776
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8733, F1: 0.8733
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8515, F1: 0.8515
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7681, F1: 0.7681
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6461, F1: 0.6461
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5164, F1: 0.5164
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8695, F1: 0.8695
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8698, F1: 0.8698
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8587, F1: 0.8587
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8526, F1: 0.8526
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7712, F1: 0.7712
# Test-AttentionWeightedProtoNet-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6791, F1: 0.6790
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 3 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=3) ---
# Stats-AttentionWeightedProtoNet-3 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 9.13
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=3, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0713 | Train Acc: 0.9762 | Val Acc: 0.9340
# Episode  2000 | Loss: 0.0195 | Train Acc: 0.9922 | Val Acc: 0.9596
# Episode  3000 | Loss: 0.0487 | Train Acc: 0.9833 | Val Acc: 0.9740
# Episode  4000 | Loss: 0.2012 | Train Acc: 0.9500 | Val Acc: 0.9496
# Episode  5000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.9519
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=3) ---
# Test-AttentionWeightedProtoNet-3-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-3-Shot (Clean) | Acc: 0.9037, F1: 0.9037
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9025, F1: 0.9025
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8983, F1: 0.8983
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8945, F1: 0.8945
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8959, F1: 0.8959
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8920, F1: 0.8920
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8687, F1: 0.8687
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7462, F1: 0.7462
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6466, F1: 0.6466
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5302, F1: 0.5301
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8896, F1: 0.8896
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8850, F1: 0.8850
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8746, F1: 0.8746
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8781, F1: 0.8782
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8168, F1: 0.8168
# Test-AttentionWeightedProtoNet-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7044, F1: 0.7044
#
# ======================================================================
# STARTING AttentionWeightedProtoNet FOR K-SHOT = 5 (Fold 2)
# ======================================================================
# --- Calculating Meta Model Stats (Model=AttentionWeightedProtoNet, K=5) ---
# Stats-AttentionWeightedProtoNet-5 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 8.86
# --- Meta-Training (Model=AttentionWeightedProtoNet, K=5, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.0096 | Train Acc: 0.9905 | Val Acc: 0.9461
# Episode  2000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.9544
# Episode  3000 | Loss: 0.0609 | Train Acc: 0.9778 | Val Acc: 0.8660
# Episode  4000 | Loss: 0.0450 | Train Acc: 0.9818 | Val Acc: 0.9716
# Episode  5000 | Loss: 0.0354 | Train Acc: 1.0000 | Val Acc: 0.9832
#
# --- Testing Meta-Learning Model (Model=AttentionWeightedProtoNet, K=5) ---
# Test-AttentionWeightedProtoNet-5-Shot (Clean) | Testing...
# Test-AttentionWeightedProtoNet-5-Shot (Clean) | Acc: 0.9182, F1: 0.9182
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9192, F1: 0.9192
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9129, F1: 0.9129
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9108, F1: 0.9108
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9183, F1: 0.9183
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9093, F1: 0.9093
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8709, F1: 0.8709
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7643, F1: 0.7643
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6472, F1: 0.6472
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.4763, F1: 0.4761
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9071, F1: 0.9071
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8939, F1: 0.8939
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8824, F1: 0.8824
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8886, F1: 0.8886
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7868, F1: 0.7868
# Test-AttentionWeightedProtoNet-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6286, F1: 0.6285
#
# ********************************************************************************
# STARTING FOLD 3/3 (Dataset: DSADS)
# Test subjects: [4 7]
# Val subjects:  [np.int64(2)]
# Train subjects: [6 1 8 3 5]
# ********************************************************************************
# Train samples: 4180
# Val samples: 836
# Test samples: 1672
#
# ================================================================================
# PART 1: SUPERVISED BASELINE (Fold 3)
# ================================================================================
# --- Training Supervised Baseline ---
# Epoch  10/50 | Train Loss: 0.0992 | Train Acc: 0.9785
# Epoch  20/50 | Train Loss: 0.0348 | Train Acc: 0.9904
# Epoch  30/50 | Train Loss: 0.0164 | Train Acc: 0.9959
# Epoch  40/50 | Train Loss: 0.0153 | Train Acc: 0.9967
# Epoch  50/50 | Train Loss: 0.0362 | Train Acc: 0.9902
#
# --- Calculating Supervised Model Stats ---
# Supervised Stats | Params(M): 0.37, FLOPs(M): 2.52, Inf. Time(ms): 1.25
#
# --- Testing Supervised Baseline (Clean) ---
# Supervised Clean | Acc: 0.7093, F1: 0.6860
#
# --- Testing Supervised Baseline (Robustness) ---
# Supervised Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.7117, F1: 0.6881
# Supervised Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.7039, F1: 0.6789
# Supervised Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.7045, F1: 0.6837
# Supervised Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.7141, F1: 0.6917
# Supervised Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.7099, F1: 0.6865
# Supervised Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.6962, F1: 0.6743
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.6441, F1: 0.6205
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.5819, F1: 0.5533
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5359, F1: 0.5061
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.7028, F1: 0.6786
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.6830, F1: 0.6562
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.6776, F1: 0.6526
# Supervised Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.6639, F1: 0.6371
# Supervised Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.6190, F1: 0.5830
# Supervised Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.5634, F1: 0.5336
#
# ================================================================================
# PART 2: META-LEARNING (Per K-Shot Training) (Fold 3)
# ================================================================================
#
# ================================================================================
# ===== STARTING META-TRAINING FOR: OriginalProtoNet (Fold 3) =====
# ================================================================================
#
# ======================================================================
# STARTING OriginalProtoNet FOR K-SHOT = 1 (Fold 3)
# ======================================================================
# --- Calculating Meta Model Stats (Model=OriginalProtoNet, K=1) ---
# Stats-OriginalProtoNet-1 | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.52, E2E Inf. Time(ms): 5.43
# --- Meta-Training (Model=OriginalProtoNet, K=1, 5000 Episodes) ---
# Training Strategy: Fully shuffled list of 5000 episodes.
# (Composition: 2000 Clean, 4x750 Augmentations)
# Episode  1000 | Loss: 0.1512 | Train Acc: 0.8923 | Val Acc: 0.8691
# Episode  2000 | Loss: 0.0171 | Train Acc: 0.9905 | Val Acc: 0.8649
# Episode  3000 | Loss: 0.0089 | Train Acc: 1.0000 | Val Acc: 0.9877
# Episode  4000 | Loss: 0.0039 | Train Acc: 1.0000 | Val Acc: 0.9384
# Episode  5000 | Loss: 0.0478 | Train Acc: 0.9961 | Val Acc: 0.9618
#
# --- Testing Meta-Learning Model (Model=OriginalProtoNet, K=1) ---
# Test-OriginalProtoNet-1-Shot (Clean) | Testing...
# Test-OriginalProtoNet-1-Shot (Clean) | Acc: 0.8860, F1: 0.8860
# Test-OriginalProtoNet-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8862, F1: 0.8862
# ...
# 47   AttentionWeightedProtoNet           5       time_shift_0.3  0.8998 ± 0.0658  0.8998 ± 0.0658  0.8998 ± 0.0657  0.8998 ± 0.0658
# 48            OriginalProtoNet           1                Clean  0.9060 ± 0.0603  0.9060 ± 0.0604  0.9061 ± 0.0603  0.9060 ± 0.0603
# 49            OriginalProtoNet           1           jitter_0.1  0.9048 ± 0.0619  0.9048 ± 0.0619  0.9048 ± 0.0619  0.9048 ± 0.0619
# 50            OriginalProtoNet           1           jitter_0.2  0.9033 ± 0.0607  0.9033 ± 0.0607  0.9033 ± 0.0607  0.9033 ± 0.0607
# 51            OriginalProtoNet           1           jitter_0.3  0.9015 ± 0.0608  0.9015 ± 0.0608  0.9015 ± 0.0608  0.9015 ± 0.0608
# 52            OriginalProtoNet           1  missing_segment_0.1  0.8948 ± 0.0624  0.8948 ± 0.0624  0.8949 ± 0.0624  0.8948 ± 0.0624
# 53            OriginalProtoNet           1  missing_segment_0.2  0.8526 ± 0.0724  0.8526 ± 0.0724  0.8527 ± 0.0723  0.8526 ± 0.0724
# 54            OriginalProtoNet           1  missing_segment_0.3  0.7665 ± 0.1013  0.7664 ± 0.1014  0.7666 ± 0.1013  0.7665 ± 0.1013
# 55            OriginalProtoNet           1    outlier_spike_0.1  0.8855 ± 0.0648  0.8855 ± 0.0647  0.8856 ± 0.0647  0.8855 ± 0.0648
# 56            OriginalProtoNet           1    outlier_spike_0.2  0.8586 ± 0.0698  0.8586 ± 0.0699  0.8586 ± 0.0698  0.8586 ± 0.0698
# 57            OriginalProtoNet           1    outlier_spike_0.3  0.8263 ± 0.0804  0.8263 ± 0.0804  0.8264 ± 0.0804  0.8263 ± 0.0804
# 58            OriginalProtoNet           1   sensor_failure_0.1  0.7922 ± 0.0706  0.7922 ± 0.0706  0.7924 ± 0.0705  0.7922 ± 0.0706
# 59            OriginalProtoNet           1   sensor_failure_0.2  0.7121 ± 0.0714  0.7121 ± 0.0714  0.7123 ± 0.0714  0.7121 ± 0.0714
# 60            OriginalProtoNet           1   sensor_failure_0.3  0.6064 ± 0.0665  0.6064 ± 0.0665  0.6068 ± 0.0664  0.6064 ± 0.0665
# 61            OriginalProtoNet           1       time_shift_0.1  0.9038 ± 0.0614  0.9037 ± 0.0615  0.9038 ± 0.0614  0.9038 ± 0.0614
# 62            OriginalProtoNet           1       time_shift_0.2  0.8939 ± 0.0676  0.8939 ± 0.0676  0.8939 ± 0.0676  0.8939 ± 0.0676
# 63            OriginalProtoNet           1       time_shift_0.3  0.8797 ± 0.0662  0.8797 ± 0.0662  0.8798 ± 0.0662  0.8797 ± 0.0662
# 64            OriginalProtoNet           3                Clean  0.9395 ± 0.0198  0.9395 ± 0.0198  0.9395 ± 0.0197  0.9395 ± 0.0198
# 65            OriginalProtoNet           3           jitter_0.1  0.9371 ± 0.0237  0.9371 ± 0.0237  0.9372 ± 0.0237  0.9371 ± 0.0237
# 66            OriginalProtoNet           3           jitter_0.2  0.9364 ± 0.0241  0.9364 ± 0.0241  0.9365 ± 0.0241  0.9364 ± 0.0241
# 67            OriginalProtoNet           3           jitter_0.3  0.9283 ± 0.0282  0.9283 ± 0.0282  0.9283 ± 0.0282  0.9283 ± 0.0282
# 68            OriginalProtoNet           3  missing_segment_0.1  0.9258 ± 0.0284  0.9258 ± 0.0284  0.9259 ± 0.0284  0.9258 ± 0.0284
# 69            OriginalProtoNet           3  missing_segment_0.2  0.8785 ± 0.0328  0.8785 ± 0.0328  0.8786 ± 0.0328  0.8785 ± 0.0328
# 70            OriginalProtoNet           3  missing_segment_0.3  0.7717 ± 0.0153  0.7717 ± 0.0153  0.7718 ± 0.0153  0.7717 ± 0.0153
# 71            OriginalProtoNet           3    outlier_spike_0.1  0.8988 ± 0.0280  0.8988 ± 0.0280  0.8989 ± 0.0280  0.8988 ± 0.0280
# 72            OriginalProtoNet           3    outlier_spike_0.2  0.8465 ± 0.0453  0.8465 ± 0.0453  0.8466 ± 0.0453  0.8465 ± 0.0453
# 73            OriginalProtoNet           3    outlier_spike_0.3  0.7899 ± 0.0590  0.7899 ± 0.0590  0.7900 ± 0.0590  0.7899 ± 0.0590
# 74            OriginalProtoNet           3   sensor_failure_0.1  0.8222 ± 0.0423  0.8221 ± 0.0423  0.8223 ± 0.0422  0.8222 ± 0.0423
# 75            OriginalProtoNet           3   sensor_failure_0.2  0.7307 ± 0.0486  0.7307 ± 0.0486  0.7309 ± 0.0486  0.7307 ± 0.0486
# 76            OriginalProtoNet           3   sensor_failure_0.3  0.6256 ± 0.0546  0.6255 ± 0.0547  0.6260 ± 0.0546  0.6256 ± 0.0546
# 77            OriginalProtoNet           3       time_shift_0.1  0.9354 ± 0.0246  0.9353 ± 0.0246  0.9354 ± 0.0246  0.9354 ± 0.0246
# 78            OriginalProtoNet           3       time_shift_0.2  0.9310 ± 0.0256  0.9310 ± 0.0256  0.9310 ± 0.0256  0.9310 ± 0.0256
# 79            OriginalProtoNet           3       time_shift_0.3  0.9147 ± 0.0220  0.9147 ± 0.0220  0.9147 ± 0.0220  0.9147 ± 0.0220
# 80            OriginalProtoNet           5                Clean  0.9457 ± 0.0089  0.9457 ± 0.0089  0.9458 ± 0.0088  0.9457 ± 0.0089
# 81            OriginalProtoNet           5           jitter_0.1  0.9433 ± 0.0070  0.9433 ± 0.0070  0.9433 ± 0.0070  0.9433 ± 0.0070
# 82            OriginalProtoNet           5           jitter_0.2  0.9422 ± 0.0086  0.9422 ± 0.0086  0.9423 ± 0.0086  0.9422 ± 0.0086
# 83            OriginalProtoNet           5           jitter_0.3  0.9383 ± 0.0117  0.9383 ± 0.0117  0.9383 ± 0.0117  0.9383 ± 0.0117
# 84            OriginalProtoNet           5  missing_segment_0.1  0.9308 ± 0.0138  0.9308 ± 0.0138  0.9308 ± 0.0138  0.9308 ± 0.0138
# 85            OriginalProtoNet           5  missing_segment_0.2  0.8650 ± 0.0262  0.8649 ± 0.0262  0.8651 ± 0.0261  0.8650 ± 0.0262
# 86            OriginalProtoNet           5  missing_segment_0.3  0.7378 ± 0.0624  0.7378 ± 0.0624  0.7379 ± 0.0624  0.7378 ± 0.0624
# 87            OriginalProtoNet           5    outlier_spike_0.1  0.9189 ± 0.0174  0.9189 ± 0.0174  0.9189 ± 0.0174  0.9189 ± 0.0174
# 88            OriginalProtoNet           5    outlier_spike_0.2  0.8778 ± 0.0301  0.8778 ± 0.0301  0.8778 ± 0.0301  0.8778 ± 0.0301
# 89            OriginalProtoNet           5    outlier_spike_0.3  0.8311 ± 0.0369  0.8311 ± 0.0369  0.8312 ± 0.0369  0.8311 ± 0.0369
# 90            OriginalProtoNet           5   sensor_failure_0.1  0.8116 ± 0.0105  0.8116 ± 0.0105  0.8118 ± 0.0105  0.8116 ± 0.0105
# 91            OriginalProtoNet           5   sensor_failure_0.2  0.7004 ± 0.0141  0.7004 ± 0.0141  0.7007 ± 0.0141  0.7004 ± 0.0141
# 92            OriginalProtoNet           5   sensor_failure_0.3  0.5926 ± 0.0181  0.5926 ± 0.0181  0.5932 ± 0.0184  0.5926 ± 0.0181
# 93            OriginalProtoNet           5       time_shift_0.1  0.9419 ± 0.0099  0.9419 ± 0.0099  0.9419 ± 0.0099  0.9419 ± 0.0099
# 94            OriginalProtoNet           5       time_shift_0.2  0.9359 ± 0.0128  0.9359 ± 0.0128  0.9360 ± 0.0128  0.9359 ± 0.0128
# 95            OriginalProtoNet           5       time_shift_0.3  0.9160 ± 0.0134  0.9160 ± 0.0134  0.9161 ± 0.0134  0.9160 ± 0.0134
# 96                  Supervised  N/A (Full)                Clean  0.7942 ± 0.0672  0.7892 ± 0.0597  0.8363 ± 0.0633  0.7999 ± 0.0664
# 97                  Supervised  N/A (Full)           jitter_0.1  0.7913 ± 0.0631  0.7863 ± 0.0556  0.8343 ± 0.0596  0.7970 ± 0.0627
# 98                  Supervised  N/A (Full)           jitter_0.2  0.7936 ± 0.0639  0.7890 ± 0.0569  0.8356 ± 0.0585  0.7997 ± 0.0624
# 99                  Supervised  N/A (Full)           jitter_0.3  0.7878 ± 0.0690  0.7853 ± 0.0617  0.8312 ± 0.0587  0.7945 ± 0.0667
# 100                 Supervised  N/A (Full)  missing_segment_0.1  0.7797 ± 0.0675  0.7735 ± 0.0580  0.8278 ± 0.0648  0.7874 ± 0.0662
# 101                 Supervised  N/A (Full)  missing_segment_0.2  0.7450 ± 0.0802  0.7299 ± 0.0791  0.7987 ± 0.0782  0.7524 ± 0.0803
# 102                 Supervised  N/A (Full)  missing_segment_0.3  0.7234 ± 0.0774  0.7082 ± 0.0717  0.7896 ± 0.0695  0.7278 ± 0.0753
# 103                 Supervised  N/A (Full)    outlier_spike_0.1  0.7642 ± 0.0757  0.7609 ± 0.0690  0.8111 ± 0.0566  0.7721 ± 0.0726
# 104                 Supervised  N/A (Full)    outlier_spike_0.2  0.7110 ± 0.0827  0.6952 ± 0.0877  0.7675 ± 0.0526  0.7216 ± 0.0797
# 105                 Supervised  N/A (Full)    outlier_spike_0.3  0.6615 ± 0.0830  0.6329 ± 0.0922  0.7211 ± 0.0474  0.6739 ± 0.0798
# 106                 Supervised  N/A (Full)   sensor_failure_0.1  0.7349 ± 0.0568  0.7226 ± 0.0629  0.7899 ± 0.0534  0.7437 ± 0.0549
# 107                 Supervised  N/A (Full)   sensor_failure_0.2  0.6659 ± 0.1198  0.6509 ± 0.1320  0.7110 ± 0.1300  0.6726 ± 0.1130
# 108                 Supervised  N/A (Full)   sensor_failure_0.3  0.5281 ± 0.0970  0.5205 ± 0.0958  0.6672 ± 0.0626  0.5403 ± 0.1085
# 109                 Supervised  N/A (Full)       time_shift_0.1  0.7911 ± 0.0623  0.7858 ± 0.0538  0.8339 ± 0.0592  0.7973 ± 0.0620
# 110                 Supervised  N/A (Full)       time_shift_0.2  0.7849 ± 0.0641  0.7789 ± 0.0555  0.8301 ± 0.0621  0.7906 ± 0.0642
# 111                 Supervised  N/A (Full)       time_shift_0.3  0.7762 ± 0.0656  0.7691 ± 0.0562  0.8235 ± 0.0610  0.7818 ± 0.0650
# ================================================================================
# ===== PIVOT TABLE: ACCURACY (MHEALTH) =====
# ================================================================================
# Model                     Supervised OriginalProtoNet                                   AttentionWeightedProtoNet
# K-Shot                    N/A (Full)                1                3                5                         1                3                5
# Noise
# Clean                0.7942 ± 0.0672  0.9060 ± 0.0603  0.9395 ± 0.0198  0.9457 ± 0.0089           0.9171 ± 0.0377  0.9273 ± 0.0266  0.9304 ± 0.0658
# jitter_0.1           0.7913 ± 0.0631  0.9048 ± 0.0619  0.9371 ± 0.0237  0.9433 ± 0.0070           0.9159 ± 0.0371  0.9275 ± 0.0267  0.9312 ± 0.0631
# jitter_0.2           0.7936 ± 0.0639  0.9033 ± 0.0607  0.9364 ± 0.0241  0.9422 ± 0.0086           0.9147 ± 0.0366  0.9244 ± 0.0272  0.9304 ± 0.0602
# jitter_0.3           0.7878 ± 0.0690  0.9015 ± 0.0608  0.9283 ± 0.0282  0.9383 ± 0.0117           0.9124 ± 0.0354  0.9200 ± 0.0306  0.9238 ± 0.0639
# missing_segment_0.1  0.7797 ± 0.0675  0.8948 ± 0.0624  0.9258 ± 0.0284  0.9308 ± 0.0138           0.8983 ± 0.0449  0.9072 ± 0.0208  0.9087 ± 0.0683
# missing_segment_0.2  0.7450 ± 0.0802  0.8526 ± 0.0724  0.8785 ± 0.0328  0.8650 ± 0.0262           0.8520 ± 0.0525  0.8436 ± 0.0564  0.8516 ± 0.0762
# missing_segment_0.3  0.7234 ± 0.0774  0.7665 ± 0.1013  0.7717 ± 0.0153  0.7378 ± 0.0624           0.7691 ± 0.0587  0.7554 ± 0.0960  0.7364 ± 0.1001
# outlier_spike_0.1    0.7642 ± 0.0757  0.8855 ± 0.0648  0.8988 ± 0.0280  0.9189 ± 0.0174           0.8928 ± 0.0424  0.8987 ± 0.0412  0.8995 ± 0.0707
# outlier_spike_0.2    0.7110 ± 0.0827  0.8586 ± 0.0698  0.8465 ± 0.0453  0.8778 ± 0.0301           0.8612 ± 0.0523  0.8509 ± 0.0618  0.8539 ± 0.0725
# outlier_spike_0.3    0.6615 ± 0.0830  0.8263 ± 0.0804  0.7899 ± 0.0590  0.8311 ± 0.0369           0.8185 ± 0.0663  0.7999 ± 0.0786  0.7998 ± 0.0785
# sensor_failure_0.1   0.7349 ± 0.0568  0.7922 ± 0.0706  0.8222 ± 0.0423  0.8116 ± 0.0105           0.8104 ± 0.0424  0.7973 ± 0.0547  0.7971 ± 0.0840
# sensor_failure_0.2   0.6659 ± 0.1198  0.7121 ± 0.0714  0.7307 ± 0.0486  0.7004 ± 0.0141           0.7161 ± 0.0379  0.7017 ± 0.0497  0.6824 ± 0.0902
# sensor_failure_0.3   0.5281 ± 0.0970  0.6064 ± 0.0665  0.6256 ± 0.0546  0.5926 ± 0.0181           0.6223 ± 0.0439  0.5897 ± 0.0569  0.5800 ± 0.0959
# time_shift_0.1       0.7911 ± 0.0623  0.9038 ± 0.0614  0.9354 ± 0.0246  0.9419 ± 0.0099           0.9160 ± 0.0363  0.9235 ± 0.0258  0.9273 ± 0.0654
# time_shift_0.2       0.7849 ± 0.0641  0.8939 ± 0.0676  0.9310 ± 0.0256  0.9359 ± 0.0128           0.9044 ± 0.0432  0.9155 ± 0.0285  0.9192 ± 0.0654
# time_shift_0.3       0.7762 ± 0.0656  0.8797 ± 0.0662  0.9147 ± 0.0220  0.9160 ± 0.0134           0.8886 ± 0.0452  0.8919 ± 0.0410  0.8998 ± 0.0658
# ================================================================================
# ===== PIVOT TABLE: F1-SCORE (MHEALTH) =====
# ================================================================================
# Model                     Supervised OriginalProtoNet                                   AttentionWeightedProtoNet
# K-Shot                    N/A (Full)                1                3                5                         1                3                5
# Noise
# Clean                0.7892 ± 0.0597  0.9060 ± 0.0604  0.9395 ± 0.0198  0.9457 ± 0.0089           0.9171 ± 0.0377  0.9273 ± 0.0266  0.9304 ± 0.0658
# jitter_0.1           0.7863 ± 0.0556  0.9048 ± 0.0619  0.9371 ± 0.0237  0.9433 ± 0.0070           0.9159 ± 0.0371  0.9275 ± 0.0267  0.9312 ± 0.0631
# jitter_0.2           0.7890 ± 0.0569  0.9033 ± 0.0607  0.9364 ± 0.0241  0.9422 ± 0.0086           0.9147 ± 0.0366  0.9244 ± 0.0273  0.9304 ± 0.0602
# jitter_0.3           0.7853 ± 0.0617  0.9015 ± 0.0608  0.9283 ± 0.0282  0.9383 ± 0.0117           0.9124 ± 0.0354  0.9200 ± 0.0306  0.9238 ± 0.0639
# missing_segment_0.1  0.7735 ± 0.0580  0.8948 ± 0.0624  0.9258 ± 0.0284  0.9308 ± 0.0138           0.8983 ± 0.0449  0.9072 ± 0.0208  0.9087 ± 0.0683
# missing_segment_0.2  0.7299 ± 0.0791  0.8526 ± 0.0724  0.8785 ± 0.0328  0.8649 ± 0.0262           0.8520 ± 0.0525  0.8436 ± 0.0564  0.8516 ± 0.0762
# missing_segment_0.3  0.7082 ± 0.0717  0.7664 ± 0.1014  0.7717 ± 0.0153  0.7378 ± 0.0624           0.7691 ± 0.0587  0.7553 ± 0.0960  0.7363 ± 0.1001
# outlier_spike_0.1    0.7609 ± 0.0690  0.8855 ± 0.0647  0.8988 ± 0.0280  0.9189 ± 0.0174           0.8928 ± 0.0423  0.8987 ± 0.0412  0.8995 ± 0.0708
# outlier_spike_0.2    0.6952 ± 0.0877  0.8586 ± 0.0699  0.8465 ± 0.0453  0.8778 ± 0.0301           0.8612 ± 0.0523  0.8509 ± 0.0618  0.8539 ± 0.0725
# outlier_spike_0.3    0.6329 ± 0.0922  0.8263 ± 0.0804  0.7899 ± 0.0590  0.8311 ± 0.0369           0.8185 ± 0.0663  0.7999 ± 0.0786  0.7998 ± 0.0785
# sensor_failure_0.1   0.7226 ± 0.0629  0.7922 ± 0.0706  0.8221 ± 0.0423  0.8116 ± 0.0105           0.8104 ± 0.0424  0.7972 ± 0.0547  0.7971 ± 0.0840
# sensor_failure_0.2   0.6509 ± 0.1320  0.7121 ± 0.0714  0.7307 ± 0.0486  0.7004 ± 0.0141           0.7161 ± 0.0379  0.7016 ± 0.0496  0.6824 ± 0.0903
# sensor_failure_0.3   0.5205 ± 0.0958  0.6064 ± 0.0665  0.6255 ± 0.0547  0.5926 ± 0.0181           0.6223 ± 0.0438  0.5897 ± 0.0570  0.5799 ± 0.0960
# time_shift_0.1       0.7858 ± 0.0538  0.9037 ± 0.0615  0.9353 ± 0.0246  0.9419 ± 0.0099           0.9160 ± 0.0363  0.9235 ± 0.0258  0.9273 ± 0.0654
# time_shift_0.2       0.7789 ± 0.0555  0.8939 ± 0.0676  0.9310 ± 0.0256  0.9359 ± 0.0128           0.9044 ± 0.0432  0.9155 ± 0.0285  0.9192 ± 0.0654
# time_shift_0.3       0.7691 ± 0.0562  0.8797 ± 0.0662  0.9147 ± 0.0220  0.9160 ± 0.0134           0.8886 ± 0.0452  0.8919 ± 0.0410  0.8998 ± 0.0658
# ================================================================================
# ===== MODEL STATISTICS (MHEALTH) =====
# ================================================================================
#                                         Param (M)    FLOPs (M) Inf. Time (ms)
# Model                     K-Shot
# AttentionWeightedProtoNet 1           0.37 ± 0.00  2.42 ± 0.00    6.62 ± 0.16
#                           3           0.37 ± 0.00  2.42 ± 0.00    6.64 ± 0.25
#                           5           0.37 ± 0.00  2.42 ± 0.00    6.76 ± 0.08
# OriginalProtoNet          1           0.37 ± 0.00  2.42 ± 0.00    4.88 ± 0.48
#                           3           0.37 ± 0.00  2.42 ± 0.00    4.58 ± 0.28
#                           5           0.37 ± 0.00  2.42 ± 0.00    5.57 ± 1.87
# Supervised                N/A (Full)  0.37 ± 0.00  2.42 ± 0.00    1.43 ± 0.21
# ================================================================================
# ===== K-SHOT PERFORMANCE COMPARISON (F1-SCORE) (MHEALTH) =====
# ================================================================================
# ##########################################################################################
# ##### ALL DATASET EXPERIMENTS COMPLETE #####
# ##########################################################################################
