# %%
# !pip install thop ptflops
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238

# %%
    noise_conditions_to_test = [
        ('jitter', 0.1),
        ('jitter', 0.2),
        ('jitter', 0.3),
        ('time_shift', 0.1),
        ('time_shift', 0.2),
        ('time_shift', 0.3),
        ('sensor_failure', 0.1),
        ('sensor_failure', 0.2),
        ('sensor_failure', 0.3),
        ('outlier_spike', 0.1),
        ('outlier_spike', 0.2),
        ('outlier_spike', 0.3),
        ('missing_segment', 0.1), # 10% length
        ('missing_segment', 0.2),  # 30% length
        ('missing_segment', 0.3)
    ]

# %%
import os
import random
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from thop import profile
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import re
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from glob import glob
import pickle

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def compute_mean_std(X):
    X = X.astype(np.float32)
    mean = X.mean(axis=(0, 2), keepdims=True)
    std  = X.std(axis=(0, 2), keepdims=True) + 1e-8
    return mean, std

def aug_jitter_scale(x_batch, jitter_sigma=0.03, scale_max=0.1):
    jitter = torch.randn_like(x_batch) * jitter_sigma
    x_batch = x_batch + jitter
    scale = 1.0 + (torch.rand(x_batch.shape[0], 1, 1, device=x_batch.device) - 0.5) * 2 * scale_max
    x_batch = x_batch * scale
    return x_batch

def aug_sensor_failure(x_batch):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    fail_channel = random.randint(0, C - 1)
    x_aug[:, fail_channel, :] = 0.0
    return x_aug

def aug_missing_segment(x_batch, missing_seg_len_range=(0.1, 0.25)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    seg_len_min = int(L * missing_seg_len_range[0])
    seg_len_max = int(L * missing_seg_len_range[1])
    if seg_len_min >= seg_len_max:
         seg_len_max = seg_len_min + 1
    seg_len = random.randint(seg_len_min, seg_len_max)
    start = random.randint(0, L - seg_len)
    x_aug[:, :, start:start+seg_len] = 0.0
    return x_aug

def aug_outlier_spike(x_batch, outlier_magnitude=10, num_outliers_range=(1, 5)):
    B, C, L = x_batch.shape
    x_aug = x_batch.clone()
    num_outliers = random.randint(num_outliers_range[0], num_outliers_range[1])
    for _ in range(num_outliers):
        b_idx = random.randint(0, B - 1)
        c_idx = random.randint(0, C - 1)
        l_idx = random.randint(0, L - 1)
        magnitude = (torch.randn(1) * outlier_magnitude).item()
        x_aug[b_idx, c_idx, l_idx] = x_aug[b_idx, c_idx, l_idx] + magnitude
    return x_aug

def apply_test_noise(x_batch, noise_type, noise_level):
    x_noisy = x_batch.clone()
    B, C, L = x_batch.shape

    if noise_type == 'jitter':
        noise = torch.randn_like(x_batch) * noise_level
        x_noisy = x_batch + noise

    elif noise_type == 'time_shift':
        max_shift = int(L * noise_level)
        if max_shift == 0 and noise_level > 0:
             max_shift = 1
        x_shifted = torch.zeros_like(x_batch)
        for i in range(B):
            shift = random.randint(-max_shift, max_shift)
            if shift == 0:
                x_shifted[i] = x_batch[i]
            elif shift > 0:
                x_shifted[i, :, shift:] = x_batch[i, :, :-shift]
            else:
                x_shifted[i, :, :shift] = x_batch[i, :, -shift:]
        x_noisy = x_shifted

    elif noise_type == 'sensor_failure':
        n_channels = int(np.ceil(C * noise_level))
        if n_channels == 0: n_channels = 1
        fail_channels = np.random.choice(C, n_channels, replace=False)
        x_noisy[:, fail_channels, :] = 0.0

    elif noise_type == 'outlier_spike':
        num_spikes = max(1, int(noise_level * 100))
        for i in range(B):
            for _ in range(num_spikes):
                c_idx = random.randint(0, C - 1)
                l_idx = random.randint(0, L - 1)
                magnitude = (torch.randn(1) * 5).item()
                x_noisy[i, c_idx, l_idx] += magnitude

    elif noise_type == 'missing_segment':
        seg_len = max(1, int(L * noise_level))
        start = random.randint(0, L - seg_len)
        x_noisy[:, :, start:start+seg_len] = 0.0

    return x_noisy


def compute_encoder_stats(encoder, input_shape=(1,9,128)):
    device = next(encoder.parameters()).device
    macs, params = profile(encoder, inputs=(torch.randn(*input_shape).to(device),), verbose=False)
    return params/1e6, macs/1e6

def measure_meta_inference_time(model, n_way, sz=(1,9,128), dev='cuda', runs=100, warm=10):
    model.eval()
    x_q = torch.randn(sz, device=dev)
    x_s = torch.randn((n_way*5,) + sz[1:], device=dev)
    y_s = torch.tensor(np.repeat(range(n_way), 5), device=dev)

    with torch.no_grad():
        for _ in range(warm):
            _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    t0 = time.time()
    with torch.no_grad():
        for _ in range(runs):
            _ = model(x_q, x_s, y_s, n_way)
    torch.cuda.synchronize() if dev=='cuda' else None
    return (time.time()-t0)/runs*1000

def compute_supervised_stats(model: nn.Module, input_shape=(9, 128)):
    device = next(model.parameters()).device
    dummy_input = torch.randn(1, *input_shape).to(device)
    model.eval()

    if not hasattr(model, 'classifier') or not hasattr(model, 'extract_features'):
        raise ValueError("Model must have 'classifier' attribute and 'extract_features' method.")

    classifier_original = model.classifier
    model.classifier = nn.Identity()
    macs_backbone, params_backbone = profile(model, inputs=(dummy_input,), verbose=False)
    model.classifier = classifier_original

    with torch.no_grad():
        features = model.extract_features(dummy_input)
        if isinstance(features, tuple):
            features = features[0]

    macs_cls, params_cls = profile(model.classifier, inputs=(features,), verbose=False)

    total_macs_m = (macs_backbone + macs_cls) / 1e6
    total_params_m = (params_backbone + params_cls) / 1e6
    return total_params_m, total_macs_m

def measure_supervised_inference_time(model: nn.Module, input_size=(1, 9, 128), device='cuda', n_runs=100, warmup=10):
    model.eval()
    inputs = torch.randn(input_size).to(device)

    with torch.inference_mode():
        for _ in range(warmup):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    start = time.time()
    with torch.inference_mode():
        for _ in range(n_runs):
            _ = model(inputs)

    if device == 'cuda':
        torch.cuda.synchronize()

    end = time.time()
    return (end - start) / n_runs * 1000

def plot_confusion_matrix(cm, labels):
    cmn = cm.astype('float')/cm.sum(axis=1)[:,None]
    df = pd.DataFrame(cmn, index=labels, columns=labels)
    plt.figure(figsize=(8,7))
    sns.heatmap(df, annot=True, fmt='.2f', cmap='Blues', cbar=True)
    plt.xlabel('Predicted', fontsize=12)
    plt.ylabel('True', fontsize=12)
    plt.title('Confusion Matrix (Normalized)', fontsize=14)
    plt.tight_layout()
    plt.show()

def plot_learning_curves(train_losses, train_accs, val_accs, title_suffix=""):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    ax1.plot(train_losses, linewidth=2, label='Train Loss')
    ax1.set_xlabel('Episode', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.set_title(f'Training Loss {title_suffix}', fontsize=14)
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(train_accs, linewidth=2, color='orange', label='Train Acc')
    ax2.plot(val_accs, linewidth=2, color='green', label='Val Acc')
    ax2.set_xlabel('Episode', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.set_title(f'Training & Validation Accuracy {title_suffix}', fontsize=14)
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    plt.tight_layout()

def plot_kshot_comparison(shot_results):
    plt.figure(figsize=(10, 6))
    plt.plot([r['K'] for r in shot_results], [r['Accuracy'] for r in shot_results],
             marker='o', linewidth=2, markersize=8, label='Accuracy')
    plt.plot([r['K'] for r in shot_results], [r['F1'] for r in shot_results],
             marker='s', linewidth=2, markersize=8, label='F1-Score')
    plt.xlabel('K-Shot', fontsize=12)
    plt.ylabel('Score', fontsize=12)
    plt.title('Meta-Learning Performance vs K-Shot', fontsize=14)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def plot_user_performance(per_user_df):
    plt.figure(figsize=(12, 6))
    x = range(len(per_user_df))
    plt.bar(x, per_user_df['Accuracy'], alpha=0.7, label='Accuracy')
    plt.axhline(y=per_user_df['Accuracy'].mean(), color='r', linestyle='--',
                label=f'Mean: {per_user_df["Accuracy"].mean():.3f}')
    plt.xlabel('Test User', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Per-User 5-Shot Accuracy', fontsize=14)
    plt.xticks(x, per_user_df['User'])
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    plt.tight_layout()
    plt.show()

class HARDataset(Dataset):
    def __init__(self, X, y, norm=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if norm:
            self.mean = self.X.mean(axis=(0,2), keepdims=True)
            self.std = self.X.std(axis=(0,2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean)/self.std
        else:
            self.mean, self.std = None, None

    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean)/self.std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        return torch.from_numpy(self.X[i]), int(self.y[i])

def load_mhealth_data(dataset_dir="MHEALTH"):
    subject_files = sorted([
        os.path.join(dataset_dir, f)
        for f in os.listdir(dataset_dir)
        if f.startswith("mHealth_subject") and f.endswith(".log")
    ])
    if not subject_files:
        return None, None, None, None

    all_windows = []
    all_labels = []
    all_subjects = []
    window_size = 50
    step = 25

    for file_path in subject_files:
        subject_id_match = re.search(r'subject(\d+)', os.path.basename(file_path))
        if not subject_id_match:
            continue
        subject_id = int(subject_id_match.group(1))

        df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
        df = df.ffill().bfill()
        if df.shape[1] < 24:
            continue

        labels = df.iloc[:, 23].values.astype(int)
        imu_cols = [0,1,2] + list(range(5, 23))
        features = df.iloc[:, imu_cols].values

        valid_indices = np.where(labels != 0)[0]
        if len(valid_indices) == 0:
            continue

        features = features[valid_indices, :]
        labels = labels[valid_indices]

        if len(features) < window_size:
            continue

        start = 0
        while start + window_size <= len(features):
            window_data = features[start : start + window_size, :]
            window_labels_raw = labels[start : start + window_size]
            most_common_label = Counter(window_labels_raw).most_common(1)[0][0]

            all_windows.append(window_data)
            all_labels.append(most_common_label)
            all_subjects.append(subject_id)

            start += step

    if not all_windows:
        return None, None, None, None

    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(all_labels)
    X_windowed = np.array(all_windows, dtype=np.float32)

    X_windowed = np.transpose(X_windowed, (0, 2, 1))

    mhealth_activity_mapping = {
        1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down', 4: 'Walking',
        5: 'Climbing stairs', 6: 'Waist bends forward', 7: 'Frontal elevation of arms',
        8: 'Knees bending', 9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
    }
    activity_labels = []
    class_names = list(label_encoder.classes_)

    for original_label in class_names:
        if original_label in mhealth_activity_mapping:
            activity_labels.append(mhealth_activity_mapping[original_label])
        else:
            activity_labels.append(f"Unknown_Activity_{original_label}")

    return X_windowed, y_encoded, np.array(all_subjects, dtype=int), activity_labels

class CompactEncoder(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128):
        super().__init__()
        self.stage1 = self._make_stage(in_channels, 32, stride=2)
        self.stage2 = self._make_stage(32, 64, stride=2)
        self.stage3 = self._make_stage(64, 128, stride=2)
        self.stage4 = self._make_stage(128, embed_dim, stride=2)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def _make_stage(self, in_ch, out_ch, stride=1):
        return nn.Sequential(
            nn.Conv1d(in_ch, out_ch, kernel_size=5, stride=stride, padding=2),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU()
        )

    def forward(self, x):
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)
        x = self.pool(x).flatten(1)
        return x

class PrototypeNetwork(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder

    def forward(self, query_x, support_x, support_y, n_way):
        support_features = self.encoder(support_x)
        query_features = self.encoder(query_x)

        embed_dim = support_features.size(-1)
        prototypes = torch.zeros(n_way, embed_dim, device=support_x.device)

        for c in range(n_way):
            mask = (support_y == c)
            if mask.sum() > 0:
                prototypes[c] = support_features[mask].mean(dim=0)

        n_query = query_features.size(0)
        query_features_expanded = query_features.unsqueeze(1).expand(n_query, n_way, embed_dim)
        prototypes_expanded = prototypes.unsqueeze(0).expand(n_query, n_way, embed_dim)

        dists = ((query_features_expanded - prototypes_expanded)**2).sum(dim=2)
        logits = -dists

        return logits

class SupervisedBaseline(nn.Module):
    def __init__(self, in_channels=9, embed_dim=128, num_classes=6):
        super().__init__()
        self.encoder = CompactEncoder(in_channels=in_channels, embed_dim=embed_dim)
        self.classifier = nn.Linear(embed_dim, num_classes)

    def extract_features(self, x):
        return self.encoder(x)

    def forward(self, x):
        features = self.extract_features(x)
        return self.classifier(features)

def create_episodes(users_data, n_way=6, k_shot=5, q_query=15, total_classes=6):
    if not users_data:
        return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

    for _ in range(50):
        user = random.choice(users_data)
        data = user['data']
        labels = user['labels']
        unique_cls = np.unique(labels)

        if len(unique_cls) < n_way:
            continue

        chosen_classes = np.random.choice(unique_cls, n_way, replace=False)
        support_x, support_y, query_x, query_y = [], [], [], []

        valid_episode = True
        for new_c, original_c in enumerate(chosen_classes):
            idxs = np.where(labels == original_c)[0]
            if len(idxs) < k_shot + q_query:
                valid_episode = False
                break

            np.random.shuffle(idxs)
            s_idx = idxs[:k_shot]
            q_idx = idxs[k_shot:k_shot+q_query]

            support_x.extend([data[i] for i in s_idx])
            support_y.extend([new_c] * k_shot)
            query_x.extend([data[i] for i in q_idx])
            query_y.extend([new_c] * q_query)

        if valid_episode:
            if not support_x or not query_x:
                continue
            return (torch.stack(support_x), torch.tensor(support_y),
                    torch.stack(query_x), torch.tensor(query_y))

    return (torch.empty(0), torch.empty(0), torch.empty(0), torch.empty(0))

def meta_train(model, optimizer, train_users, val_users, n_way_range, k_shot=5, q_query=15,
               episodes=5000, log_every=100, val_every=200, total_classes=6):
    model.train()
    train_losses, train_accs, val_accs = [], [], []

    clean_cutoff = int(episodes * 0.30)
    jitter_cutoff = clean_cutoff + int(episodes * 0.175)
    sensor_cutoff = jitter_cutoff + int(episodes * 0.175)
    missing_cutoff = sensor_cutoff + int(episodes * 0.175)

    for ep in range(episodes):
        n_way = random.randint(n_way_range[0], n_way_range[1])

        support_x, support_y, query_x, query_y = create_episodes(train_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue

        if ep < clean_cutoff:
            support_x_aug = support_x
            query_x_aug = query_x
        elif ep < jitter_cutoff:
            support_x_aug = aug_jitter_scale(support_x)
            query_x_aug = aug_jitter_scale(query_x)
        elif ep < sensor_cutoff:
            support_x_aug = aug_sensor_failure(support_x)
            query_x_aug = aug_sensor_failure(query_x)
        elif ep < missing_cutoff:
            support_x_aug = aug_missing_segment(support_x)
            query_x_aug = aug_missing_segment(query_x)
        else:
            support_x_aug = aug_outlier_spike(support_x)
            query_x_aug = aug_outlier_spike(query_x)

        support_x_aug, support_y = support_x_aug.cuda(), support_y.cuda()
        query_x_aug, query_y = query_x_aug.cuda(), query_y.cuda()

        logits = model(query_x_aug, support_x_aug, support_y, n_way)
        loss = F.cross_entropy(logits, query_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (logits.argmax(1) == query_y).float().mean().item()
        train_losses.append(loss.item())
        train_accs.append(acc)

        if (ep + 1) % log_every == 0:
            print(f"Episode {ep+1:5d} | Loss: {loss.item():.4f} | Train Acc: {acc:.4f}", end="")
            if (ep + 1) % val_every == 0:
                val_acc = meta_validate(model, val_users, k_shot, n_way_range[1], trials=20, total_classes=total_classes)
                val_accs.append(val_acc)
                print(f" | Val Acc: {val_acc:.4f}")
            else:
                print()

    val_episodes = list(range(val_every - 1, episodes, val_every))
    if len(val_accs) == 0 and episodes > 0:
        val_accs = [0.0]
    val_accs_interpolated = np.interp(range(episodes), val_episodes, val_accs)

    return train_losses, train_accs, val_accs_interpolated

def meta_validate(model, val_users, k_shot=5, n_way=6, trials=20, total_classes=6):
    model.eval()
    correct, total = 0, 0
    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(val_users, n_way, k_shot, 15, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()
        with torch.no_grad():
            logits = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1)
            correct += (preds == query_y).sum().item()
            total += len(query_y)
    model.train()
    return correct / total if total > 0 else 0.0

def meta_test(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        with torch.no_grad():
            logits = model(query_x, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def meta_test_noisy(model, test_users, k_shot=5, n_way=6, q_query=15, trials=100, noise_type='jitter', noise_level=0.1, total_classes=6):
    model.eval()
    all_preds, all_trues = [], []

    for _ in range(trials):
        support_x, support_y, query_x, query_y = create_episodes(test_users, n_way, k_shot, q_query, total_classes=total_classes)
        if support_x.size(0) == 0:
            continue
        support_x, support_y = support_x.cuda(), support_y.cuda()
        query_x, query_y = query_x.cuda(), query_y.cuda()

        query_x_noisy = apply_test_noise(query_x, noise_type, noise_level)

        with torch.no_grad():
            logits = model(query_x_noisy, support_x, support_y, n_way)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(query_y.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((n_way, n_way))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(n_way))

    return acc, f1, prec, rec, cm

def train_supervised(model, train_loader, optimizer, criterion, epochs, device):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_correct = 0
        total_samples = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            logits = model(x_batch)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * x_batch.size(0)
            total_correct += (logits.argmax(1) == y_batch).sum().item()
            total_samples += x_batch.size(0)

        avg_loss = total_loss / total_samples
        avg_acc = total_correct / total_samples
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | Train Loss: {avg_loss:.4f} | Train Acc: {avg_acc:.4f}")

def test_supervised(model, test_loader, device, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            logits = model(x_batch)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm

def test_supervised_noisy(model, test_loader, device, noise_type, noise_level, num_classes=6):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            x_batch_noisy = apply_test_noise(x_batch, noise_type, noise_level)
            logits = model(x_batch_noisy)
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_trues.extend(y_batch.cpu().numpy())

    if not all_trues:
        return 0, 0, 0, 0, np.zeros((num_classes, num_classes))

    acc = accuracy_score(all_trues, all_preds)
    f1 = f1_score(all_trues, all_preds, average='macro', zero_division=0)
    prec = precision_score(all_trues, all_preds, average='macro', zero_division=0)
    rec = recall_score(all_trues, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_trues, all_preds, labels=range(num_classes))
    return acc, f1, prec, rec, cm


def prepare_users(X, y, sub, subs, mean, std):
    users = []
    for uid in subs:
        mask = (sub == uid)
        user_data = X[mask]
        user_labels = y[mask]
        if len(user_data) == 0:
            continue
        user_dataset = HARDataset(user_data, user_labels, norm=False)
        user_dataset.set_stats(mean, std)

        if len(user_dataset) > 0:
            users.append({
                'data': torch.stack([user_dataset[i][0] for i in range(len(user_dataset))]),
                'labels': user_labels,
                'id': uid
            })
    return users

if __name__ == '__main__':
    set_seed(42)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Device: {device}\n")

    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)

    root = "/content/drive/MyDrive/HAR_Dataset/MHEALTH"
    print("=" * 60)
    print("LOADING MHEALTH DATASET")
    print("=" * 60)
    X_raw, y_raw, sub_raw, labels = load_mhealth_data(root)

    if X_raw is None:
        print("Failed to load MHEALTH data. Check directory path and data.")
        exit()

    print(f"Data shape (N, C, L): {X_raw.shape}")
    print(f"Labels: {labels}")
    print(f"Total subjects: {len(np.unique(sub_raw))}")

    INPUT_CHANNELS = X_raw.shape[1]
    INPUT_LENGTH = X_raw.shape[2]
    TOTAL_CLASSES = len(labels)

    unique_subs = np.unique(sub_raw)
    train_subs = unique_subs[:7]
    val_subs = unique_subs[7:8]
    test_subs = unique_subs[8:]

    print(f"\nTrain subjects: {len(train_subs)} users (IDs: {train_subs})")
    print(f"Val subjects: {len(val_subs)} users (IDs: {val_subs})")
    print(f"Test subjects: {len(test_subs)} users (IDs: {test_subs})")

    train_mask = np.isin(sub_raw, train_subs)
    val_mask = np.isin(sub_raw, val_subs)
    test_mask = np.isin(sub_raw, test_subs)

    X_train, y_train, sub_train = X_raw[train_mask], y_raw[train_mask], sub_raw[train_mask]
    X_val, y_val, sub_val = X_raw[val_mask], y_raw[val_mask], sub_raw[val_mask]
    X_test, y_test, sub_test = X_raw[test_mask], y_raw[test_mask], sub_raw[test_mask]

    print(f"\nTrain samples: {len(X_train)}")
    print(f"Val samples: {len(X_val)}")
    print(f"Test samples: {len(X_test)}")

    mean, std = compute_mean_std(X_train)

    train_users = prepare_users(X_train, y_train, sub_train, train_subs, mean, std)
    val_users = prepare_users(X_val, y_val, sub_val, val_subs, mean, std)
    test_users = prepare_users(X_test, y_test, sub_test, test_subs, mean, std)

    train_dataset_sup = HARDataset(X_train, y_train, norm=False)
    train_dataset_sup.set_stats(mean, std)
    train_loader_sup = DataLoader(train_dataset_sup, batch_size=64, shuffle=True)

    test_dataset_sup = HARDataset(X_test, y_test, norm=False)
    test_dataset_sup.set_stats(mean, std)
    test_loader_sup = DataLoader(test_dataset_sup, batch_size=256, shuffle=False)

    final_results_list = []
    stats_results_list = []

    noise_conditions_to_test = [
        ('jitter', 0.1),
        ('jitter', 0.2),
        ('jitter', 0.3),
        ('time_shift', 0.1),
        ('time_shift', 0.2),
        ('time_shift', 0.3),
        ('sensor_failure', 0.1),
        ('sensor_failure', 0.2),
        ('sensor_failure', 0.3),
        ('outlier_spike', 0.1),
        ('outlier_spike', 0.2),
        ('outlier_spike', 0.3),
        ('missing_segment', 0.1),
        ('missing_segment', 0.2),
        ('missing_segment', 0.3)
    ]
    train_k_shots_list = [1, 3, 5, 10]

    print("\n" + "=" * 80)
    print("PART 1: SUPERVISED BASELINE (CompactEncoder + Classifier)")
    print("=" * 80)

    supervised_model = SupervisedBaseline(
        in_channels=INPUT_CHANNELS,
        embed_dim=128,
        num_classes=TOTAL_CLASSES
    ).to(device)

    optimizer_sup = torch.optim.Adam(supervised_model.parameters(), lr=0.001)
    criterion_sup = nn.CrossEntropyLoss()

    print("--- Training Supervised Baseline ---")
    train_supervised(supervised_model, train_loader_sup, optimizer_sup, criterion_sup, epochs=50, device=device)

    print("\n--- Calculating Supervised Model Stats ---")
    sup_params, sup_flops = compute_supervised_stats(supervised_model, input_shape=(INPUT_CHANNELS, INPUT_LENGTH))
    sup_inf_time = measure_supervised_inference_time(supervised_model, input_size=(1, INPUT_CHANNELS, INPUT_LENGTH), device=device)
    print(f"Supervised Stats | Params(M): {sup_params:.2f}, FLOPs(M): {sup_flops:.2f}, Inf. Time(ms): {sup_inf_time:.2f}")

    stats_results_list.append({
        'Model': 'Supervised',
        'K-Shot': 'N/A (Full)',
        'Param (M)': sup_params,
        'FLOPs (M)': sup_flops,
        'Inf. Time (ms)': sup_inf_time
    })

    print("\n--- Testing Supervised Baseline (Clean) ---")
    acc_s, f1_s, prec_s, rec_s, _ = test_supervised(supervised_model, test_loader_sup, device, num_classes=TOTAL_CLASSES)
    print(f"Supervised Clean | Acc: {acc_s:.4f}, F1: {f1_s:.4f}")
    final_results_list.append({
        'Model': 'Supervised',
        'K-Shot': 'N/A (Full)',
        'Noise': 'Clean',
        'Accuracy': acc_s,
        'F1-Score': f1_s,
        'Precision': prec_s,
        'Recall': rec_s
    })

    print("\n--- Testing Supervised Baseline (Robustness) ---")
    for n_type, n_level in noise_conditions_to_test:
        acc_n, f1_n, prec_n, rec_n, _ = test_supervised_noisy(
            supervised_model, test_loader_sup, device,
            noise_type=n_type, noise_level=n_level, num_classes=TOTAL_CLASSES
        )
        print(f"Supervised Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
        final_results_list.append({
            'Model': 'Supervised',
            'K-Shot': 'N/A (Full)',
            'Noise': f"{n_type}_{n_level}",
            'Accuracy': acc_n,
            'F1-Score': f1_n,
            'Precision': prec_n,
            'Recall': rec_n
        })

    del supervised_model, optimizer_sup, criterion_sup
    torch.cuda.empty_cache()

    print("\n" + "=" * 80)
    print("PART 2: META-LEARNING (Per K-Shot Training)")
    print("=" * 80)

    N_WAY_TRAIN_MIN = max(3, TOTAL_CLASSES - 6)
    N_WAY_TRAIN_MAX = TOTAL_CLASSES
    Q_QUERY_TRAIN = 15
    EPISODES = 10000

    for k_train in train_k_shots_list:
        print("\n" + "=" * 70)
        print(f"STARTING META-TRAINING FOR K-SHOT = {k_train}")
        print("=" * 70)

        K_SHOT_TRAIN = k_train

        base_encoder = CompactEncoder(in_channels=INPUT_CHANNELS, embed_dim=128).to(device)
        meta_model = PrototypeNetwork(base_encoder).to(device)
        optimizer_meta = torch.optim.Adam(meta_model.parameters(), lr=0.001)

        print(f"--- Calculating Meta Model Stats (K={k_train}) ---")
        meta_enc_params, meta_enc_flops = compute_encoder_stats(base_encoder, input_shape=(1, INPUT_CHANNELS, INPUT_LENGTH))
        meta_e2e_inf_time = measure_meta_inference_time(meta_model, n_way=TOTAL_CLASSES, sz=(1, INPUT_CHANNELS, INPUT_LENGTH), dev=device)

        total_meta_params = meta_enc_params
        for param in meta_model.parameters():
             if param.requires_grad:
                 total_meta_params += param.numel() / 1e6

        print(f"Meta-{k_train} Stats | Encoder Params(M): {meta_enc_params:.2f}, Encoder FLOPs(M): {meta_enc_flops:.2f}, E2E Inf. Time(ms): {meta_e2e_inf_time:.2f}")

        stats_results_list.append({
            'Model': 'Meta-Learning',
            'K-Shot': k_train,
            'Param (M)': meta_enc_params,
            'FLOPs (M)': meta_enc_flops,
            'Inf. Time (ms)': meta_e2e_inf_time
        })

        print(f"--- Meta-Training (K={K_SHOT_TRAIN}, {EPISODES} Episodes, Robust Augmentation) ---")
        train_losses, train_accs, val_accs = meta_train(
            meta_model, optimizer_meta, train_users, val_users,
            n_way_range=(N_WAY_TRAIN_MIN, N_WAY_TRAIN_MAX),
            k_shot=K_SHOT_TRAIN,
            q_query=Q_QUERY_TRAIN,
            episodes=EPISODES,
            log_every=1000,
            val_every=1000,
            total_classes=TOTAL_CLASSES
        )

        print(f"\n--- Plotting Meta-Training Learning Curves (K={k_train}) ---")
        plot_learning_curves(train_losses, train_accs, val_accs, title_suffix=f"(K-Train = {k_train})")
        plt.show()

        print(f"\n--- Testing Meta-Learning Model (K={k_train}) ---")

        print(f"Meta-{k_train}-Shot (Clean) | Testing...")
        acc_m, f1_m, prec_m, rec_m, _ = meta_test(
            meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES,
            q_query=15, trials=200, total_classes=TOTAL_CLASSES
        )
        print(f"Meta-{k_train}-Shot (Clean) | Acc: {acc_m:.4f}, F1: {f1_m:.4f}")
        final_results_list.append({
            'Model': 'Meta-Learning',
            'K-Shot': k_train,
            'Noise': 'Clean',
            'Accuracy': acc_m,
            'F1-Score': f1_m,
            'Precision': prec_m,
            'Recall': rec_m
        })

        for n_type, n_level in noise_conditions_to_test:
            acc_n, f1_n, prec_n, rec_n, _ = meta_test_noisy(
                meta_model, test_users, k_shot=k_train, n_way=TOTAL_CLASSES, q_query=15,
                trials=100, noise_type=n_type, noise_level=n_level,
                total_classes=TOTAL_CLASSES
            )
            print(f"Meta-{k_train}-Shot Noisy | Type: {n_type:16s} | Lvl: {n_level} | Acc: {acc_n:.4f}, F1: {f1_n:.4f}")
            final_results_list.append({
                'Model': 'Meta-Learning',
                'K-Shot': k_train,
                'Noise': f"{n_type}_{n_level}",
                'Accuracy': acc_n,
                'F1-Score': f1_n,
                'Precision': prec_n,
                'Recall': rec_n
            })

        del base_encoder, meta_model, optimizer_meta
        torch.cuda.empty_cache()


    print("\n" + "=" * 80)
    print("===== FINAL COMPARISON RESULTS =====")
    print("=" * 80)

    final_df = pd.DataFrame(final_results_list)
    display(final_df)

    print("\n" + "=" * 80)
    print("===== PIVOT TABLE: ACCURACY =====")
    print("=" * 80)
    pivot_acc = final_df.pivot_table(
        index='Noise',
        columns=['Model', 'K-Shot'],
        values='Accuracy'
    )

    cols_order = [
        ('Supervised', 'N/A (Full)'),
        ('Meta-Learning', 1),
        ('Meta-Learning', 3),
        ('Meta-Learning', 5),
        ('Meta-Learning', 10)
    ]

    cols_present = [c for c in cols_order if c in pivot_acc.columns]
    pivot_acc = pivot_acc[cols_present]

    display(pivot_acc.style.format("{:.4f}").highlight_max(axis=1, color='lightgreen'))


    print("\n" + "=" * 80)
    print("===== PIVOT TABLE: F1-SCORE =====")
    print("=" * 80)
    pivot_f1 = final_df.pivot_table(
        index='Noise',
        columns=['Model', 'K-Shot'],
        values='F1-Score'
    )

    cols_present_f1 = [c for c in cols_order if c in pivot_f1.columns]
    pivot_f1 = pivot_f1[cols_present_f1]

    display(pivot_f1.style.format("{:.4f}").highlight_max(axis=1, color='lightgreen'))

    print("\n" + "=" * 80)
    print("===== MODEL STATISTICS (Params, FLOPs, Latency) =====")
    print("=" * 80)
    stats_df = pd.DataFrame(stats_results_list)
    display(stats_df.set_index(['Model', 'K-Shot']).style.format("{:.2f}"))
# Out:
# <>:287: SyntaxWarning: invalid escape sequence '\s'
# <>:287: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1651046682.py:287: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=None, engine='python', dtype=np.float32)
# Device: cuda
#
# ============================================================
# LOADING MHEALTH DATASET
# ============================================================
# Data shape (N, C, L): (13714, 21, 50)
# Labels: ['Standing still', 'Sitting and relaxing', 'Lying down', 'Walking', 'Climbing stairs', 'Waist bends forward', 'Frontal elevation of arms', 'Knees bending', 'Cycling', 'Jogging', 'Running', 'Jump front & back']
# Total subjects: 10
#
# Train subjects: 7 users (IDs: [1 2 3 4 5 6 7])
# Val subjects: 1 users (IDs: [8])
# Test subjects: 2 users (IDs: [ 9 10])
#
# Train samples: 9663
# Val samples: 1332
# Test samples: 2719
#
# ================================================================================
# PART 1: SUPERVISED BASELINE (CompactEncoder + Classifier)
# ================================================================================
# --- Training Supervised Baseline ---
# Epoch  10/50 | Train Loss: 0.0454 | Train Acc: 0.9865
# Epoch  20/50 | Train Loss: 0.0177 | Train Acc: 0.9954
# Epoch  30/50 | Train Loss: 0.0119 | Train Acc: 0.9969
# Epoch  40/50 | Train Loss: 0.0046 | Train Acc: 0.9984
# Epoch  50/50 | Train Loss: 0.0111 | Train Acc: 0.9973
#
# --- Calculating Supervised Model Stats ---
# Supervised Stats | Params(M): 0.37, FLOPs(M): 2.42, Inf. Time(ms): 1.44
#
# --- Testing Supervised Baseline (Clean) ---
# Supervised Clean | Acc: 0.9165, F1: 0.9152
#
# --- Testing Supervised Baseline (Robustness) ---
# Supervised Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9161, F1: 0.9149
# Supervised Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9095, F1: 0.9090
# Supervised Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8897, F1: 0.8903
# Supervised Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8959, F1: 0.8962
# Supervised Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8595, F1: 0.8597
# Supervised Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8430, F1: 0.8426
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8411, F1: 0.8424
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6741, F1: 0.6801
# Supervised Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5704, F1: 0.5585
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8566, F1: 0.8539
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8172, F1: 0.8041
# Supervised Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.7812, F1: 0.7600
# Supervised Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8687, F1: 0.8701
# Supervised Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7514, F1: 0.7499
# Supervised Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6822, F1: 0.6640
#
# ================================================================================
# PART 2: META-LEARNING (Per K-Shot Training)
# ================================================================================
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 1
# ======================================================================
# --- Calculating Meta Model Stats (K=1) ---
# Meta-1 Stats | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.42, E2E Inf. Time(ms): 4.72
# --- Meta-Training (K=1, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.5462 | Train Acc: 0.8933 | Val Acc: 0.7603
# Episode  2000 | Loss: 0.2825 | Train Acc: 0.9444 | Val Acc: 0.7858
# Episode  3000 | Loss: 0.0132 | Train Acc: 1.0000 | Val Acc: 0.8406
# Episode  4000 | Loss: 0.0847 | Train Acc: 0.9810 | Val Acc: 0.8342
# Episode  5000 | Loss: 0.0561 | Train Acc: 0.9778 | Val Acc: 0.7431
# Episode  6000 | Loss: 0.0580 | Train Acc: 0.9879 | Val Acc: 0.8369
# Episode  7000 | Loss: 0.0347 | Train Acc: 0.9778 | Val Acc: 0.8133
# Episode  8000 | Loss: 0.0202 | Train Acc: 0.9917 | Val Acc: 0.8242
# Episode  9000 | Loss: 0.0137 | Train Acc: 0.9917 | Val Acc: 0.8581
# Episode 10000 | Loss: 0.1105 | Train Acc: 0.9583 | Val Acc: 0.7661
#
# --- Plotting Meta-Training Learning Curves (K=1) ---
# --- Testing Meta-Learning Model (K=1) ---
# Meta-1-Shot (Clean) | Testing...
# Meta-1-Shot (Clean) | Acc: 0.8764, F1: 0.8763
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.8779, F1: 0.8780
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.8762, F1: 0.8761
# Meta-1-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.8774, F1: 0.8773
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.8654, F1: 0.8653
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.8536, F1: 0.8536
# Meta-1-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.8320, F1: 0.8319
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.7666, F1: 0.7666
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.6624, F1: 0.6627
# Meta-1-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.5613, F1: 0.5613
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8686, F1: 0.8686
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8528, F1: 0.8528
# Meta-1-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8361, F1: 0.8360
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.8508, F1: 0.8508
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.7629, F1: 0.7629
# Meta-1-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.6197, F1: 0.6196
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 3
# ======================================================================
# --- Calculating Meta Model Stats (K=3) ---
# Meta-3 Stats | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.42, E2E Inf. Time(ms): 5.01
# --- Meta-Training (K=3, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0030 | Train Acc: 1.0000 | Val Acc: 0.9250
# Episode  2000 | Loss: 0.0272 | Train Acc: 1.0000 | Val Acc: 0.9333
# Episode  3000 | Loss: 0.0003 | Train Acc: 1.0000 | Val Acc: 0.9394
# Episode  4000 | Loss: 0.0055 | Train Acc: 1.0000 | Val Acc: 0.9589
# Episode  5000 | Loss: 0.0257 | Train Acc: 0.9810 | Val Acc: 0.9356
# Episode  6000 | Loss: 0.0059 | Train Acc: 0.9926 | Val Acc: 0.9333
# Episode  7000 | Loss: 0.0192 | Train Acc: 0.9926 | Val Acc: 0.9347
# Episode  8000 | Loss: 0.0050 | Train Acc: 1.0000 | Val Acc: 0.9622
# Episode  9000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.9653
# Episode 10000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.9417
#
# --- Plotting Meta-Training Learning Curves (K=3) ---
# --- Testing Meta-Learning Model (K=3) ---
# Meta-3-Shot (Clean) | Testing...
# Meta-3-Shot (Clean) | Acc: 0.9531, F1: 0.9531
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9402, F1: 0.9402
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9354, F1: 0.9354
# Meta-3-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9311, F1: 0.9311
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9324, F1: 0.9324
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9159, F1: 0.9159
# Meta-3-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9059, F1: 0.9059
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8166, F1: 0.8167
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7117, F1: 0.7118
# Meta-3-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.6064, F1: 0.6062
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.8877, F1: 0.8877
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.8494, F1: 0.8495
# Meta-3-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8125, F1: 0.8127
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9182, F1: 0.9180
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.8766, F1: 0.8767
# Meta-3-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7642, F1: 0.7642
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 5
# ======================================================================
# --- Calculating Meta Model Stats (K=5) ---
# Meta-5 Stats | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.42, E2E Inf. Time(ms): 4.77
# --- Meta-Training (K=5, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0001 | Train Acc: 1.0000 | Val Acc: 0.8594
# Episode  2000 | Loss: 0.0000 | Train Acc: 1.0000 | Val Acc: 0.9339
# Episode  3000 | Loss: 0.0007 | Train Acc: 1.0000 | Val Acc: 0.8917
# Episode  4000 | Loss: 0.0154 | Train Acc: 0.9939 | Val Acc: 0.9344
# Episode  5000 | Loss: 0.1384 | Train Acc: 0.9278 | Val Acc: 0.8797
# Episode  6000 | Loss: 0.0017 | Train Acc: 1.0000 | Val Acc: 0.9231
# Episode  7000 | Loss: 0.0109 | Train Acc: 0.9917 | Val Acc: 0.9478
# Episode  8000 | Loss: 0.0029 | Train Acc: 1.0000 | Val Acc: 0.9286
# Episode  9000 | Loss: 0.0008 | Train Acc: 1.0000 | Val Acc: 0.9000
# Episode 10000 | Loss: 0.0005 | Train Acc: 1.0000 | Val Acc: 0.9189
#
# --- Plotting Meta-Training Learning Curves (K=5) ---
# --- Testing Meta-Learning Model (K=5) ---
# Meta-5-Shot (Clean) | Testing...
# Meta-5-Shot (Clean) | Acc: 0.9819, F1: 0.9819
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9804, F1: 0.9804
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9809, F1: 0.9810
# Meta-5-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9799, F1: 0.9799
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9792, F1: 0.9792
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9754, F1: 0.9755
# Meta-5-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9638, F1: 0.9639
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.8811, F1: 0.8812
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.7910, F1: 0.7909
# Meta-5-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.6840, F1: 0.6840
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9721, F1: 0.9721
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9512, F1: 0.9512
# Meta-5-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.9215, F1: 0.9215
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9760, F1: 0.9760
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.9406, F1: 0.9406
# Meta-5-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.8611, F1: 0.8610
#
# ======================================================================
# STARTING META-TRAINING FOR K-SHOT = 10
# ======================================================================
# --- Calculating Meta Model Stats (K=10) ---
# Meta-10 Stats | Encoder Params(M): 0.37, Encoder FLOPs(M): 2.42, E2E Inf. Time(ms): 4.72
# --- Meta-Training (K=10, 10000 Episodes, Robust Augmentation) ---
# Episode  1000 | Loss: 0.0197 | Train Acc: 1.0000 | Val Acc: 0.9447
# Episode  2000 | Loss: 0.0060 | Train Acc: 1.0000 | Val Acc: 0.9428
# Episode  3000 | Loss: 0.0014 | Train Acc: 1.0000 | Val Acc: 0.9400
# Episode  4000 | Loss: 0.0002 | Train Acc: 1.0000 | Val Acc: 0.9394
# Episode  5000 | Loss: 0.0812 | Train Acc: 0.9867 | Val Acc: 0.9561
# Episode  6000 | Loss: 0.0009 | Train Acc: 1.0000 | Val Acc: 0.9050
# Episode  7000 | Loss: 0.0029 | Train Acc: 1.0000 | Val Acc: 0.9394
# Episode  8000 | Loss: 0.3698 | Train Acc: 0.9583 | Val Acc: 0.9156
# Episode  9000 | Loss: 0.0005 | Train Acc: 1.0000 | Val Acc: 0.9444
# Episode 10000 | Loss: 0.0001 | Train Acc: 1.0000 | Val Acc: 0.9572
#
# --- Plotting Meta-Training Learning Curves (K=10) ---
# --- Testing Meta-Learning Model (K=10) ---
# Meta-10-Shot (Clean) | Testing...
# Meta-10-Shot (Clean) | Acc: 0.9706, F1: 0.9706
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.1 | Acc: 0.9656, F1: 0.9656
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.2 | Acc: 0.9627, F1: 0.9627
# Meta-10-Shot Noisy | Type: jitter           | Lvl: 0.3 | Acc: 0.9626, F1: 0.9626
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.1 | Acc: 0.9667, F1: 0.9667
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.2 | Acc: 0.9618, F1: 0.9618
# Meta-10-Shot Noisy | Type: time_shift       | Lvl: 0.3 | Acc: 0.9490, F1: 0.9490
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.1 | Acc: 0.9098, F1: 0.9099
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.2 | Acc: 0.8248, F1: 0.8249
# Meta-10-Shot Noisy | Type: sensor_failure   | Lvl: 0.3 | Acc: 0.7242, F1: 0.7242
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.1 | Acc: 0.9507, F1: 0.9507
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.2 | Acc: 0.9224, F1: 0.9223
# Meta-10-Shot Noisy | Type: outlier_spike    | Lvl: 0.3 | Acc: 0.8873, F1: 0.8873
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.1 | Acc: 0.9654, F1: 0.9654
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.2 | Acc: 0.9195, F1: 0.9195
# Meta-10-Shot Noisy | Type: missing_segment  | Lvl: 0.3 | Acc: 0.7726, F1: 0.7722
#
# ================================================================================
# ===== FINAL COMPARISON RESULTS =====
# ================================================================================
#             Model      K-Shot                Noise  Accuracy  F1-Score  Precision    Recall
# 0      Supervised  N/A (Full)                Clean  0.916513  0.915200   0.939293  0.921429
# 1      Supervised  N/A (Full)           jitter_0.1  0.916146  0.914877   0.939167  0.921093
# 2      Supervised  N/A (Full)           jitter_0.2  0.909526  0.909000   0.931067  0.914950
# 3      Supervised  N/A (Full)           jitter_0.3  0.889665  0.890270   0.913351  0.896519
# 4      Supervised  N/A (Full)       time_shift_0.1  0.895918  0.896157   0.917936  0.901788
# 5      Supervised  N/A (Full)       time_shift_0.2  0.859507  0.859722   0.899132  0.867950
# 6      Supervised  N/A (Full)       time_shift_0.3  0.842957  0.842626   0.897024  0.853164
# 7      Supervised  N/A (Full)   sensor_failure_0.1  0.841118  0.842371   0.884243  0.852195
# 8      Supervised  N/A (Full)   sensor_failure_0.2  0.674145  0.680105   0.753783  0.695519
# 9      Supervised  N/A (Full)   sensor_failure_0.3  0.570430  0.558521   0.637065  0.595270
# 10     Supervised  N/A (Full)    outlier_spike_0.1  0.856565  0.853860   0.890745  0.865804
# 11     Supervised  N/A (Full)    outlier_spike_0.2  0.817212  0.804144   0.868117  0.829086
# 12     Supervised  N/A (Full)    outlier_spike_0.3  0.781170  0.760016   0.850735  0.794704
# 13     Supervised  N/A (Full)  missing_segment_0.1  0.868702  0.870082   0.900543  0.877245
# 14     Supervised  N/A (Full)  missing_segment_0.2  0.751379  0.749908   0.789795  0.768074
# 15     Supervised  N/A (Full)  missing_segment_0.3  0.682236  0.664020   0.759417  0.699996
# 16  Meta-Learning           1                Clean  0.876361  0.876318   0.876461  0.876361
# 17  Meta-Learning           1           jitter_0.1  0.877889  0.877953   0.878256  0.877889
# 18  Meta-Learning           1           jitter_0.2  0.876222  0.876120   0.876371  0.876222
# 19  Meta-Learning           1           jitter_0.3  0.877389  0.877332   0.877433  0.877389
# 20  Meta-Learning           1       time_shift_0.1  0.865389  0.865267   0.865508  0.865389
# 21  Meta-Learning           1       time_shift_0.2  0.853556  0.853588   0.853975  0.853556
# 22  Meta-Learning           1       time_shift_0.3  0.832000  0.831950   0.832312  0.832000
# 23  Meta-Learning           1   sensor_failure_0.1  0.766611  0.766592   0.766762  0.766611
# 24  Meta-Learning           1   sensor_failure_0.2  0.662444  0.662655   0.663611  0.662444
# 25  Meta-Learning           1   sensor_failure_0.3  0.561333  0.561300   0.561911  0.561333
# 26  Meta-Learning           1    outlier_spike_0.1  0.868556  0.868618   0.868869  0.868556
# 27  Meta-Learning           1    outlier_spike_0.2  0.852833  0.852778   0.852913  0.852833
# 28  Meta-Learning           1    outlier_spike_0.3  0.836056  0.836041   0.836292  0.836056
# 29  Meta-Learning           1  missing_segment_0.1  0.850833  0.850816   0.850921  0.850833
# 30  Meta-Learning           1  missing_segment_0.2  0.762889  0.762929   0.764166  0.762889
# 31  Meta-Learning           1  missing_segment_0.3  0.619722  0.619605   0.620687  0.619722
# 32  Meta-Learning           3                Clean  0.953111  0.953102   0.953147  0.953111
# 33  Meta-Learning           3           jitter_0.1  0.940222  0.940178   0.940451  0.940222
# 34  Meta-Learning           3           jitter_0.2  0.935389  0.935366   0.935534  0.935389
# 35  Meta-Learning           3           jitter_0.3  0.931056  0.931068   0.931152  0.931056
# 36  Meta-Learning           3       time_shift_0.1  0.932389  0.932380   0.932472  0.932389
# 37  Meta-Learning           3       time_shift_0.2  0.915889  0.915904   0.916149  0.915889
# 38  Meta-Learning           3       time_shift_0.3  0.905889  0.905859   0.906005  0.905889
# 39  Meta-Learning           3   sensor_failure_0.1  0.816556  0.816739   0.818569  0.816556
# 40  Meta-Learning           3   sensor_failure_0.2  0.711667  0.711768   0.713268  0.711667
# 41  Meta-Learning           3   sensor_failure_0.3  0.606389  0.606204   0.607547  0.606389
# 42  Meta-Learning           3    outlier_spike_0.1  0.887722  0.887708   0.887865  0.887722
# 43  Meta-Learning           3    outlier_spike_0.2  0.849444  0.849524   0.849995  0.849444
# 44  Meta-Learning           3    outlier_spike_0.3  0.812500  0.812734   0.813465  0.812500
# 45  Meta-Learning           3  missing_segment_0.1  0.918167  0.918032   0.918221  0.918167
# 46  Meta-Learning           3  missing_segment_0.2  0.876611  0.876669   0.877091  0.876611
# 47  Meta-Learning           3  missing_segment_0.3  0.764222  0.764162   0.765655  0.764222
# 48  Meta-Learning           5                Clean  0.981861  0.981865   0.981886  0.981861
# 49  Meta-Learning           5           jitter_0.1  0.980444  0.980436   0.980444  0.980444
# 50  Meta-Learning           5           jitter_0.2  0.980944  0.980953   0.981002  0.980944
# 51  Meta-Learning           5           jitter_0.3  0.979944  0.979936   0.979972  0.979944
# 52  Meta-Learning           5       time_shift_0.1  0.979167  0.979165   0.979224  0.979167
# 53  Meta-Learning           5       time_shift_0.2  0.975444  0.975451   0.975523  0.975444
# 54  Meta-Learning           5       time_shift_0.3  0.963833  0.963859   0.963937  0.963833
# 55  Meta-Learning           5   sensor_failure_0.1  0.881056  0.881152   0.881630  0.881056
# 56  Meta-Learning           5   sensor_failure_0.2  0.791000  0.790872   0.791355  0.791000
# 57  Meta-Learning           5   sensor_failure_0.3  0.684000  0.683983   0.685122  0.684000
# 58  Meta-Learning           5    outlier_spike_0.1  0.972111  0.972110   0.972167  0.972111
# 59  Meta-Learning           5    outlier_spike_0.2  0.951222  0.951208   0.951279  0.951222
# 60  Meta-Learning           5    outlier_spike_0.3  0.921500  0.921464   0.921584  0.921500
# 61  Meta-Learning           5  missing_segment_0.1  0.976000  0.976011   0.976058  0.976000
# 62  Meta-Learning           5  missing_segment_0.2  0.940556  0.940567   0.940702  0.940556
# 63  Meta-Learning           5  missing_segment_0.3  0.861056  0.861050   0.861531  0.861056
# 64  Meta-Learning          10                Clean  0.970611  0.970614   0.970636  0.970611
# 65  Meta-Learning          10           jitter_0.1  0.965611  0.965599   0.965627  0.965611
# 66  Meta-Learning          10           jitter_0.2  0.962722  0.962698   0.962723  0.962722
# 67  Meta-Learning          10           jitter_0.3  0.962556  0.962555   0.962583  0.962556
# 68  Meta-Learning          10       time_shift_0.1  0.966667  0.966683   0.966766  0.966667
# 69  Meta-Learning          10       time_shift_0.2  0.961833  0.961829   0.961856  0.961833
# 70  Meta-Learning          10       time_shift_0.3  0.949000  0.948988   0.949033  0.949000
# 71  Meta-Learning          10   sensor_failure_0.1  0.909833  0.909917   0.910408  0.909833
# 72  Meta-Learning          10   sensor_failure_0.2  0.824778  0.824870   0.825656  0.824778
# 73  Meta-Learning          10   sensor_failure_0.3  0.724167  0.724176   0.724729  0.724167
# 74  Meta-Learning          10    outlier_spike_0.1  0.950667  0.950665   0.950714  0.950667
# 75  Meta-Learning          10    outlier_spike_0.2  0.922389  0.922334   0.922567  0.922389
# 76  Meta-Learning          10    outlier_spike_0.3  0.887278  0.887306   0.887420  0.887278
# 77  Meta-Learning          10  missing_segment_0.1  0.965444  0.965443   0.965467  0.965444
# 78  Meta-Learning          10  missing_segment_0.2  0.919500  0.919542   0.919824  0.919500
# 79  Meta-Learning          10  missing_segment_0.3  0.772611  0.772242   0.772926  0.772611
# ================================================================================
# ===== PIVOT TABLE: ACCURACY =====
# ================================================================================
# <style type="text/css">
# #T_35121_row0_col3, #T_35121_row1_col3, #T_35121_row2_col3, #T_35121_row3_col3, #T_35121_row4_col3, #T_35121_row5_col3, #T_35121_row6_col3, #T_35121_row7_col3, #T_35121_row8_col3, #T_35121_row9_col3, #T_35121_row10_col4, #T_35121_row11_col4, #T_35121_row12_col4, #T_35121_row13_col3, #T_35121_row14_col3, #T_35121_row15_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_35121" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_35121_level0_col0" class="col_heading level0 col0" >Supervised</th>
#       <th id="T_35121_level0_col1" class="col_heading level0 col1" colspan="4">Meta-Learning</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >K-Shot</th>
#       <th id="T_35121_level1_col0" class="col_heading level1 col0" >N/A (Full)</th>
#       <th id="T_35121_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_35121_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_35121_level1_col3" class="col_heading level1 col3" >5</th>
#       <th id="T_35121_level1_col4" class="col_heading level1 col4" >10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Noise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35121_level0_row0" class="row_heading level0 row0" >Clean</th>
#       <td id="T_35121_row0_col0" class="data row0 col0" >0.9165</td>
#       <td id="T_35121_row0_col1" class="data row0 col1" >0.8764</td>
#       <td id="T_35121_row0_col2" class="data row0 col2" >0.9531</td>
#       <td id="T_35121_row0_col3" class="data row0 col3" >0.9819</td>
#       <td id="T_35121_row0_col4" class="data row0 col4" >0.9706</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row1" class="row_heading level0 row1" >jitter_0.1</th>
#       <td id="T_35121_row1_col0" class="data row1 col0" >0.9161</td>
#       <td id="T_35121_row1_col1" class="data row1 col1" >0.8779</td>
#       <td id="T_35121_row1_col2" class="data row1 col2" >0.9402</td>
#       <td id="T_35121_row1_col3" class="data row1 col3" >0.9804</td>
#       <td id="T_35121_row1_col4" class="data row1 col4" >0.9656</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row2" class="row_heading level0 row2" >jitter_0.2</th>
#       <td id="T_35121_row2_col0" class="data row2 col0" >0.9095</td>
#       <td id="T_35121_row2_col1" class="data row2 col1" >0.8762</td>
#       <td id="T_35121_row2_col2" class="data row2 col2" >0.9354</td>
#       <td id="T_35121_row2_col3" class="data row2 col3" >0.9809</td>
#       <td id="T_35121_row2_col4" class="data row2 col4" >0.9627</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row3" class="row_heading level0 row3" >jitter_0.3</th>
#       <td id="T_35121_row3_col0" class="data row3 col0" >0.8897</td>
#       <td id="T_35121_row3_col1" class="data row3 col1" >0.8774</td>
#       <td id="T_35121_row3_col2" class="data row3 col2" >0.9311</td>
#       <td id="T_35121_row3_col3" class="data row3 col3" >0.9799</td>
#       <td id="T_35121_row3_col4" class="data row3 col4" >0.9626</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row4" class="row_heading level0 row4" >missing_segment_0.1</th>
#       <td id="T_35121_row4_col0" class="data row4 col0" >0.8687</td>
#       <td id="T_35121_row4_col1" class="data row4 col1" >0.8508</td>
#       <td id="T_35121_row4_col2" class="data row4 col2" >0.9182</td>
#       <td id="T_35121_row4_col3" class="data row4 col3" >0.9760</td>
#       <td id="T_35121_row4_col4" class="data row4 col4" >0.9654</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row5" class="row_heading level0 row5" >missing_segment_0.2</th>
#       <td id="T_35121_row5_col0" class="data row5 col0" >0.7514</td>
#       <td id="T_35121_row5_col1" class="data row5 col1" >0.7629</td>
#       <td id="T_35121_row5_col2" class="data row5 col2" >0.8766</td>
#       <td id="T_35121_row5_col3" class="data row5 col3" >0.9406</td>
#       <td id="T_35121_row5_col4" class="data row5 col4" >0.9195</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row6" class="row_heading level0 row6" >missing_segment_0.3</th>
#       <td id="T_35121_row6_col0" class="data row6 col0" >0.6822</td>
#       <td id="T_35121_row6_col1" class="data row6 col1" >0.6197</td>
#       <td id="T_35121_row6_col2" class="data row6 col2" >0.7642</td>
#       <td id="T_35121_row6_col3" class="data row6 col3" >0.8611</td>
#       <td id="T_35121_row6_col4" class="data row6 col4" >0.7726</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row7" class="row_heading level0 row7" >outlier_spike_0.1</th>
#       <td id="T_35121_row7_col0" class="data row7 col0" >0.8566</td>
#       <td id="T_35121_row7_col1" class="data row7 col1" >0.8686</td>
#       <td id="T_35121_row7_col2" class="data row7 col2" >0.8877</td>
#       <td id="T_35121_row7_col3" class="data row7 col3" >0.9721</td>
#       <td id="T_35121_row7_col4" class="data row7 col4" >0.9507</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row8" class="row_heading level0 row8" >outlier_spike_0.2</th>
#       <td id="T_35121_row8_col0" class="data row8 col0" >0.8172</td>
#       <td id="T_35121_row8_col1" class="data row8 col1" >0.8528</td>
#       <td id="T_35121_row8_col2" class="data row8 col2" >0.8494</td>
#       <td id="T_35121_row8_col3" class="data row8 col3" >0.9512</td>
#       <td id="T_35121_row8_col4" class="data row8 col4" >0.9224</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row9" class="row_heading level0 row9" >outlier_spike_0.3</th>
#       <td id="T_35121_row9_col0" class="data row9 col0" >0.7812</td>
#       <td id="T_35121_row9_col1" class="data row9 col1" >0.8361</td>
#       <td id="T_35121_row9_col2" class="data row9 col2" >0.8125</td>
#       <td id="T_35121_row9_col3" class="data row9 col3" >0.9215</td>
#       <td id="T_35121_row9_col4" class="data row9 col4" >0.8873</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row10" class="row_heading level0 row10" >sensor_failure_0.1</th>
#       <td id="T_35121_row10_col0" class="data row10 col0" >0.8411</td>
#       <td id="T_35121_row10_col1" class="data row10 col1" >0.7666</td>
#       <td id="T_35121_row10_col2" class="data row10 col2" >0.8166</td>
#       <td id="T_35121_row10_col3" class="data row10 col3" >0.8811</td>
#       <td id="T_35121_row10_col4" class="data row10 col4" >0.9098</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row11" class="row_heading level0 row11" >sensor_failure_0.2</th>
#       <td id="T_35121_row11_col0" class="data row11 col0" >0.6741</td>
#       <td id="T_35121_row11_col1" class="data row11 col1" >0.6624</td>
#       <td id="T_35121_row11_col2" class="data row11 col2" >0.7117</td>
#       <td id="T_35121_row11_col3" class="data row11 col3" >0.7910</td>
#       <td id="T_35121_row11_col4" class="data row11 col4" >0.8248</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row12" class="row_heading level0 row12" >sensor_failure_0.3</th>
#       <td id="T_35121_row12_col0" class="data row12 col0" >0.5704</td>
#       <td id="T_35121_row12_col1" class="data row12 col1" >0.5613</td>
#       <td id="T_35121_row12_col2" class="data row12 col2" >0.6064</td>
#       <td id="T_35121_row12_col3" class="data row12 col3" >0.6840</td>
#       <td id="T_35121_row12_col4" class="data row12 col4" >0.7242</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row13" class="row_heading level0 row13" >time_shift_0.1</th>
#       <td id="T_35121_row13_col0" class="data row13 col0" >0.8959</td>
#       <td id="T_35121_row13_col1" class="data row13 col1" >0.8654</td>
#       <td id="T_35121_row13_col2" class="data row13 col2" >0.9324</td>
#       <td id="T_35121_row13_col3" class="data row13 col3" >0.9792</td>
#       <td id="T_35121_row13_col4" class="data row13 col4" >0.9667</td>
#     </tr>
#     <tr>
#       <th id="T_35121_level0_row14" class="row_heading level0 row14" >time_shift_0.2</th>
#       <td id="T_35121_row14_col0" class="data row14 col0" >0.8595</
# ================================================================================
# ===== PIVOT TABLE: F1-SCORE =====
# ================================================================================
# <style type="text/css">
# #T_9ab55_row0_col3, #T_9ab55_row1_col3, #T_9ab55_row2_col3, #T_9ab55_row3_col3, #T_9ab55_row4_col3, #T_9ab55_row5_col3, #T_9ab55_row6_col3, #T_9ab55_row7_col3, #T_9ab55_row8_col3, #T_9ab55_row9_col3, #T_9ab55_row10_col4, #T_9ab55_row11_col4, #T_9ab55_row12_col4, #T_9ab55_row13_col3, #T_9ab55_row14_col3, #T_9ab55_row15_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9ab55" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_9ab55_level0_col0" class="col_heading level0 col0" >Supervised</th>
#       <th id="T_9ab55_level0_col1" class="col_heading level0 col1" colspan="4">Meta-Learning</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >K-Shot</th>
#       <th id="T_9ab55_level1_col0" class="col_heading level1 col0" >N/A (Full)</th>
#       <th id="T_9ab55_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_9ab55_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_9ab55_level1_col3" class="col_heading level1 col3" >5</th>
#       <th id="T_9ab55_level1_col4" class="col_heading level1 col4" >10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Noise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab55_level0_row0" class="row_heading level0 row0" >Clean</th>
#       <td id="T_9ab55_row0_col0" class="data row0 col0" >0.9152</td>
#       <td id="T_9ab55_row0_col1" class="data row0 col1" >0.8763</td>
#       <td id="T_9ab55_row0_col2" class="data row0 col2" >0.9531</td>
#       <td id="T_9ab55_row0_col3" class="data row0 col3" >0.9819</td>
#       <td id="T_9ab55_row0_col4" class="data row0 col4" >0.9706</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row1" class="row_heading level0 row1" >jitter_0.1</th>
#       <td id="T_9ab55_row1_col0" class="data row1 col0" >0.9149</td>
#       <td id="T_9ab55_row1_col1" class="data row1 col1" >0.8780</td>
#       <td id="T_9ab55_row1_col2" class="data row1 col2" >0.9402</td>
#       <td id="T_9ab55_row1_col3" class="data row1 col3" >0.9804</td>
#       <td id="T_9ab55_row1_col4" class="data row1 col4" >0.9656</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row2" class="row_heading level0 row2" >jitter_0.2</th>
#       <td id="T_9ab55_row2_col0" class="data row2 col0" >0.9090</td>
#       <td id="T_9ab55_row2_col1" class="data row2 col1" >0.8761</td>
#       <td id="T_9ab55_row2_col2" class="data row2 col2" >0.9354</td>
#       <td id="T_9ab55_row2_col3" class="data row2 col3" >0.9810</td>
#       <td id="T_9ab55_row2_col4" class="data row2 col4" >0.9627</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row3" class="row_heading level0 row3" >jitter_0.3</th>
#       <td id="T_9ab55_row3_col0" class="data row3 col0" >0.8903</td>
#       <td id="T_9ab55_row3_col1" class="data row3 col1" >0.8773</td>
#       <td id="T_9ab55_row3_col2" class="data row3 col2" >0.9311</td>
#       <td id="T_9ab55_row3_col3" class="data row3 col3" >0.9799</td>
#       <td id="T_9ab55_row3_col4" class="data row3 col4" >0.9626</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row4" class="row_heading level0 row4" >missing_segment_0.1</th>
#       <td id="T_9ab55_row4_col0" class="data row4 col0" >0.8701</td>
#       <td id="T_9ab55_row4_col1" class="data row4 col1" >0.8508</td>
#       <td id="T_9ab55_row4_col2" class="data row4 col2" >0.9180</td>
#       <td id="T_9ab55_row4_col3" class="data row4 col3" >0.9760</td>
#       <td id="T_9ab55_row4_col4" class="data row4 col4" >0.9654</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row5" class="row_heading level0 row5" >missing_segment_0.2</th>
#       <td id="T_9ab55_row5_col0" class="data row5 col0" >0.7499</td>
#       <td id="T_9ab55_row5_col1" class="data row5 col1" >0.7629</td>
#       <td id="T_9ab55_row5_col2" class="data row5 col2" >0.8767</td>
#       <td id="T_9ab55_row5_col3" class="data row5 col3" >0.9406</td>
#       <td id="T_9ab55_row5_col4" class="data row5 col4" >0.9195</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row6" class="row_heading level0 row6" >missing_segment_0.3</th>
#       <td id="T_9ab55_row6_col0" class="data row6 col0" >0.6640</td>
#       <td id="T_9ab55_row6_col1" class="data row6 col1" >0.6196</td>
#       <td id="T_9ab55_row6_col2" class="data row6 col2" >0.7642</td>
#       <td id="T_9ab55_row6_col3" class="data row6 col3" >0.8610</td>
#       <td id="T_9ab55_row6_col4" class="data row6 col4" >0.7722</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row7" class="row_heading level0 row7" >outlier_spike_0.1</th>
#       <td id="T_9ab55_row7_col0" class="data row7 col0" >0.8539</td>
#       <td id="T_9ab55_row7_col1" class="data row7 col1" >0.8686</td>
#       <td id="T_9ab55_row7_col2" class="data row7 col2" >0.8877</td>
#       <td id="T_9ab55_row7_col3" class="data row7 col3" >0.9721</td>
#       <td id="T_9ab55_row7_col4" class="data row7 col4" >0.9507</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row8" class="row_heading level0 row8" >outlier_spike_0.2</th>
#       <td id="T_9ab55_row8_col0" class="data row8 col0" >0.8041</td>
#       <td id="T_9ab55_row8_col1" class="data row8 col1" >0.8528</td>
#       <td id="T_9ab55_row8_col2" class="data row8 col2" >0.8495</td>
#       <td id="T_9ab55_row8_col3" class="data row8 col3" >0.9512</td>
#       <td id="T_9ab55_row8_col4" class="data row8 col4" >0.9223</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row9" class="row_heading level0 row9" >outlier_spike_0.3</th>
#       <td id="T_9ab55_row9_col0" class="data row9 col0" >0.7600</td>
#       <td id="T_9ab55_row9_col1" class="data row9 col1" >0.8360</td>
#       <td id="T_9ab55_row9_col2" class="data row9 col2" >0.8127</td>
#       <td id="T_9ab55_row9_col3" class="data row9 col3" >0.9215</td>
#       <td id="T_9ab55_row9_col4" class="data row9 col4" >0.8873</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row10" class="row_heading level0 row10" >sensor_failure_0.1</th>
#       <td id="T_9ab55_row10_col0" class="data row10 col0" >0.8424</td>
#       <td id="T_9ab55_row10_col1" class="data row10 col1" >0.7666</td>
#       <td id="T_9ab55_row10_col2" class="data row10 col2" >0.8167</td>
#       <td id="T_9ab55_row10_col3" class="data row10 col3" >0.8812</td>
#       <td id="T_9ab55_row10_col4" class="data row10 col4" >0.9099</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row11" class="row_heading level0 row11" >sensor_failure_0.2</th>
#       <td id="T_9ab55_row11_col0" class="data row11 col0" >0.6801</td>
#       <td id="T_9ab55_row11_col1" class="data row11 col1" >0.6627</td>
#       <td id="T_9ab55_row11_col2" class="data row11 col2" >0.7118</td>
#       <td id="T_9ab55_row11_col3" class="data row11 col3" >0.7909</td>
#       <td id="T_9ab55_row11_col4" class="data row11 col4" >0.8249</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row12" class="row_heading level0 row12" >sensor_failure_0.3</th>
#       <td id="T_9ab55_row12_col0" class="data row12 col0" >0.5585</td>
#       <td id="T_9ab55_row12_col1" class="data row12 col1" >0.5613</td>
#       <td id="T_9ab55_row12_col2" class="data row12 col2" >0.6062</td>
#       <td id="T_9ab55_row12_col3" class="data row12 col3" >0.6840</td>
#       <td id="T_9ab55_row12_col4" class="data row12 col4" >0.7242</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row13" class="row_heading level0 row13" >time_shift_0.1</th>
#       <td id="T_9ab55_row13_col0" class="data row13 col0" >0.8962</td>
#       <td id="T_9ab55_row13_col1" class="data row13 col1" >0.8653</td>
#       <td id="T_9ab55_row13_col2" class="data row13 col2" >0.9324</td>
#       <td id="T_9ab55_row13_col3" class="data row13 col3" >0.9792</td>
#       <td id="T_9ab55_row13_col4" class="data row13 col4" >0.9667</td>
#     </tr>
#     <tr>
#       <th id="T_9ab55_level0_row14" class="row_heading level0 row14" >time_shift_0.2</th>
#       <td id="T_9ab55_row14_col0" class="data row14 col0" >0.8597</
# ================================================================================
# ===== MODEL STATISTICS (Params, FLOPs, Latency) =====
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_fe6bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe6bb_level0_col0" class="col_heading level0 col0" >Param (M)</th>
#       <th id="T_fe6bb_level0_col1" class="col_heading level0 col1" >FLOPs (M)</th>
#       <th id="T_fe6bb_level0_col2" class="col_heading level0 col2" >Inf. Time (ms)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="index_name level1" >K-Shot</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe6bb_level0_row0" class="row_heading level0 row0" >Supervised</th>
#       <th id="T_fe6bb_level1_row0" class="row_heading level1 row0" >N/A (Full)</th>
#       <td id="T_fe6bb_row0_col0" class="data row0 col0" >0.37</td>
#       <td id="T_fe6bb_row0_col1" class="data row0 col1" >2.42</td>
#       <td id="T_fe6bb_row0_col2" class="data row0 col2" >1.44</td>
#     </tr>
#     <tr>
#       <th id="T_fe6bb_level0_row1" class="row_heading level0 row1" rowspan="4">Meta-Learning</th>
#       <th id="T_fe6bb_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_fe6bb_row1_col0" class="data row1 col0" >0.37</td>
#       <td id="T_fe6bb_row1_col1" class="data row1 col1" >2.42</td>
#       <td id="T_fe6bb_row1_col2" class="data row1 col2" >4.72</td>
#     </tr>
#     <tr>
#       <th id="T_fe6bb_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_fe6bb_row2_col0" class="data row2 col0" >0.37</td>
#       <td id="T_fe6bb_row2_col1" class="data row2 col1" >2.42</td>
#       <td id="T_fe6bb_row2_col2" class="data row2 col2" >5.01</td>
#     </tr>
#     <tr>
#       <th id="T_fe6bb_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_fe6bb_row3_col0" class="data row3 col0" >0.37</td>
#       <td id="T_fe6bb_row3_col1" class="data row3 col1" >2.42</td>
#       <td id="T_fe6bb_row3_col2" class="data row3 col2" >4.77</td>
#     </tr>
#     <tr>
#       <th id="T_fe6bb_level1_row4" class="row_heading level1 row4" >10</th>
#       <td id="T_fe6bb_row4_col0" class="data row4 col0" >0.37</td>
#       <td id="T_fe6bb_row4_col1" class="data row4 col1" >2.42</td>
#       <td id="T_fe6bb_row4_col2" class="data row4 col2" >4.72</td>
#     </tr>
#   </tbody>
# </table>
